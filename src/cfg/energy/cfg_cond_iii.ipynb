# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset
import matplotlib.pyplot as plt
from tqdm import tqdm
from joblib import Parallel, delayed
from time import perf_counter
from functools import partial
import random
from numba import jit
import scipy as sp

os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

# %%
s = np.load("ising_samples.npy")
h = np.load("ising_h.npy")
J = np.load("ising_J.npy")

# %%
class SinusoidalTimeEmbedding(nn.Module):
    def __init__(self, dim):
        super().__init__()
        self.dim = dim
    def forward(self, t):
        half_dim = self.dim // 2
        emb = torch.exp(torch.arange(half_dim, device=t.device) * -(np.log(10000) / (half_dim-1)))
        emb = t[:, None] * emb[None, :]
        return torch.cat([torch.sin(emb), torch.cos(emb)], dim=-1)

class DiffusionMLP(nn.Module):
    def __init__(self, input_dim=40, n_class=2, embed_dim=32):
        super().__init__()
        self.embedding = nn.Embedding(n_class+1, embed_dim)
        time_embed_dim = 128
        self.time_embed = SinusoidalTimeEmbedding(time_embed_dim)
        self.enc1 = nn.Linear(input_dim + time_embed_dim + embed_dim, 128)
        self.enc2 = nn.Linear(128, 256)
        self.enc3 = nn.Linear(256, 512)
        self.dec1 = nn.Linear(512, 512)
        self.dec2 = nn.Linear(512, 512)
        self.dec3 = nn.Linear(512, 256)
        self.dec4 = nn.Linear(256, 128)
        self.out = nn.Linear(128, input_dim)
        self.act = nn.GELU()
    def forward(self, x, t, y):
        t_embed = self.time_embed(t).to(x.dtype)
        y_embed = self.embedding(y).to(x.dtype)
        h = torch.cat([x, t_embed, y_embed], dim=1)
        h1 = self.act(self.enc1(h))
        h2 = self.act(self.enc2(h1))
        h3 = self.act(self.enc3(h2))
        d1 = self.act(self.dec1(h3))
        d2 = self.act(self.dec2(d1) + d1)
        d3 = self.act(self.dec3(d2) + h2)
        d4 = self.act(self.dec4(d3) + h1)
        return self.out(d4)

# ------------------------------
# 3. DDPM 정의
# ------------------------------
class DDPM(nn.Module):
    def __init__(self, model, beta_start=0.001, beta_end=0.02, n_T=1000, device='cuda'):
        super().__init__()
        self.model = model
        self.n_T = n_T
        self.device = device

        betas = torch.linspace(beta_start, beta_end, n_T).to(device)
        alphas = 1 - betas
        alphabar = torch.cumprod(alphas, dim=0)

        self.register_buffer("betas", betas)
        self.register_buffer("alphas", alphas)
        self.register_buffer("alphabar", alphabar)
        self.register_buffer("sqrtab", torch.sqrt(alphabar))
        self.register_buffer("sqrtmab", torch.sqrt(1 - alphabar))
        self.register_buffer("oneover_sqrta", 1 / torch.sqrt(alphas))
        self.register_buffer("bt_over_sqrtmab", betas / torch.sqrt(1 - alphabar))
        self.register_buffer("sqrt_beta_t", torch.sqrt(betas))

    def forward(self, x, y):
        B = x.shape[0]
        t = torch.randint(1, self.n_T+1, (B,), device=x.device).float()
        sqrtab_t = self.sqrtab[t.long()-1].view(B, 1)
        sqrtmab_t = self.sqrtmab[t.long()-1].view(B, 1)
        eps = torch.randn_like(x)
        x_t = sqrtab_t * x + sqrtmab_t * eps
        eps_pred = self.model(x_t, t, y)
        return F.mse_loss(eps_pred, eps)

# %%
# ------------------------------
# 5. Training Loop & 샘플링
# ------------------------------
# 모델을 불러오고 파라미터 로드 후 이를 사용하여 샘플링을 수행합니다! 반드시 돌리지 않으셔도됩니다. 이미 데이터가 저장되어있습니다.
n_class = 2
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = DiffusionMLP(n_class=n_class).to(device)

# 저장된 파라미터 로드
epoch = 30000
model.load_state_dict(torch.load(f"model/model_epoch_{epoch}.pth"))
model.eval() 
ddpm = DDPM(model, device=device).to(device)

n_sample_per_batch = 500
n_batches = 100  # 1000 * 100 = 100,000
N = 40
guidance_scale = 1.0
for y_value, label in zip([0, 1], ['freq', 'rare']):
    for batch_idx in range(n_batches):
        with torch.no_grad():  # 추가!
            x = torch.randn(n_sample_per_batch, N).to(device)

            for t in reversed(range(1, ddpm.n_T + 1)):
                t_batch = torch.full((n_sample_per_batch,), t, device=device).float()
                y_cond = torch.full((n_sample_per_batch,), y_value, device=device, dtype=torch.long)
                y_null = torch.ones_like(y_cond) * n_class

                eps_cond = model(x, t_batch, y_cond)
                eps_null = model(x, t_batch, y_null)
                eps = eps_null + guidance_scale * (eps_cond - eps_null)

                mu = ddpm.oneover_sqrta[t-1] * (x - ddpm.bt_over_sqrtmab[t-1] * eps)
                sigma = ddpm.sqrt_beta_t[t-1]
                z = torch.randn_like(x) if t > 1 else torch.zeros_like(x)
                x = mu + sigma * z

            # numpy 저장
            # x_numpy = x.cpu().numpy()
            # os.makedirs(f"{label}_{epoch}", exist_ok=True)
            # np.save(f"{label}_{epoch}/{label}_batch_{batch_idx:03d}.npy", x_numpy)

        torch.cuda.empty_cache()  # 추가: 메모리 해제!
        print(f"✅ Saved {label}_{batch_idx:03d}.npy ({n_sample_per_batch} samples)")
# Out:
# /tmp/ipykernel_35100/725023980.py:83: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"model_epoch_{epoch}.pth"))
# ✅ Saved freq_000.npy (500 samples)
# ✅ Saved freq_001.npy (500 samples)
# ✅ Saved freq_002.npy (500 samples)
# ✅ Saved freq_003.npy (500 samples)
# ✅ Saved freq_004.npy (500 samples)
# ✅ Saved freq_005.npy (500 samples)
# ✅ Saved freq_006.npy (500 samples)
# ✅ Saved freq_007.npy (500 samples)
# ✅ Saved freq_008.npy (500 samples)
# ✅ Saved freq_009.npy (500 samples)
# ✅ Saved freq_010.npy (500 samples)
# ✅ Saved freq_011.npy (500 samples)
# ✅ Saved freq_012.npy (500 samples)
# ✅ Saved freq_013.npy (500 samples)
# ✅ Saved freq_014.npy (500 samples)
# ✅ Saved freq_015.npy (500 samples)
# ✅ Saved freq_016.npy (500 samples)
# ✅ Saved freq_017.npy (500 samples)
# ✅ Saved freq_018.npy (500 samples)
# ✅ Saved freq_019.npy (500 samples)
# ✅ Saved freq_020.npy (500 samples)
# ✅ Saved freq_021.npy (500 samples)
# ✅ Saved freq_022.npy (500 samples)
# ✅ Saved freq_023.npy (500 samples)
# ✅ Saved freq_024.npy (500 samples)
# ✅ Saved freq_025.npy (500 samples)
# ✅ Saved freq_026.npy (500 samples)
# ✅ Saved freq_027.npy (500 samples)
# ✅ Saved freq_028.npy (500 samples)
# ✅ Saved freq_029.npy (500 samples)
# ✅ Saved freq_030.npy (500 samples)
# ✅ Saved freq_031.npy (500 samples)
# ✅ Saved freq_032.npy (500 samples)
# ✅ Saved freq_033.npy (500 samples)
# ✅ Saved freq_034.npy (500 samples)
# ✅ Saved freq_035.npy (500 samples)
# ✅ Saved freq_036.npy (500 samples)
# ✅ Saved freq_037.npy (500 samples)
# ✅ Saved freq_038.npy (500 samples)
# ✅ Saved freq_039.npy (500 samples)
# ✅ Saved freq_040.npy (500 samples)
# ✅ Saved freq_041.npy (500 samples)
# ✅ Saved freq_042.npy (500 samples)
# ✅ Saved freq_043.npy (500 samples)
# ✅ Saved freq_044.npy (500 samples)
# ✅ Saved freq_045.npy (500 samples)
# ✅ Saved freq_046.npy (500 samples)
# ✅ Saved freq_047.npy (500 samples)
# ✅ Saved freq_048.npy (500 samples)
# ✅ Saved freq_049.npy (500 samples)
# ✅ Saved freq_050.npy (500 samples)
# ✅ Saved freq_051.npy (500 samples)
# ✅ Saved freq_052.npy (500 samples)
# ✅ Saved freq_053.npy (500 samples)
# ✅ Saved freq_054.npy (500 samples)
# ✅ Saved freq_055.npy (500 samples)
# ✅ Saved freq_056.npy (500 samples)
# ✅ Saved freq_057.npy (500 samples)
# ✅ Saved freq_058.npy (500 samples)
# ✅ Saved freq_059.npy (500 samples)
# ✅ Saved freq_060.npy (500 samples)
# ✅ Saved freq_061.npy (500 samples)
# ✅ Saved freq_062.npy (500 samples)
# ✅ Saved freq_063.npy (500 samples)
# ✅ Saved freq_064.npy (500 samples)
# ✅ Saved freq_065.npy (500 samples)
# ✅ Saved freq_066.npy (500 samples)
# ✅ Saved freq_067.npy (500 samples)
# ✅ Saved freq_068.npy (500 samples)
# ✅ Saved freq_069.npy (500 samples)
# ✅ Saved freq_070.npy (500 samples)
# ✅ Saved freq_071.npy (500 samples)
# ✅ Saved freq_072.npy (500 samples)
# ✅ Saved freq_073.npy (500 samples)
# ✅ Saved freq_074.npy (500 samples)
# ✅ Saved freq_075.npy (500 samples)
# ✅ Saved freq_076.npy (500 samples)
# ✅ Saved freq_077.npy (500 samples)
# ✅ Saved freq_078.npy (500 samples)
# ✅ Saved freq_079.npy (500 samples)
# ✅ Saved freq_080.npy (500 samples)
# ✅ Saved freq_081.npy (500 samples)
# ✅ Saved freq_082.npy (500 samples)
# ✅ Saved freq_083.npy (500 samples)
# ✅ Saved freq_084.npy (500 samples)
# ✅ Saved freq_085.npy (500 samples)
# ✅ Saved freq_086.npy (500 samples)
# ✅ Saved freq_087.npy (500 samples)
# ✅ Saved freq_088.npy (500 samples)
# ✅ Saved freq_089.npy (500 samples)
# ✅ Saved freq_090.npy (500 samples)
# ✅ Saved freq_091.npy (500 samples)
# ✅ Saved freq_092.npy (500 samples)
# ✅ Saved freq_093.npy (500 samples)
# ✅ Saved freq_094.npy (500 samples)
# ✅ Saved freq_095.npy (500 samples)
# ✅ Saved freq_096.npy (500 samples)
# ✅ Saved freq_097.npy (500 samples)
# ✅ Saved freq_098.npy (500 samples)
# ✅ Saved freq_099.npy (500 samples)
# ✅ Saved rare_000.npy (500 samples)
# ✅ Saved rare_001.npy (500 samples)
# ✅ Saved rare_002.npy (500 samples)
# ✅ Saved rare_003.npy (500 samples)
# ✅ Saved rare_004.npy (500 samples)
# ✅ Saved rare_005.npy (500 samples)
# ✅ Saved rare_006.npy (500 samples)
# ✅ Saved rare_007.npy (500 samples)
# ✅ Saved rare_008.npy (500 samples)
# ✅ Saved rare_009.npy (500 samples)
# ✅ Saved rare_010.npy (500 samples)
# ✅ Saved rare_011.npy (500 samples)
# ✅ Saved rare_012.npy (500 samples)
# ✅ Saved rare_013.npy (500 samples)
# ✅ Saved rare_014.npy (500 samples)
# ✅ Saved rare_015.npy (500 samples)
# ✅ Saved rare_016.npy (500 samples)
# ✅ Saved rare_017.npy (500 samples)
# ✅ Saved rare_018.npy (500 samples)
# ✅ Saved rare_019.npy (500 samples)
# ✅ Saved rare_020.npy (500 samples)
# ✅ Saved rare_021.npy (500 samples)
# ✅ Saved rare_022.npy (500 samples)
# ✅ Saved rare_023.npy (500 samples)
# ✅ Saved rare_024.npy (500 samples)
# ✅ Saved rare_025.npy (500 samples)
# ✅ Saved rare_026.npy (500 samples)
# ✅ Saved rare_027.npy (500 samples)
# ✅ Saved rare_028.npy (500 samples)
# ✅ Saved rare_029.npy (500 samples)
# ✅ Saved rare_030.npy (500 samples)
# ✅ Saved rare_031.npy (500 samples)
# ✅ Saved rare_032.npy (500 samples)
# ✅ Saved rare_033.npy (500 samples)
# ✅ Saved rare_034.npy (500 samples)
# ✅ Saved rare_035.npy (500 samples)
# ✅ Saved rare_036.npy (500 samples)
# ✅ Saved rare_037.npy (500 samples)
# ✅ Saved rare_038.npy (500 samples)
# ✅ Saved rare_039.npy (500 samples)
# ✅ Saved rare_040.npy (500 samples)
# ✅ Saved rare_041.npy (500 samples)
# ✅ Saved rare_042.npy (500 samples)
# ✅ Saved rare_043.npy (500 samples)
# ✅ Saved rare_044.npy (500 samples)
# ✅ Saved rare_045.npy (500 samples)
# ✅ Saved rare_046.npy (500 samples)
# ✅ Saved rare_047.npy (500 samples)
# ✅ Saved rare_048.npy (500 samples)
# ✅ Saved rare_049.npy (500 samples)
# ✅ Saved rare_050.npy (500 samples)
# ✅ Saved rare_051.npy (500 samples)
# ✅ Saved rare_052.npy (500 samples)
# ✅ Saved rare_053.npy (500 samples)
# ✅ Saved rare_054.npy (500 samples)
# ✅ Saved rare_055.npy (500 samples)
# ✅ Saved rare_056.npy (500 samples)
# ✅ Saved rare_057.npy (500 samples)
# ✅ Saved rare_058.npy (500 samples)
# ✅ Saved rare_059.npy (500 samples)
# ✅ Saved rare_060.npy (500 samples)
# ✅ Saved rare_061.npy (500 samples)
# ✅ Saved rare_062.npy (500 samples)
# ✅ Saved rare_063.npy (500 samples)
# ✅ Saved rare_064.npy (500 samples)
# ✅ Saved rare_065.npy (500 samples)
# ✅ Saved rare_066.npy (500 samples)
# ✅ Saved rare_067.npy (500 samples)
# ✅ Saved rare_068.npy (500 samples)
# ✅ Saved rare_069.npy (500 samples)
# ✅ Saved rare_070.npy (500 samples)
# ✅ Saved rare_071.npy (500 samples)
# ✅ Saved rare_072.npy (500 samples)
# ✅ Saved rare_073.npy (500 samples)
# ✅ Saved rare_074.npy (500 samples)
# ✅ Saved rare_075.npy (500 samples)
# ✅ Saved rare_076.npy (500 samples)
# ✅ Saved rare_077.npy (500 samples)
# ✅ Saved rare_078.npy (500 samples)
# ✅ Saved rare_079.npy (500 samples)
# ✅ Saved rare_080.npy (500 samples)
# ✅ Saved rare_081.npy (500 samples)
# ✅ Saved rare_082.npy (500 samples)
# ✅ Saved rare_083.npy (500 samples)
# ✅ Saved rare_084.npy (500 samples)
# ✅ Saved rare_085.npy (500 samples)
# ✅ Saved rare_086.npy (500 samples)
# ✅ Saved rare_087.npy (500 samples)
# ✅ Saved rare_088.npy (500 samples)
# ✅ Saved rare_089.npy (500 samples)
# ✅ Saved rare_090.npy (500 samples)
# ✅ Saved rare_091.npy (500 samples)
# ✅ Saved rare_092.npy (500 samples)
# ✅ Saved rare_093.npy (500 samples)
# ✅ Saved rare_094.npy (500 samples)
# ✅ Saved rare_095.npy (500 samples)
# ✅ Saved rare_096.npy (500 samples)
# ✅ Saved rare_097.npy (500 samples)
# ✅ Saved rare_098.npy (500 samples)
# ✅ Saved rare_099.npy (500 samples)

# %%
import numpy as np
import os
epoch = 16000
def load_samples(label: str, total_samples: int, batch_size: int = 500, base_dir: str = '.'):
    """
    label: 'freq', 'rare', 'null'
    total_samples: 불러올 총 샘플 수
    batch_size: 한 파일에 저장된 샘플 수
    base_dir: npy 파일이 저장된 디렉토리
    """
    n_batches = total_samples // batch_size
    all_samples = []

    for i in range(n_batches):
        file_path = os.path.join(base_dir, f"{label}_batch/{label}_batch_{i:03d}.npy")
        if not os.path.exists(file_path):
            raise FileNotFoundError(f"파일 없음: {file_path}")
        batch = np.load(file_path)
        all_samples.append(batch)

    samples = np.vstack(all_samples)
    print(f"[{label}] 총 {samples.shape[0]}개 로드 완료.")
    return samples

# 샘플 5000개 로드
x_freq_5k = load_samples("freq", total_samples=50000)
x_rare_5k = load_samples("rare", total_samples=50000)

x_freq_5k = np.vstack([x_freq_5k, s])
x_rare_5k = np.vstack([x_rare_5k, s])

s_ = np.vstack([x_freq_5k, x_rare_5k, s])
# Out:
# [freq] 총 50000개 로드 완료.
# [rare] 총 50000개 로드 완료.

# %%
def energy_general_ising(seq, b, w):
    field_term = -np.dot(b, seq)
    interaction_term = -np.sum(np.triu(w, k=1) * np.outer(seq, seq))
    return field_term + interaction_term

def metropolis_sample(L, b, w, beta=1.0, n_steps=1000, seed=None):
    if seed is not None:
        np.random.seed(seed)

    seq = np.random.choice([-1, 1], size=L)
    local_field = b + np.dot(w, seq)

    for step in range(n_steps):
        i = np.random.randint(L)
        dE = 2 * seq[i] * local_field[i]

        if dE <= 0 or np.random.rand() < np.exp(-beta * dE):
            seq[i] *= -1
            local_field += 2 * w[:, i] * seq[i]

    return seq

def sample_general_ising(L, N, b, w, beta=1.0, n_steps=1000, n_jobs=10):
    from joblib import parallel_backend

    seeds = np.random.randint(0, 1e6, size=N)

    with parallel_backend('loky'):
        samples = Parallel(n_jobs=n_jobs)(
            delayed(metropolis_sample)(L, b, w, beta, n_steps, int(seeds[i]))
            for i in tqdm(range(N), desc="Sampling Ising states", unit="sample")
        )

    return np.array(samples)

def plot_energy_histogram_general(samples, b, w, color='cornflowerblue', bins = 30):
    energies = np.array([energy_general_ising(s, b, w) for s in samples])
    plt.hist(energies, bins=bins, density=True, color=color, edgecolor='black', alpha=0.6)
    plt.title(f"Ising Model Energy Histogram L = {L}")
    plt.xlabel("Energy")
    plt.ylabel("A.U.")
    plt.grid(True)

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def compute_energy(seq, b, w):
    field_term = -np.dot(b, seq)
    interaction_term = -np.sum(np.triu(w, k=1) * np.outer(seq, seq))
    return field_term + interaction_term

def estimate_f_epsilon(samples, b, w, epsilon):
    energies = np.array([compute_energy(s, b, w) for s in samples])
    ps = np.exp(-energies)
    ps_epsilon = ps ** (-1 + epsilon)
    weights = ps_epsilon / np.sum(ps_epsilon)
    return weights


def update_parameters(samples, b, w, epsilon, lr):
    n = samples.shape[1]
    weights = estimate_f_epsilon(samples, b, w, epsilon)

    mean_sigma = np.zeros(n)
    for s, wgt in zip(samples, weights):
        mean_sigma += wgt * s
    #mean_sigma = np.average(samples, axis=0, weights=weights)  # ⟨σ_i⟩_{f_ε}
    mean_sigma_sigma = np.zeros((n, n))
    for s, wgt in zip(samples, weights):
        #mean_sigma_sigma += wgt * np.einsum("i,j->ij", s, s)
        mean_sigma_sigma += wgt * np.outer(s, s)
    np.fill_diagonal(mean_sigma_sigma, 0)
    b_model = epsilon * b
    w_model = epsilon * w

    #print(np.linalg.norm(mean_sigma - b_model))
    
    # Gradient update
    b_new = b + lr * (mean_sigma - b_model)
    w_new = w + lr * (mean_sigma_sigma - w_model)
    
    return b_new, w_new

# === Example Usage ===
def train_erasure_machine(samples, n, epsilon=0.05, lr=0.1, epochs=100):
    b_temp = np.random.randn(n) * 0.01
    w_temp = np.random.randn(n, n) * 0.01
    w_temp = (w_temp + w_temp.T) / 2  # Make symmetric
    np.fill_diagonal(w_temp, 0)

    for epoch in range(epochs):
        b_temp, w_temp = update_parameters(samples, b_temp, w_temp, epsilon, lr)
        if epoch % 10 == 0:
            print(f"Epoch {epoch}: b norm = {np.linalg.norm(b_temp):.4f}, w norm = {np.linalg.norm(w_temp):.4f}")
    return b_temp, w_temp

# %%
L = 40
def mse(w, w_e, b, b_e) :
    LL = L + L*(L-1)/2
    b_error = np.sum((b_e - b)**2)/LL
    mask = np.triu(np.ones_like(w), k=1)
    w_diff = (w_e - w) * mask
    w_error = np.sum(w_diff**2)/LL
    return (b_error + w_error)

# %%
import torch
import numpy as np

def compute_energy_torch(samples, b, w):
    # energy = -b·σ - sum_{i<j} w_ij σ_i σ_j
    field_term = -torch.matmul(samples, b)
    interaction_term = -0.5 * torch.sum(samples @ w * samples, dim=1)
    return field_term + interaction_term

def estimate_f_epsilon_torch(samples, b, w, epsilon):
    with torch.no_grad():
        energies = compute_energy_torch(samples, b, w)
        ps = torch.exp(-energies)
        ps_epsilon = ps ** (-1 + epsilon)
        weights = ps_epsilon / ps_epsilon.sum()
    return weights

def update_parameters_torch(samples, b, w, epsilon, lr):
    weights = estimate_f_epsilon_torch(samples, b, w, epsilon)

    mean_sigma = torch.sum(weights[:, None] * samples, dim=0)

    outer = samples.unsqueeze(2) * samples.unsqueeze(1)  # shape: (N, L, L)
    weighted_outer = weights[:, None, None] * outer
    mean_sigma_sigma = torch.sum(weighted_outer, dim=0)
    mean_sigma_sigma.fill_diagonal_(0.0)

    b_model = epsilon * b
    w_model = epsilon * w

    b_new = b + lr * (mean_sigma - b_model)
    w_new = w + lr * (mean_sigma_sigma - w_model)

    return b_new, w_new

def train_erasure_machine_torch(samples_np, n, epsilon=0.05, lr=0.1, epochs=100, use_cuda=True):
    device = torch.device("cuda" if use_cuda and torch.cuda.is_available() else "cpu")
    samples = torch.tensor(samples_np, dtype=torch.float32, device=device)

    b = torch.randn(n, device=device) * 0.01
    w = torch.randn(n, n, device=device) * 0.01
    w = (w + w.T) / 2
    w.fill_diagonal_(0.0)

    for epoch in range(epochs):
        b, w = update_parameters_torch(samples, b, w, epsilon, lr)
        if epoch % 10 == 0:
            print(f"[GPU] Epoch {epoch}: b norm = {b.norm():.4f}, w norm = {w.norm():.4f}")
    return b.cpu().numpy(), w.cpu().numpy()

# %% [markdown]
# ### Augment data with 100K

# %%
x_freq_5k = load_samples("freq", total_samples=100000)
x_rare_5k = load_samples("rare", total_samples=100000)

x_freq_5k = np.vstack([x_freq_5k, s])
x_rare_5k = np.vstack([x_rare_5k, s])

s_ = np.vstack([x_freq_5k, x_rare_5k, s])
# Out:
# [freq] 총 100000개 로드 완료.
# [rare] 총 100000개 로드 완료.

# %%
b = np.load("ising_h.npy")
w = np.load("ising_J.npy")
def run_erasure_machine(samples, epsilon=0.7, lr=0.1, epochs=150):
    n = samples.shape[1]
    b_learned, w_learned = train_erasure_machine_torch(samples, n, epsilon=epsilon, lr=lr, epochs=epochs)
    return b_learned, w_learned

# Erasure Machine 학습
b_freq, w_freq = run_erasure_machine(x_freq_5k)
b_rare, w_rare = run_erasure_machine(x_rare_5k)
b_learned_s, w_learned_s = run_erasure_machine(s)
# Out:
# [GPU] Epoch 0: b norm = 0.3134, w norm = 1.1002
# [GPU] Epoch 10: b norm = 1.0966, w norm = 3.9227
# [GPU] Epoch 20: b norm = 1.3196, w norm = 4.6428
# [GPU] Epoch 30: b norm = 1.4114, w norm = 4.9110
# [GPU] Epoch 40: b norm = 1.4514, w norm = 5.0183
# [GPU] Epoch 50: b norm = 1.4691, w norm = 5.0623
# [GPU] Epoch 60: b norm = 1.4769, w norm = 5.0808
# [GPU] Epoch 70: b norm = 1.4805, w norm = 5.0885
# [GPU] Epoch 80: b norm = 1.4821, w norm = 5.0918
# [GPU] Epoch 90: b norm = 1.4828, w norm = 5.0933
# [GPU] Epoch 100: b norm = 1.4831, w norm = 5.0939
# [GPU] Epoch 110: b norm = 1.4833, w norm = 5.0941
# [GPU] Epoch 120: b norm = 1.4834, w norm = 5.0943
# [GPU] Epoch 130: b norm = 1.4834, w norm = 5.0943
# [GPU] Epoch 140: b norm = 1.4834, w norm = 5.0943
# [GPU] Epoch 0: b norm = 0.1297, w norm = 0.3861
# [GPU] Epoch 10: b norm = 0.7181, w norm = 1.9330
# [GPU] Epoch 20: b norm = 0.9297, w norm = 2.4878
# [GPU] Epoch 30: b norm = 1.0136, w norm = 2.6909
# [GPU] Epoch 40: b norm = 1.0485, w norm = 2.7673
# [GPU] Epoch 50: b norm = 1.0635, w norm = 2.7965
# [GPU] Epoch 60: b norm = 1.0700, w norm = 2.8079
# [GPU] Epoch 70: b norm = 1.0729, w norm = 2.8123
# [GPU] Epoch 80: b norm = 1.0741, w norm = 2.8141
# [GPU] Epoch 90: b norm = 1.0747, w norm = 2.8148
# [GPU] Epoch 100: b norm = 1.0750, w norm = 2.8150
# [GPU] Epoch 110: b norm = 1.0751, w norm = 2.8152
# [GPU] Epoch 120: b norm = 1.0751, w norm = 2.8152
# [GPU] Epoch 130: b norm = 1.0751, w norm = 2.8152
# [GPU] Epoch 140: b norm = 1.0752, w norm = 2.8152
# [GPU] Epoch 0: b norm = 0.2016, w norm = 0.6928
# [GPU] Epoch 10: b norm = 0.8866, w norm = 3.0537
# [GPU] Epoch 20: b norm = 1.1060, w norm = 3.8461
# [GPU] Epoch 30: b norm = 1.1967, w norm = 4.1665
# [GPU] Epoch 40: b norm = 1.2363, w norm = 4.3022
# [GPU] Epoch 50: b norm = 1.2538, w norm = 4.3609
# [GPU] Epoch 60: b norm = 1.2617, w norm = 4.3866
# [GPU] Epoch 70: b norm = 1.2653, w norm = 4.3979
# [GPU] Epoch 80: b norm = 1.2669, w norm = 4.4029
# [GPU] Epoch 90: b norm = 1.2676, w norm = 4.4052
# [GPU] Epoch 100: b norm = 1.2679, w norm = 4.4062
# [GPU] Epoch 110: b norm = 1.2681, w norm = 4.4066
# [GPU] Epoch 120: b norm = 1.2682, w norm = 4.4068
# [GPU] Epoch 130: b norm = 1.2682, w norm = 4.4069
# [GPU] Epoch 140: b norm = 1.2682, w norm = 4.4070

# %%
x = np.concatenate([b, w[np.triu_indices_from(w, k=1)]])
y = np.concatenate([b_freq, w_freq[np.triu_indices_from(w, k=1)]])
y2 = np.concatenate([b_rare, w_rare[np.triu_indices_from(w, k=1)]])
y_s = np.concatenate([b_learned_s, w_learned_s[np.triu_indices_from(w, k=1)]])

# %%
plt.figure(figsize=(6, 6))
plt.plot([-1, 1], [-1, 1], 'r--', label='y = x')
plt.xlim(-0.7, 0.7)
plt.ylim(-0.7, 0.7)
plt.scatter(x, y, label='Learned (Frequent+obs)', alpha=0.5, color='blue')
plt.scatter(x, y2, label='Learned (Rare+obs)', alpha=0.5, color='red')
plt.scatter(x, y_s, label='Learned (obs)', alpha=0.5, color='green')
plt.legend()
plt.show()

# %%
mse_freq = mse(w, w_freq, b, b_freq)
mse_rare = mse(w, w_rare, b, b_rare)
mse_s = mse(w, w_learned_s, b, b_learned_s)
print(f"MSE (Frequent): {mse_freq:.4f}")
print(f"MSE (Rare): {mse_rare:.4f}")
print(f"MSE (Learned All): {mse_s:.4f}")
# Out:
# MSE (Frequent): 0.0045
# MSE (Rare): 0.0042
# MSE (Learned All): 0.0022

# %% [markdown]
# ### Augment data with 50K

# %%
x_freq_5k = load_samples("freq", total_samples=50000)
x_rare_5k = load_samples("rare", total_samples=50000)

x_freq_5k = np.vstack([x_freq_5k, s])
x_rare_5k = np.vstack([x_rare_5k, s])

s_ = np.vstack([x_freq_5k, x_rare_5k, s])
# Out:
# [freq] 총 50000개 로드 완료.
# [rare] 총 50000개 로드 완료.

# %%
def run_erasure_machine(samples, epsilon=0.7, lr=0.1, epochs=150):
    n = samples.shape[1]
    b_learned, w_learned = train_erasure_machine_torch(samples, n, epsilon=epsilon, lr=lr, epochs=epochs)
    return b_learned, w_learned

# Erasure Machine 학습
b_freq, w_freq = run_erasure_machine(x_freq_5k)
b_rare, w_rare = run_erasure_machine(x_rare_5k)
b_learned_s, w_learned_s = run_erasure_machine(s)
# Out:
# [GPU] Epoch 0: b norm = 0.2815, w norm = 1.0588
# [GPU] Epoch 10: b norm = 1.0569, w norm = 3.7942
# [GPU] Epoch 20: b norm = 1.2798, w norm = 4.5172
# [GPU] Epoch 30: b norm = 1.3711, w norm = 4.7916
# [GPU] Epoch 40: b norm = 1.4107, w norm = 4.9023
# [GPU] Epoch 50: b norm = 1.4282, w norm = 4.9481
# [GPU] Epoch 60: b norm = 1.4360, w norm = 4.9673
# [GPU] Epoch 70: b norm = 1.4395, w norm = 4.9755
# [GPU] Epoch 80: b norm = 1.4411, w norm = 4.9790
# [GPU] Epoch 90: b norm = 1.4418, w norm = 4.9805
# [GPU] Epoch 100: b norm = 1.4421, w norm = 4.9811
# [GPU] Epoch 110: b norm = 1.4423, w norm = 4.9814
# [GPU] Epoch 120: b norm = 1.4423, w norm = 4.9815
# [GPU] Epoch 130: b norm = 1.4424, w norm = 4.9816
# [GPU] Epoch 140: b norm = 1.4424, w norm = 4.9816
# [GPU] Epoch 0: b norm = 0.1312, w norm = 0.3911
# [GPU] Epoch 10: b norm = 0.7161, w norm = 1.9718
# [GPU] Epoch 20: b norm = 0.9273, w norm = 2.5300
# [GPU] Epoch 30: b norm = 1.0112, w norm = 2.7340
# [GPU] Epoch 40: b norm = 1.0463, w norm = 2.8109
# [GPU] Epoch 50: b norm = 1.0613, w norm = 2.8404
# [GPU] Epoch 60: b norm = 1.0679, w norm = 2.8519
# [GPU] Epoch 70: b norm = 1.0708, w norm = 2.8564
# [GPU] Epoch 80: b norm = 1.0721, w norm = 2.8582
# [GPU] Epoch 90: b norm = 1.0727, w norm = 2.8590
# [GPU] Epoch 100: b norm = 1.0730, w norm = 2.8593
# [GPU] Epoch 110: b norm = 1.0731, w norm = 2.8594
# [GPU] Epoch 120: b norm = 1.0731, w norm = 2.8594
# [GPU] Epoch 130: b norm = 1.0732, w norm = 2.8595
# [GPU] Epoch 140: b norm = 1.0732, w norm = 2.8595
# [GPU] Epoch 0: b norm = 0.2174, w norm = 0.6946
# [GPU] Epoch 10: b norm = 0.8950, w norm = 3.0514
# [GPU] Epoch 20: b norm = 1.1096, w norm = 3.8449
# [GPU] Epoch 30: b norm = 1.1983, w norm = 4.1660
# [GPU] Epoch 40: b norm = 1.2370, w norm = 4.3020
# [GPU] Epoch 50: b norm = 1.2542, w norm = 4.3608
# [GPU] Epoch 60: b norm = 1.2619, w norm = 4.3865
# [GPU] Epoch 70: b norm = 1.2653, w norm = 4.3979
# [GPU] Epoch 80: b norm = 1.2669, w norm = 4.4029
# [GPU] Epoch 90: b norm = 1.2676, w norm = 4.4052
# [GPU] Epoch 100: b norm = 1.2679, w norm = 4.4062
# [GPU] Epoch 110: b norm = 1.2681, w norm = 4.4066
# [GPU] Epoch 120: b norm = 1.2682, w norm = 4.4068
# [GPU] Epoch 130: b norm = 1.2682, w norm = 4.4069
# [GPU] Epoch 140: b norm = 1.2682, w norm = 4.4070

# %%
x = np.concatenate([b, w[np.triu_indices_from(w, k=1)]])
y = np.concatenate([b_freq, w_freq[np.triu_indices_from(w, k=1)]])
y2 = np.concatenate([b_rare, w_rare[np.triu_indices_from(w, k=1)]])
y_s = np.concatenate([b_learned_s, w_learned_s[np.triu_indices_from(w, k=1)]])

# %%
plt.figure(figsize=(6, 6))
plt.plot([-1, 1], [-1, 1], 'r--', label='y = x')
plt.xlim(-0.7, 0.7)
plt.ylim(-0.7, 0.7)
plt.scatter(x, y, label='Learned (Frequent+obs)', alpha=0.5, color='blue')
plt.scatter(x, y2, label='Learned (Rare+obs)', alpha=0.5, color='red')
plt.scatter(x, y_s, label='Learned (obs)', alpha=0.5, color='green')
plt.legend()
plt.show()

# %%
mse_freq = mse(w, w_freq, b, b_freq)
mse_rare = mse(w, w_rare, b, b_rare)
mse_s = mse(w, w_learned_s, b, b_learned_s)
print(f"MSE (Frequent): {mse_freq:.4f}")
print(f"MSE (Rare): {mse_rare:.4f}")
print(f"MSE (Learned All): {mse_s:.4f}")
# Out:
# MSE (Frequent): 0.0040
# MSE (Rare): 0.0040
# MSE (Learned All): 0.0022

# %% [markdown]
# ### Augment data with 10K

# %%
x_freq_5k = load_samples("freq", total_samples=10000)
x_rare_5k = load_samples("rare", total_samples=10000)

x_freq_5k = np.vstack([x_freq_5k, s])
x_rare_5k = np.vstack([x_rare_5k, s])

s_ = np.vstack([x_freq_5k, x_rare_5k, s])
# Out:
# [freq] 총 10000개 로드 완료.
# [rare] 총 10000개 로드 완료.

# %%
def run_erasure_machine(samples, epsilon=0.7, lr=0.1, epochs=150):
    n = samples.shape[1]
    b_learned, w_learned = train_erasure_machine_torch(samples, n, epsilon=epsilon, lr=lr, epochs=epochs)
    return b_learned, w_learned

# Erasure Machine 학습
b_freq, w_freq = run_erasure_machine(x_freq_5k)
b_rare, w_rare = run_erasure_machine(x_rare_5k)
b_learned_s, w_learned_s = run_erasure_machine(s)
# Out:
# [GPU] Epoch 0: b norm = 0.2658, w norm = 0.9523
# [GPU] Epoch 10: b norm = 0.9746, w norm = 3.4311
# [GPU] Epoch 20: b norm = 1.1910, w norm = 4.1674
# [GPU] Epoch 30: b norm = 1.2807, w norm = 4.4569
# [GPU] Epoch 40: b norm = 1.3198, w norm = 4.5766
# [GPU] Epoch 50: b norm = 1.3371, w norm = 4.6272
# [GPU] Epoch 60: b norm = 1.3448, w norm = 4.6489
# [GPU] Epoch 70: b norm = 1.3483, w norm = 4.6583
# [GPU] Epoch 80: b norm = 1.3498, w norm = 4.6624
# [GPU] Epoch 90: b norm = 1.3506, w norm = 4.6642
# [GPU] Epoch 100: b norm = 1.3509, w norm = 4.6650
# [GPU] Epoch 110: b norm = 1.3510, w norm = 4.6653
# [GPU] Epoch 120: b norm = 1.3511, w norm = 4.6655
# [GPU] Epoch 130: b norm = 1.3511, w norm = 4.6656
# [GPU] Epoch 140: b norm = 1.3511, w norm = 4.6656
# [GPU] Epoch 0: b norm = 0.1475, w norm = 0.4453
# [GPU] Epoch 10: b norm = 0.7395, w norm = 2.1414
# [GPU] Epoch 20: b norm = 0.9473, w norm = 2.7128
# [GPU] Epoch 30: b norm = 1.0314, w norm = 2.9245
# [GPU] Epoch 40: b norm = 1.0672, w norm = 3.0062
# [GPU] Epoch 50: b norm = 1.0828, w norm = 3.0386
# [GPU] Epoch 60: b norm = 1.0897, w norm = 3.0516
# [GPU] Epoch 70: b norm = 1.0928, w norm = 3.0569
# [GPU] Epoch 80: b norm = 1.0941, w norm = 3.0590
# [GPU] Epoch 90: b norm = 1.0948, w norm = 3.0600
# [GPU] Epoch 100: b norm = 1.0950, w norm = 3.0603
# [GPU] Epoch 110: b norm = 1.0952, w norm = 3.0605
# [GPU] Epoch 120: b norm = 1.0952, w norm = 3.0606
# [GPU] Epoch 130: b norm = 1.0952, w norm = 3.0606
# [GPU] Epoch 140: b norm = 1.0953, w norm = 3.0606
# [GPU] Epoch 0: b norm = 0.1971, w norm = 0.6941
# [GPU] Epoch 10: b norm = 0.8884, w norm = 3.0531
# [GPU] Epoch 20: b norm = 1.1075, w norm = 3.8457
# [GPU] Epoch 30: b norm = 1.1976, w norm = 4.1663
# [GPU] Epoch 40: b norm = 1.2367, w norm = 4.3022
# [GPU] Epoch 50: b norm = 1.2541, w norm = 4.3609
# [GPU] Epoch 60: b norm = 1.2618, w norm = 4.3866
# [GPU] Epoch 70: b norm = 1.2653, w norm = 4.3979
# [GPU] Epoch 80: b norm = 1.2669, w norm = 4.4029
# [GPU] Epoch 90: b norm = 1.2676, w norm = 4.4052
# [GPU] Epoch 100: b norm = 1.2679, w norm = 4.4062
# [GPU] Epoch 110: b norm = 1.2681, w norm = 4.4066
# [GPU] Epoch 120: b norm = 1.2682, w norm = 4.4068
# [GPU] Epoch 130: b norm = 1.2682, w norm = 4.4069
# [GPU] Epoch 140: b norm = 1.2682, w norm = 4.4070

# %%
x = np.concatenate([b, w[np.triu_indices_from(w, k=1)]])
y = np.concatenate([b_freq, w_freq[np.triu_indices_from(w, k=1)]])
y2 = np.concatenate([b_rare, w_rare[np.triu_indices_from(w, k=1)]])
y_s = np.concatenate([b_learned_s, w_learned_s[np.triu_indices_from(w, k=1)]])

plt.figure(figsize=(6, 6))
plt.plot([-1, 1], [-1, 1], 'r--', label='y = x')
plt.xlim(-0.7, 0.7)
plt.ylim(-0.7, 0.7)
plt.scatter(x, y, label='Learned (Frequent+obs)', alpha=0.5, color='blue')
plt.scatter(x, y2, label='Learned (Rare+obs)', alpha=0.5, color='red')
plt.scatter(x, y_s, label='Learned (obs)', alpha=0.5, color='green')
plt.legend()
plt.show()

# %%
mse_freq = mse(w, w_freq, b, b_freq)
mse_rare = mse(w, w_rare, b, b_rare)
mse_s = mse(w, w_learned_s, b, b_learned_s)
print(f"MSE (Frequent): {mse_freq:.4f}")
print(f"MSE (Rare): {mse_rare:.4f}")
print(f"MSE (Learned All): {mse_s:.4f}")
# Out:
# MSE (Frequent): 0.0029
# MSE (Rare): 0.0035
# MSE (Learned All): 0.0022

# %% [markdown]
# ### Augment data with 5K

# %%
x_freq_5k = load_samples("freq", total_samples=5000)
x_rare_5k = load_samples("rare", total_samples=5000)

x_freq_5k = np.vstack([x_freq_5k, s])
x_rare_5k = np.vstack([x_rare_5k, s])

s_ = np.vstack([x_freq_5k, x_rare_5k, s])
# Out:
# [freq] 총 5000개 로드 완료.
# [rare] 총 5000개 로드 완료.

# %%
def run_erasure_machine(samples, epsilon=0.7, lr=0.1, epochs=150):
    n = samples.shape[1]
    b_learned, w_learned = train_erasure_machine_torch(samples, n, epsilon=epsilon, lr=lr, epochs=epochs)
    return b_learned, w_learned

# Erasure Machine 학습
b_freq, w_freq = run_erasure_machine(x_freq_5k)
b_rare, w_rare = run_erasure_machine(x_rare_5k)
b_learned_s, w_learned_s = run_erasure_machine(s)
# Out:
# [GPU] Epoch 0: b norm = 0.2495, w norm = 0.8920
# [GPU] Epoch 10: b norm = 0.9428, w norm = 3.2993
# [GPU] Epoch 20: b norm = 1.1588, w norm = 4.0498
# [GPU] Epoch 30: b norm = 1.2479, w norm = 4.3491
# [GPU] Epoch 40: b norm = 1.2866, w norm = 4.4744
# [GPU] Epoch 50: b norm = 1.3037, w norm = 4.5279
# [GPU] Epoch 60: b norm = 1.3114, w norm = 4.5511
# [GPU] Epoch 70: b norm = 1.3148, w norm = 4.5612
# [GPU] Epoch 80: b norm = 1.3163, w norm = 4.5657
# [GPU] Epoch 90: b norm = 1.3170, w norm = 4.5676
# [GPU] Epoch 100: b norm = 1.3173, w norm = 4.5685
# [GPU] Epoch 110: b norm = 1.3175, w norm = 4.5689
# [GPU] Epoch 120: b norm = 1.3176, w norm = 4.5691
# [GPU] Epoch 130: b norm = 1.3176, w norm = 4.5692
# [GPU] Epoch 140: b norm = 1.3176, w norm = 4.5692
# [GPU] Epoch 0: b norm = 0.1606, w norm = 0.4947
# [GPU] Epoch 10: b norm = 0.7583, w norm = 2.2746
# [GPU] Epoch 20: b norm = 0.9650, w norm = 2.8542
# [GPU] Epoch 30: b norm = 1.0493, w norm = 3.0708
# [GPU] Epoch 40: b norm = 1.0853, w norm = 3.1558
# [GPU] Epoch 50: b norm = 1.1010, w norm = 3.1901
# [GPU] Epoch 60: b norm = 1.1080, w norm = 3.2042
# [GPU] Epoch 70: b norm = 1.1111, w norm = 3.2100
# [GPU] Epoch 80: b norm = 1.1125, w norm = 3.2125
# [GPU] Epoch 90: b norm = 1.1131, w norm = 3.2135
# [GPU] Epoch 100: b norm = 1.1134, w norm = 3.2140
# [GPU] Epoch 110: b norm = 1.1135, w norm = 3.2141
# [GPU] Epoch 120: b norm = 1.1136, w norm = 3.2142
# [GPU] Epoch 130: b norm = 1.1136, w norm = 3.2143
# [GPU] Epoch 140: b norm = 1.1136, w norm = 3.2143
# [GPU] Epoch 0: b norm = 0.2021, w norm = 0.6920
# [GPU] Epoch 10: b norm = 0.8875, w norm = 3.0523
# [GPU] Epoch 20: b norm = 1.1066, w norm = 3.8454
# [GPU] Epoch 30: b norm = 1.1970, w norm = 4.1662
# [GPU] Epoch 40: b norm = 1.2364, w norm = 4.3021
# [GPU] Epoch 50: b norm = 1.2539, w norm = 4.3608
# [GPU] Epoch 60: b norm = 1.2618, w norm = 4.3865
# [GPU] Epoch 70: b norm = 1.2653, w norm = 4.3979
# [GPU] Epoch 80: b norm = 1.2669, w norm = 4.4029
# [GPU] Epoch 90: b norm = 1.2676, w norm = 4.4052
# [GPU] Epoch 100: b norm = 1.2679, w norm = 4.4062
# [GPU] Epoch 110: b norm = 1.2681, w norm = 4.4066
# [GPU] Epoch 120: b norm = 1.2682, w norm = 4.4068
# [GPU] Epoch 130: b norm = 1.2682, w norm = 4.4069
# [GPU] Epoch 140: b norm = 1.2682, w norm = 4.4070

# %%
x = np.concatenate([b, w[np.triu_indices_from(w, k=1)]])
y = np.concatenate([b_freq, w_freq[np.triu_indices_from(w, k=1)]])
y2 = np.concatenate([b_rare, w_rare[np.triu_indices_from(w, k=1)]])
y_s = np.concatenate([b_learned_s, w_learned_s[np.triu_indices_from(w, k=1)]])

plt.figure(figsize=(6, 6))
plt.plot([-1, 1], [-1, 1], 'r--', label='y = x')
plt.xlim(-0.7, 0.7)
plt.ylim(-0.7, 0.7)
plt.scatter(x, y, label='Learned (Frequent+obs)', alpha=0.5, color='blue')
plt.scatter(x, y2, label='Learned (Rare+obs)', alpha=0.5, color='red')
plt.scatter(x, y_s, label='Learned (obs)', alpha=0.5, color='green')
plt.legend()
plt.show()

# %%
mse_freq = mse(w, w_freq, b, b_freq)
mse_rare = mse(w, w_rare, b, b_rare)
mse_s = mse(w, w_learned_s, b, b_learned_s)
print(f"MSE (Frequent): {mse_freq:.4f}")
print(f"MSE (Rare): {mse_rare:.4f}")
print(f"MSE (Learned All): {mse_s:.4f}")
# Out:
# MSE (Frequent): 0.0026
# MSE (Rare): 0.0031
# MSE (Learned All): 0.0022
