# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset
import matplotlib.pyplot as plt
from tqdm import tqdm
from joblib import Parallel, delayed
from time import perf_counter
from functools import partial
import random
from numba import jit
import scipy as sp

os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

# %%
b = np.load("ising_h.npy")
w = np.load("ising_J.npy")
s = np.load("ising_samples.npy")

# %%
import math
class SinusoidalTimeEmbedding(nn.Module):
    def __init__(self, dim):
        super().__init__()
        self.dim = dim

    def forward(self, t):
        half_dim = self.dim // 2
        emb = math.log(10000) / (half_dim - 1)
        emb = torch.exp(torch.arange(half_dim, device=t.device) * -emb)
        emb = t[:, None] * emb[None, :]
        emb = torch.cat([torch.sin(emb), torch.cos(emb)], dim=-1)
        return emb

# -------------------------------
# 2️Diffusion MLP (논문 구조)
# -------------------------------
class DiffusionMLP(nn.Module):
    def __init__(self, input_dim=40):
        super().__init__()
        time_embed_dim = 128
        self.time_embed = SinusoidalTimeEmbedding(time_embed_dim)

        self.enc1 = nn.Linear(input_dim + time_embed_dim, 128)
        self.enc2 = nn.Linear(128, 256)
        self.enc3 = nn.Linear(256, 512)

        self.dec1 = nn.Linear(512, 512)
        self.dec2 = nn.Linear(512, 512)
        self.dec3 = nn.Linear(512, 256)
        self.dec4 = nn.Linear(256, 128)

        self.out = nn.Linear(128, input_dim)
        self.act = nn.GELU()

    def forward(self, x, t):
        t_embed = self.time_embed(t).to(x.dtype)
        h = torch.cat([x, t_embed], dim=1)

        h1 = self.act(self.enc1(h))
        h2 = self.act(self.enc2(h1))
        h3 = self.act(self.enc3(h2))

        d1 = self.act(self.dec1(h3))
        d2 = self.act(self.dec2(d1) + d1)
        d3 = self.act(self.dec3(d2) + h2)
        d4 = self.act(self.dec4(d3) + h1)

        return self.out(d4)

# -------------------------------
# 3 DDPM Schedules
# -------------------------------
def ddpm_schedules(beta_start, beta_end, n_T):
    betas = torch.linspace(beta_start, beta_end, n_T)
    alphas = 1. - betas
    alphabar = torch.cumprod(alphas, dim=0)

    return {
        'beta_t': betas,
        'alpha_t': alphas,
        'alphabar_t': alphabar,
        'sqrtab': torch.sqrt(alphabar),
        'sqrtmab': torch.sqrt(1 - alphabar),
        'oneover_sqrta': 1. / torch.sqrt(alphas),
        'bt_over_sqrtmab': betas / torch.sqrt(1 - alphabar),
        'sqrt_beta_t': torch.sqrt(betas),
    }

# -------------------------------
# 4️ DDPM Class (Device 문제 해결)
# -------------------------------
class DDPM(nn.Module):
    def __init__(self, nn_model, betas, n_T, device):
        super().__init__()
        self.nn_model = nn_model
        self.n_T = n_T
        self.device = device

        for k, v in ddpm_schedules(betas[0], betas[1], n_T).items():
            self.register_buffer(k, v)

        self.to(device)  

    def forward(self, x):
        batch_size = x.size(0)
        t = torch.randint(1, self.n_T+1, (batch_size,), device=x.device).float()

        sqrtab_t = self.sqrtab[t.long()-1].view(batch_size, 1)
        sqrtmab_t = self.sqrtmab[t.long()-1].view(batch_size, 1)

        epsilon = torch.randn_like(x)
        x_t = sqrtab_t * x + sqrtmab_t * epsilon

        pred_epsilon = self.nn_model(x_t, t)
        loss = F.mse_loss(pred_epsilon, epsilon)
        return loss

    def sample(self, n_sample, size):
        x = torch.randn(n_sample, size).to(self.device)
        x_seq = []

        for t in reversed(range(1, self.n_T+1)):
            t_batch = torch.full((n_sample,), t, device=self.device).float()
            epsilon_pred = self.nn_model(x, t_batch)

            mu = self.oneover_sqrta[t-1] * (x - self.bt_over_sqrtmab[t-1] * epsilon_pred)
            sigma = self.sqrt_beta_t[t-1]

            z = torch.randn_like(x) if t > 1 else torch.zeros_like(x)
            x = mu + sigma * z

            if t % (self.n_T // 10) == 0 or t == 1:
                x_seq.append(x.detach().cpu().numpy())

        return x, np.array(x_seq)


# ------------------------------
# 5. Training Loop & 샘플링
# ------------------------------
# 모델 인스턴스 생성 (구조 동일해야 함!)
device = 'cuda' if torch.cuda.is_available() else 'cpu'


n_sample_per_batch = 5000
n_batches = 10  # 1000 * 100 = 100,000
N = 40
for epoch in range(1, 50):
    real_epoch = epoch *1000
    model = DiffusionMLP(input_dim=40)
    ddpm = DDPM(model, betas=(0.0001, 0.02), n_T=1000, device=device)
    model.load_state_dict(torch.load(f"final/finalmodel_epoch_{real_epoch-1}.pth"))
    model.eval() 
    for batch_idx in range(n_batches):
        with torch.no_grad():  # 추가!

            x_diff, _ = ddpm.sample(n_sample_per_batch, size=40)
            x_diff = np.sign(x_diff.cpu().numpy())

            os.makedirs(f"final/final_sample_{real_epoch}/", exist_ok=True)
            np.save(f"final/final_sample_{real_epoch}/{batch_idx+10:03d}.npy", x_diff)

        torch.cuda.empty_cache()  # 추가: 메모리 해제!
# Out:
# /tmp/ipykernel_94054/3914376892.py:133: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f"final/finalmodel_epoch_{real_epoch-1}.pth"))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[64], line 138
#     135 for batch_idx in range(n_batches):
#     136     with torch.no_grad():  # 추가!
# --> 138         x_diff, _ = ddpm.sample(n_sample_per_batch, size=40)
#     139         x_diff = np.sign(x_diff.cpu().numpy())
#     141         os.makedirs(f"final/final_sample_{real_epoch}/", exist_ok=True)
#
# Cell In[64], line 114, in DDPM.sample(self, n_sample, size)
#     111     x = mu + sigma * z
#     113     if t % (self.n_T // 10) == 0 or t == 1:
# --> 114         x_seq.append(x.detach().cpu().numpy())
#     116 return x, np.array(x_seq)
#
# KeyboardInterrupt:

# %%
import numpy as np
import os
epoch = 50000
def load_samples( total_samples: int,epoch :int, batch_size: int = 5000, base_dir: str = '.'):
    """
    label: 'freq', 'rare', 'null'
    total_samples: 불러올 총 샘플 수
    batch_size: 한 파일에 저장된 샘플 수
    base_dir: npy 파일이 저장된 디렉토리
    """
    n_batches = total_samples // batch_size
    all_samples = []

    file_path = os.path.join(base_dir, f"final/ddpm_samples_epoch_{epoch}.npy")
    if not os.path.exists(file_path):
        raise FileNotFoundError(f"파일 없음: {file_path}")
    batch = np.load(file_path)
    all_samples.append(batch)

    samples = np.vstack(all_samples)
    return samples


def load_multi_samples(name : int, total_samples: int, batch_size: int = 5000, base_dir: str = '.'):
    """
    label: 'freq', 'rare', 'null'
    total_samples: 불러올 총 샘플 수
    batch_size: 한 파일에 저장된 샘플 수
    base_dir: npy 파일이 저장된 디렉토리
    """
    n_batches = total_samples // batch_size
    all_samples = []

    for i in range(n_batches):
        file_path = os.path.join(base_dir, f"final/final_sample_{name}/{i:03d}.npy")
        if not os.path.exists(file_path):
            raise FileNotFoundError(f"파일 없음: {file_path}")
        batch = np.load(file_path)
        all_samples.append(batch)

    samples = np.vstack(all_samples)
    return samples

# %%
x =load_multi_samples(name = 10000, batch_size=5000, total_samples=50000)
x.shape
# Out:
# (50000, 40)

# %%
def energy_general_ising(seq, b, w):
    field_term = -np.dot(b, seq)
    interaction_term = -np.sum(np.triu(w, k=1) * np.outer(seq, seq))
    return field_term + interaction_term

def metropolis_sample(L, b, w, beta=1.0, n_steps=1000, seed=None):
    if seed is not None:
        np.random.seed(seed)

    seq = np.random.choice([-1, 1], size=L)
    local_field = b + np.dot(w, seq)

    for step in range(n_steps):
        i = np.random.randint(L)
        dE = 2 * seq[i] * local_field[i]

        if dE <= 0 or np.random.rand() < np.exp(-beta * dE):
            seq[i] *= -1
            local_field += 2 * w[:, i] * seq[i]

    return seq

def sample_general_ising(L, N, b, w, beta=1.0, n_steps=1000, n_jobs=10):
    from joblib import parallel_backend

    seeds = np.random.randint(0, 1e6, size=N)

    with parallel_backend('loky'):
        samples = Parallel(n_jobs=n_jobs)(
            delayed(metropolis_sample)(L, b, w, beta, n_steps, int(seeds[i]))
            for i in tqdm(range(N), desc="Sampling Ising states", unit="sample")
        )

    return np.array(samples)

def plot_energy_histogram_general(samples, b, w, color='cornflowerblue', bins = 30):
    energies = np.array([energy_general_ising(s, b, w) for s in samples])
    plt.hist(energies, bins=bins, density=True, color=color, edgecolor='black', alpha=0.6)
    plt.title(f"Ising Model Energy Histogram L = {L}")
    plt.xlabel("Energy")
    plt.ylabel("A.U.")
    plt.grid(True)

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def compute_energy(seq, b, w):
    field_term = -np.dot(b, seq)
    interaction_term = -np.sum(np.triu(w, k=1) * np.outer(seq, seq))
    return field_term + interaction_term

def estimate_f_epsilon(samples, b, w, epsilon):
    energies = np.array([compute_energy(s, b, w) for s in samples])
    ps = np.exp(-energies)
    ps_epsilon = ps ** (-1 + epsilon)
    weights = ps_epsilon / np.sum(ps_epsilon)
    return weights


def update_parameters(samples, b, w, epsilon, lr):
    n = samples.shape[1]
    weights = estimate_f_epsilon(samples, b, w, epsilon)

    mean_sigma = np.zeros(n)
    for s, wgt in zip(samples, weights):
        mean_sigma += wgt * s
    #mean_sigma = np.average(samples, axis=0, weights=weights)  # ⟨σ_i⟩_{f_ε}
    mean_sigma_sigma = np.zeros((n, n))
    for s, wgt in zip(samples, weights):
        #mean_sigma_sigma += wgt * np.einsum("i,j->ij", s, s)
        mean_sigma_sigma += wgt * np.outer(s, s)
    np.fill_diagonal(mean_sigma_sigma, 0)
    b_model = epsilon * b
    w_model = epsilon * w

    #print(np.linalg.norm(mean_sigma - b_model))
    
    # Gradient update
    b_new = b + lr * (mean_sigma - b_model)
    w_new = w + lr * (mean_sigma_sigma - w_model)
    
    return b_new, w_new

# === Example Usage ===
def train_erasure_machine(samples, n, epsilon=0.05, lr=0.1, epochs=100):
    b_temp = np.random.randn(n) * 0.01
    w_temp = np.random.randn(n, n) * 0.01
    w_temp = (w_temp + w_temp.T) / 2  # Make symmetric
    np.fill_diagonal(w_temp, 0)

    for epoch in range(epochs):
        b_temp, w_temp = update_parameters(samples, b_temp, w_temp, epsilon, lr)
        if epoch % 10 == 0:
            print(f"Epoch {epoch}: b norm = {np.linalg.norm(b_temp):.4f}, w norm = {np.linalg.norm(w_temp):.4f}")
    return b_temp, w_temp

L = 40
def mse(w, w_e, b, b_e) :
    LL = L + L*(L-1)/2
    b_error = np.sum((b_e - b)**2)/LL
    mask = np.triu(np.ones_like(w), k=1)
    w_diff = (w_e - w) * mask
    w_error = np.sum(w_diff**2)/LL
    return (b_error + w_error)

# %%
import torch
import numpy as np

def compute_energy_torch(samples, b, w):
    # energy = -b·σ - sum_{i<j} w_ij σ_i σ_j
    field_term = -torch.matmul(samples, b)
    interaction_term = -0.5 * torch.sum(samples @ w * samples, dim=1)
    return field_term + interaction_term

def estimate_f_epsilon_torch(samples, b, w, epsilon):
    with torch.no_grad():
        energies = compute_energy_torch(samples, b, w)
        ps = torch.exp(-energies)
        ps_epsilon = ps ** (-1 + epsilon)
        weights = ps_epsilon / ps_epsilon.sum()
    return weights

def update_parameters_torch(samples, b, w, epsilon, lr):
    weights = estimate_f_epsilon_torch(samples, b, w, epsilon)

    mean_sigma = torch.sum(weights[:, None] * samples, dim=0)

    outer = samples.unsqueeze(2) * samples.unsqueeze(1)  # shape: (N, L, L)
    weighted_outer = weights[:, None, None] * outer
    mean_sigma_sigma = torch.sum(weighted_outer, dim=0)
    mean_sigma_sigma.fill_diagonal_(0.0)

    b_model = epsilon * b
    w_model = epsilon * w

    b_new = b + lr * (mean_sigma - b_model)
    w_new = w + lr * (mean_sigma_sigma - w_model)

    return b_new, w_new

def train_erasure_machine_torch(samples_np, n, epsilon=0.05, lr=0.1, epochs=100, use_cuda=True):
    device = torch.device("cuda" if use_cuda and torch.cuda.is_available() else "cpu")
    samples = torch.tensor(samples_np, dtype=torch.float32, device=device)

    b = torch.randn(n, device=device) * 0.01
    w = torch.randn(n, n, device=device) * 0.01
    w = (w + w.T) / 2
    w.fill_diagonal_(0.0)

    for epoch in range(epochs):
        b, w = update_parameters_torch(samples, b, w, epsilon, lr)
        if epoch % 10 == 0:
            print(f"[GPU] Epoch {epoch}: b norm = {b.norm():.4f}, w norm = {w.norm():.4f}")
    return b.cpu().numpy(), w.cpu().numpy()

# %%
# MCMC 샘플 (s_tensor)와 DataLoader는 이미 준비됨

def compute_energy_(seq, b, w):
    field_term = -np.dot(b, seq)
    interaction_term = -np.sum(np.triu(w, k=1) * np.outer(seq, seq))
    return field_term + interaction_term

def plot_energy_histogram(E_mcmc, E_diff_cond, E_diff_cond2, E_diff_null, num):
    # 디렉토리 생성 (없으면)
    save_dir="figures"
    filename=f"energy_histogram_{num}.png"
    os.makedirs(save_dir, exist_ok=True)
    
    plt.figure(figsize=(8,6))
    plt.hist(E_mcmc, bins=50, alpha=0.5, label='MCMC', density=True)
    plt.hist(E_diff_cond, bins=50, alpha=0.5, label='Diffusion (freq)', density=True)
    plt.hist(E_diff_cond2, bins=50, alpha=0.5, label='Diffusion (rare)', density=True)
    plt.hist(E_diff_null, bins=50, alpha=0.5, label='Diffusion (uncond)', density=True)
    plt.xlabel("Energy")
    plt.ylabel("Density")
    plt.legend()
    
    # 저장
    save_path = os.path.join(save_dir, filename)
    plt.savefig(save_path, dpi=300)
    plt.close()  # 메모리 해제

    print(f"✅ Histogram saved at: {save_path}")

device = 'cuda' if torch.cuda.is_available() else 'cpu'
L, N = s.shape
h = b
J = w
energies = np.array([-np.dot(s[i], h) - np.dot(s[i], J @ s[i]) for i in range(L)])

fig, axs = plt.subplots(1, 2, figsize=(12, 5))

# --- 1. 에너지 분포 ---
axs[0].hist(energies, bins=50, color='lightcoral', alpha=0.7)
axs[0].set_title("Energy Distribution")
axs[0].set_xlabel("Energy E(σ)")
axs[0].set_ylabel("Count")
axs[0].grid(True)

energies_diff = np.array([-np.dot(x[i], h) - np.dot(x[i], J @ x[i]) for i in range(x.shape[0])])

# --- 2. 에너지 분포 (Diffusion) ---
axs[1].hist(energies_diff, bins=50, color='cornflowerblue', alpha=0.7)  
axs[1].set_title("Energy Distribution (Diffusion)")
axs[1].set_xlabel("Energy E(σ)")
axs[1].set_ylabel("Count")
axs[1].grid(True)

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 5))

# --- 1. 에너지 분포 (겹쳐서 표시, 정규화됨) ---
axs[0].hist(energies, bins=50, color='lightcoral', alpha=0.5, label='MCMC', density=True)
axs[0].hist(energies_diff, bins=50, color='cornflowerblue', alpha=0.5, label='Diffusion', density=True)
axs[0].set_title("Energy Distribution Comparison (Normalized)")
axs[0].set_xlabel("Energy E(σ)")
axs[0].set_ylabel("Density")
axs[0].legend()
axs[0].grid(True)

# --- 2. 에너지 분포 (Diffusion만, 정규화됨) ---
axs[1].hist(energies_diff, bins=50, color='cornflowerblue', alpha=0.7, density=True)
axs[1].set_title("Energy Distribution (Diffusion, Normalized)")
axs[1].set_xlabel("Energy E(σ)")
axs[1].set_ylabel("Density")
axs[1].grid(True)

plt.tight_layout()
plt.show()

# %%
N = 40
b_s, w_s = train_erasure_machine(s, N, epsilon=0.84, lr=0.1, epochs=150)
b_s_1, w_s_1 = train_erasure_machine(s, N, epsilon=0.7, lr=0.1, epochs=150)
mse_new = mse(w, w_s,b,b_s)
mse_new_1 = mse(w, w_s_1,b,b_s_1)
print(f"New MSE: {mse_new:.4f}")
print(f"New MSE: {mse_new_1:.4f}")
# Out:
# Epoch 0: b norm = 0.2138, w norm = 0.7079
# Epoch 10: b norm = 0.9890, w norm = 3.3034
# Epoch 20: b norm = 1.1972, w norm = 4.0486
# Epoch 30: b norm = 1.2689, w norm = 4.3034
# Epoch 40: b norm = 1.2955, w norm = 4.3949
# Epoch 50: b norm = 1.3057, w norm = 4.4286
# Epoch 60: b norm = 1.3096, w norm = 4.4412
# Epoch 70: b norm = 1.3112, w norm = 4.4460
# Epoch 80: b norm = 1.3118, w norm = 4.4478
# Epoch 90: b norm = 1.3120, w norm = 4.4485
# Epoch 100: b norm = 1.3121, w norm = 4.4488
# Epoch 110: b norm = 1.3122, w norm = 4.4489
# Epoch 120: b norm = 1.3122, w norm = 4.4489
# Epoch 130: b norm = 1.3122, w norm = 4.4490
# Epoch 140: b norm = 1.3122, w norm = 4.4490
# Epoch 0: b norm = 0.2093, w norm = 0.6859
# Epoch 10: b norm = 0.8923, w norm = 3.0501
# Epoch 20: b norm = 1.1086, w norm = 3.8445
# Epoch 30: b norm = 1.1979, w norm = 4.1658
# Epoch 40: b norm = 1.2368, w norm = 4.3019
# Epoch 50: b norm = 1.2541, w norm = 4.3608
# Epoch 60: b norm = 1.2618, w norm = 4.3865
# Epoch 70: b norm = 1.2653, w norm = 4.3979
# Epoch 80: b norm = 1.2669, w norm = 4.4029
# Epoch 90: b norm = 1.2676, w norm = 4.4052
# Epoch 100: b norm = 1.2679, w norm = 4.4062
# Epoch 110: b norm = 1.2681, w norm = 4.4066
# Epoch 120: b norm = 1.2682, w norm = 4.4068
# Epoch 130: b norm = 1.2682, w norm = 4.4069
# Epoch 140: b norm = 1.2682, w norm = 4.4070
# New MSE: 0.0032
# New MSE: 0.0022

# %%
mse_new_1
# Out:
# 0.002205060787758071

# %%
b_list = []
w_list = []

b_list_1 = []
w_list_1 = []

mse_list = []
mse_list_1 = []
for epoch in range(1,50):
    real_epoch = epoch * 1000
    x_= load_multi_samples(name = real_epoch, batch_size=5000, total_samples=50000)
    b_in, w_in = train_erasure_machine_torch(x_, N, epsilon=0.84, lr=0.1, epochs=150)
    b_in_1, w_in_1 = train_erasure_machine_torch(x_, N, epsilon=0.7, lr=0.1, epochs=150)

    b_list.append(b_in)
    w_list.append(w_in)
    b_list_1.append(b_in_1)
    w_list_1.append(w_in_1)

    mse_in = mse(w, w_in, b, b_in)
    mse_in_1 = mse(w, w_in_1, b, b_in_1)
    mse_list.append(mse_in)
    mse_list_1.append(mse_in_1)

np.save(f"b_list_50K.npy", np.array(b_list))
np.save(f"w_list_50K.npy", np.array(w_list))
np.save(f"b_list_1_50K.npy", np.array(b_list_1))
np.save(f"w_list_1_50K.npy", np.array(w_list_1))
np.save(f"mse_list_50K.npy", np.array(mse_list))
np.save(f"mse_list_1_50K.npy", np.array(mse_list_1))
# Out:
# [GPU] Epoch 0: b norm = 0.2841, w norm = 0.9276
# [GPU] Epoch 10: b norm = 1.2783, w norm = 3.3534
# [GPU] Epoch 20: b norm = 1.5311, w norm = 3.8725
# [GPU] Epoch 30: b norm = 1.6187, w norm = 4.0317
# [GPU] Epoch 40: b norm = 1.6515, w norm = 4.0840
# [GPU] Epoch 50: b norm = 1.6643, w norm = 4.1017
# [GPU] Epoch 60: b norm = 1.6693, w norm = 4.1078
# [GPU] Epoch 70: b norm = 1.6713, w norm = 4.1099
# [GPU] Epoch 80: b norm = 1.6720, w norm = 4.1107
# [GPU] Epoch 90: b norm = 1.6724, w norm = 4.1110
# [GPU] Epoch 100: b norm = 1.6725, w norm = 4.1111
# [GPU] Epoch 110: b norm = 1.6725, w norm = 4.1111
# [GPU] Epoch 120: b norm = 1.6726, w norm = 4.1111
# [GPU] Epoch 130: b norm = 1.6726, w norm = 4.1111
# [GPU] Epoch 140: b norm = 1.6726, w norm = 4.1111
# [GPU] Epoch 0: b norm = 0.2869, w norm = 0.9312
# [GPU] Epoch 10: b norm = 1.1214, w norm = 2.8392
# [GPU] Epoch 20: b norm = 1.3712, w norm = 3.3421
# [GPU] Epoch 30: b norm = 1.4717, w norm = 3.5151
# [GPU] Epoch 40: b norm = 1.5152, w norm = 3.5781
# [GPU] Epoch 50: b norm = 1.5345, w norm = 3.6018
# [GPU] Epoch 60: b norm = 1.5432, w norm = 3.6108
# [GPU] Epoch 70: b norm = 1.5472, w norm = 3.6143
# [GPU] Epoch 80: b norm = 1.5490, w norm = 3.6157
# [GPU] Epoch 90: b norm = 1.5498, w norm = 3.6163
# [GPU] Epoch 100: b norm = 1.5502, w norm = 3.6165
# [GPU] Epoch 110: b norm = 1.5504, w norm = 3.6166
# [GPU] Epoch 120: b norm = 1.5505, w norm = 3.6166
# [GPU] Epoch 130: b norm = 1.5505, w norm = 3.6166
# [GPU] Epoch 140: b norm = 1.5505, w norm = 3.6166
# [GPU] Epoch 0: b norm = 0.2173, w norm = 0.7326
# [GPU] Epoch 10: b norm = 1.0787, w norm = 3.1924
# [GPU] Epoch 20: b norm = 1.3075, w norm = 3.8460
# [GPU] Epoch 30: b norm = 1.3849, w norm = 4.0572
# [GPU] Epoch 40: b norm = 1.4131, w norm = 4.1292
# [GPU] Epoch 50: b norm = 1.4238, w norm = 4.1544
# [GPU] Epoch 60: b norm = 1.4279, w norm = 4.1634
# [GPU] Epoch 70: b norm = 1.4295, w norm = 4.1667
# [GPU] Epoch 80: b norm = 1.4302, w norm = 4.1679
# [GPU] Epoch 90: b norm = 1.4304, w norm = 4.1683
# [GPU] Epoch 100: b norm = 1.4305, w norm = 4.1685
# [GPU] Epoch 110: b norm = 1.4305, w norm = 4.1685
# [GPU] Epoch 120: b norm = 1.4306, w norm = 4.1685
# [GPU] Epoch 130: b norm = 1.4306, w norm = 4.1686
# [GPU] Epoch 140: b norm = 1.4306, w norm = 4.1686
# [GPU] Epoch 0: b norm = 0.2310, w norm = 0.7201
# [GPU] Epoch 10: b norm = 0.9733, w norm = 2.8736
# [GPU] Epoch 20: b norm = 1.1921, w norm = 3.5144
# [GPU] Epoch 30: b norm = 1.2761, w norm = 3.7442
# [GPU] Epoch 40: b norm = 1.3109, w norm = 3.8315
# [GPU] Epoch 50: b norm = 1.3258, w norm = 3.8658
# [GPU] Epoch 60: b norm = 1.3323, w norm = 3.8796
# [GPU] Epoch 70: b norm = 1.3352, w norm = 3.8852
# [GPU] Epoch 80: b norm = 1.3364, w norm = 3.8875
# [GPU] Epoch 90: b norm = 1.3370, w norm = 3.8884
# [GPU] Epoch 100: b norm = 1.3372, w norm = 3.8888
# [GPU] Epoch 110: b norm = 1.3374, w norm = 3.8890
# [GPU] Epoch 120: b norm = 1.3374, w norm = 3.8891
# [GPU] Epoch 130: b norm = 1.3374, w norm = 3.8891
# [GPU] Epoch 140: b norm = 1.3374, w norm = 3.8891
# [GPU] Epoch 0: b norm = 0.2079, w norm = 0.7098
# [GPU] Epoch 10: b norm = 1.0720, w norm = 3.1483
# [GPU] Epoch 20: b norm = 1.2989, w norm = 3.7815
# [GPU] Epoch 30: b norm = 1.3745, w norm = 3.9816
# [GPU] Epoch 40: b norm = 1.4018, w norm = 4.0487
# [GPU] Epoch 50: b norm = 1.4121, w norm = 4.0720
# [GPU] Epoch 60: b norm = 1.4160, w norm = 4.0802
# [GPU] Epoch 70: b norm = 1.4175, w norm = 4.0831
# [GPU] Epoch 80: b norm = 1.4181, w norm = 4.0842
# [GPU] Epoch 90: b norm = 1.4183, w norm = 4.0846
# [GPU] Epoch 100: b norm = 1.4184, w norm = 4.0847
# [GPU] Epoch 110: b norm = 1.4184, w norm = 4.0848
# [GPU] Epoch 120: b norm = 1.4185, w norm = 4.0848
# [GPU] Epoch 130: b norm = 1.4185, w norm = 4.0848
# [GPU] Epoch 140: b norm = 1.4185, w norm = 4.0848
# [GPU] Epoch 0: b norm = 0.2329, w norm = 0.6841
# [GPU] Epoch 10: b norm = 0.9661, w norm = 2.8214
# [GPU] Epoch 20: b norm = 1.1794, w norm = 3.4315
# [GPU] Epoch 30: b norm = 1.2609, w norm = 3.6449
# [GPU] Epoch 40: b norm = 1.2944, w norm = 3.7241
# [GPU] Epoch 50: b norm = 1.3087, w norm = 3.7544
# [GPU] Epoch 60: b norm = 1.3149, w norm = 3.7663
# [GPU] Epoch 70: b norm = 1.3177, w norm = 3.7710
# [GPU] Epoch 80: b norm = 1.3189, w norm = 3.7729
# [GPU] Epoch 90: b norm = 1.3194, w norm = 3.7737
# [GPU] Epoch 100: b norm = 1.3196, w norm = 3.7740
# [GPU] Epoch 110: b norm = 1.3197, w norm = 3.7742
# [GPU] Epoch 120: b norm = 1.3198, w norm = 3.7742
# [GPU] Epoch 130: b norm = 1.3198, w norm = 3.7742
# [GPU] Epoch 140: b norm = 1.3198, w norm = 3.7742
# [GPU] Epoch 0: b norm = 0.2213, w norm = 0.6898
# [GPU] Epoch 10: b norm = 1.0303, w norm = 3.1149
# [GPU] Epoch 20: b norm = 1.2391, w norm = 3.7505
# [GPU] Epoch 30: b norm = 1.3086, w norm = 3.9522
# [GPU] Epoch 40: b norm = 1.3337, w norm = 4.0201
# [GPU] Epoch 50: b norm = 1.3431, w norm = 4.0437
# [GPU] Epoch 60: b norm = 1.3467, w norm = 4.0521
# [GPU] Epoch 70: b norm = 1.3481, w norm = 4.0551
# [GPU] Epoch 80: b norm = 1.3486, w norm = 4.0562
# [GPU] Epoch 90: b norm = 1.3489, w norm = 4.0566
# [GPU] Epoch 100: b norm = 1.3489, w norm = 4.0567
# [GPU] Epoch 110: b norm = 1.3490, w norm = 4.0568
# [GPU] Epoch 120: b norm = 1.3490, w norm = 4.0568
# [GPU] Epoch 130: b norm = 1.3490, w norm = 4.0568
# [GPU] Epoch 140: b norm = 1.3490, w norm = 4.0568
# [GPU] Epoch 0: b norm = 0.2093, w norm = 0.7017
# [GPU] Epoch 10: b norm = 0.9137, w norm = 2.8105
# [GPU] Epoch 20: b norm = 1.1175, w norm = 3.4161
# [GPU] Epoch 30: b norm = 1.1953, w norm = 3.6292
# [GPU] Epoch 40: b norm = 1.2274, w norm = 3.7089
# [GPU] Epoch 50: b norm = 1.2410, w norm = 3.7397
# [GPU] Epoch 60: b norm = 1.2469, w norm = 3.7519
# [GPU] Epoch 70: b norm = 1.2495, w norm = 3.7568
# [GPU] Epoch 80: b norm = 1.2506, w norm = 3.7588
# [GPU] Epoch 90: b norm = 1.2511, w norm = 3.7596
# [GPU] Epoch 100: b norm = 1.2513, w norm = 3.7599
# [GPU] Epoch 110: b norm = 1.2514, w norm = 3.7601
# [GPU] Epoch 120: b norm = 1.2515, w norm = 3.7601
# [GPU] Epoch 130: b norm = 1.2515, w norm = 3.7602
# [GPU] Epoch 140: b norm = 1.2515, w norm = 3.7602
# [GPU] Epoch 0: b norm = 0.2094, w norm = 0.6682
# [GPU] Epoch 10: b norm = 0.9984, w norm = 3.1340
# [GPU] Epoch 20: b norm = 1.2036, w norm = 3.7971
# [GPU] Epoch 30: b norm = 1.2714, w norm = 4.0090
# [GPU] Epoch 40: b norm = 1.2957, w norm = 4.0805
# [GPU] Epoch 50: b norm = 1.3047, w norm = 4.1054
# [GPU] Epoch 60: b norm = 1.3081, w norm = 4.1143
# [GPU] Epoch 70: b norm = 1.3095, w norm = 4.1175
# [GPU] Epoch 80: b norm = 1.3100, w norm = 4.1186
# [GPU] Epoch 90: b norm = 1.3102, w norm = 4.1190
# [GPU] Epoch 100: b norm = 1.3102, w norm = 4.1192
# [GPU] Epoch 110: b norm = 1.3103, w norm = 4.1193
# [GPU] Epoch 120: b norm = 1.3103, w norm = 4.1193
# [GPU] Epoch 130: b norm = 1.3103, w norm = 4.1193
# [GPU] Epoch 140: b norm = 1.3103, w norm = 4.1193
# [GPU] Epoch 0: b norm = 0.2114, w norm = 0.6791
# [GPU] Epoch 10: b norm = 0.8957, w norm = 2.8489
# [GPU] Epoch 20: b norm = 1.0928, w norm = 3.4808
# [GPU] Epoch 30: b norm = 1.1678, w norm = 3.7034
# [GPU] Epoch 40: b norm = 1.1985, w norm = 3.7867
# [GPU] Epoch 50: b norm = 1.2115, w norm = 3.8190
# [GPU] Epoch 60: b norm = 1.2171, w norm = 3.8317
# [GPU] Epoch 70: b norm = 1.2195, w norm = 3.8368
# [GPU] Epoch 80: b norm = 1.2206, w norm = 3.8389
# [GPU] Epoch 90: b norm = 1.2210, w norm = 3.8398
# [GPU] Epoch 100: b norm = 1.2213, w norm = 3.8401
# [GPU] Epoch 110: b norm = 1.2214, w norm = 3.8403
# [GPU] Epoch 120: b norm = 1.2214, w norm = 3.8403
# [GPU] Epoch 130: b norm = 1.2214, w norm = 3.8404
# [GPU] Epoch 140: b norm = 1.2214, w norm = 3.8404
# [GPU] Epoch 0: b norm = 0.2338, w norm = 0.7333
# [GPU] Epoch 10: b norm = 1.0580, w norm = 3.2000
# [GPU] Epoch 20: b norm = 1.2759, w norm = 3.8515
# [GPU] Epoch 30: b norm = 1.3498, w norm = 4.0604
# [GPU] Epoch 40: b norm = 1.3768, w norm = 4.1311
# [GPU] Epoch 50: b norm = 1.3870, w norm = 4.1557
# [GPU] Epoch 60: b norm = 1.3910, w norm = 4.1644
# [GPU] Epoch 70: b norm = 1.3925, w norm = 4.1676
# [GPU] Epoch 80: b norm = 1.3931, w norm = 4.1687
# [GPU] Epoch 90: b norm = 1.3933, w norm = 4.1692
# [GPU] Epoch 100: b norm = 1.3934, w norm = 4.1693
# [GPU] Epoch 110: b norm = 1.3935, w norm = 4.1694
# [GPU] Epoch 120: b norm = 1.3935, w norm = 4.1694
# [GPU] Epoch 130: b norm = 1.3935, w norm = 4.1694
# [GPU] Epoch 140: b norm = 1.3935, w norm = 4.1694
# [GPU] Epoch 0: b norm = 0.2315, w norm = 0.7181
# [GPU] Epoch 10: b norm = 0.9500, w norm = 2.8793
# [GPU] Epoch 20: b norm = 1.1637, w norm = 3.5100
# [GPU] Epoch 30: b norm = 1.2475, w norm = 3.7337
# [GPU] Epoch 40: b norm = 1.2828, w norm = 3.8178
# [GPU] Epoch 50: b norm = 1.2981, w norm = 3.8503
# [GPU] Epoch 60: b norm = 1.3049, w norm = 3.8632
# [GPU] Epoch 70: b norm = 1.3079, w norm = 3.8684
# [GPU] Epoch 80: b norm = 1.3092, w norm = 3.8705
# [GPU] Epoch 90: b norm = 1.3098, w norm = 3.8713
# [GPU] Epoch 100: b norm = 1.3101, w norm = 3.8717
# [GPU] Epoch 110: b norm = 1.3102, w norm = 3.8718
# [GPU] Epoch 120: b norm = 1.3103, w norm = 3.8719
# [GPU] Epoch 130: b norm = 1.3103, w norm = 3.8719
# [GPU] Epoch 140: b norm = 1.3103, w norm = 3.8719
# [GPU] Epoch 0: b norm = 0.2219, w norm = 0.7056
# [GPU] Epoch 10: b norm = 1.0521, w norm = 3.1479
# [GPU] Epoch 20: b norm = 1.2721, w norm = 3.7945
# [GPU] Epoch 30: b norm = 1.3453, w norm = 4.0000
# [GPU] Epoch 40: b norm = 1.3717, w norm = 4.0690
# [GPU] Epoch 50: b norm = 1.3815, w norm = 4.0929
# [GPU] Epoch 60: b norm = 1.3853, w norm = 4.1014
# [GPU] Epoch 70: b norm = 1.3867, w norm = 4.1044
# [GPU] Epoch 80: b norm = 1.3873, w norm = 4.1055
# [GPU] Epoch 90: b norm = 1.3875, w norm = 4.1059
# [GPU] Epoch 100: b norm = 1.3876, w norm = 4.1060
# [GPU] Epoch 110: b norm = 1.3876, w norm = 4.1061
# [GPU] Epoch 120: b norm = 1.3876, w norm = 4.1061
# [GPU] Epoch 130: b norm = 1.3876, w norm = 4.1061
# [GPU] Epoch 140: b norm = 1.3876, w norm = 4.1061
# [GPU] Epoch 0: b norm = 0.2209, w norm = 0.6942
# [GPU] Epoch 10: b norm = 0.9436, w norm = 2.8385
# [GPU] Epoch 20: b norm = 1.1541, w norm = 3.4548
# [GPU] Epoch 30: b norm = 1.2340, w norm = 3.6696
# [GPU] Epoch 40: b norm = 1.2668, w norm = 3.7491
# [GPU] Epoch 50: b norm = 1.2807, w norm = 3.7795
# [GPU] Epoch 60: b norm = 1.2867, w norm = 3.7915
# [GPU] Epoch 70: b norm = 1.2893, w norm = 3.7962
# [GPU] Epoch 80: b norm = 1.2905, w norm = 3.7981
# [GPU] Epoch 90: b norm = 1.2910, w norm = 3.7989
# [GPU] Epoch 100: b norm = 1.2912, w norm = 3.7992
# [GPU] Epoch 110: b norm = 1.2913, w norm = 3.7994
# [GPU] Epoch 120: b norm = 1.2913, w norm = 3.7994
# [GPU] Epoch 130: b norm = 1.2914, w norm = 3.7994
# [GPU] Epoch 140: b norm = 1.2914, w norm = 3.7994
# [GPU] Epoch 0: b norm = 0.2042, w norm = 0.6656
# [GPU] Epoch 10: b norm = 1.0085, w norm = 3.1376
# [GPU] Epoch 20: b norm = 1.2211, w norm = 3.8016
# [GPU] Epoch 30: b norm = 1.2919, w norm = 4.0129
# [GPU] Epoch 40: b norm = 1.3175, w norm = 4.0841
# [GPU] Epoch 50: b norm = 1.3271, w norm = 4.1088
# [GPU] Epoch 60: b norm = 1.3307, w norm = 4.1175
# [GPU] Epoch 70: b norm = 1.3321, w norm = 4.1207
# [GPU] Epoch 80: b norm = 1.3327, w norm = 4.1218
# [GPU] Epoch 90: b norm = 1.3329, w norm = 4.1222
# [GPU] Epoch 100: b norm = 1.3330, w norm = 4.1224
# [GPU] Epoch 110: b norm = 1.3330, w norm = 4.1224
# [GPU] Epoch 120: b norm = 1.3330, w norm = 4.1224
# [GPU] Epoch 130: b norm = 1.3330, w norm = 4.1224
# [GPU] Epoch 140: b norm = 1.3330, w norm = 4.1225
# [GPU] Epoch 0: b norm = 0.2111, w norm = 0.6663
# [GPU] Epoch 10: b norm = 0.9083, w norm = 2.8497
# [GPU] Epoch 20: b norm = 1.1120, w norm = 3.4840
# [GPU] Epoch 30: b norm = 1.1892, w norm = 3.7065
# [GPU] Epoch 40: b norm = 1.2206, w norm = 3.7893
# [GPU] Epoch 50: b norm = 1.2339, w norm = 3.8212
# [GPU] Epoch 60: b norm = 1.2395, w norm = 3.8337
# [GPU] Epoch 70: b norm = 1.2420, w norm = 3.8387
# [GPU] Epoch 80: b norm = 1.2431, w norm = 3.8407
# [GPU] Epoch 90: b norm = 1.2435, w norm = 3.8416
# [GPU] Epoch 100: b norm = 1.2437, w norm = 3.8419
# [GPU] Epoch 110: b norm = 1.2438, w norm = 3.8420
# [GPU] Epoch 120: b norm = 1.2439, w norm = 3.8421
# [GPU] Epoch 130: b norm = 1.2439, w norm = 3.8421
# [GPU] Epoch 140: b norm = 1.2439, w norm = 3.8421
# [GPU] Epoch 0: b norm = 0.2235, w norm = 0.7301
# [GPU] Epoch 10: b norm = 1.0775, w norm = 3.2319
# [GPU] Epoch 20: b norm = 1.3057, w norm = 3.8913
# [GPU] Epoch 30: b norm = 1.3835, w norm = 4.1022
# [GPU] Epoch 40: b norm = 1.4121, w norm = 4.1736
# [GPU] Epoch 50: b norm = 1.4230, w norm = 4.1984
# [GPU] Epoch 60: b norm = 1.4272, w norm = 4.2072
# [GPU] Epoch 70: b norm = 1.4289, w norm = 4.2104
# [GPU] Epoch 80: b norm = 1.4295, w norm = 4.2115
# [GPU] Epoch 90: b norm = 1.4298, w norm = 4.2120
# [GPU] Epoch 100: b norm = 1.4299, w norm = 4.2121
# [GPU] Epoch 110: b norm = 1.4299, w norm = 4.2122
# [GPU] Epoch 120: b norm = 1.4299, w norm = 4.2122
# [GPU] Epoch 130: b norm = 1.4299, w norm = 4.2122
# [GPU] Epoch 140: b norm = 1.4299, w norm = 4.2122
# [GPU] Epoch 0: b norm = 0.2254, w norm = 0.7273
# [GPU] Epoch 10: b norm = 0.9678, w norm = 2.9081
# [GPU] Epoch 20: b norm = 1.1936, w norm = 3.5476
# [GPU] Epoch 30: b norm = 1.2825, w norm = 3.7740
# [GPU] Epoch 40: b norm = 1.3200, w norm = 3.8588
# [GPU] Epoch 50: b norm = 1.3362, w norm = 3.8916
# [GPU] Epoch 60: b norm = 1.3434, w norm = 3.9046
# [GPU] Epoch 70: b norm = 1.3465, w norm = 3.9097
# [GPU] Epoch 80: b norm = 1.3480, w norm = 3.9119
# [GPU] Epoch 90: b norm = 1.3486, w norm = 3.9127
# [GPU] Epoch 100: b norm = 1.3489, w norm = 3.9131
# [GPU] Epoch 110: b norm = 1.3490, w norm = 3.9132
# [GPU] Epoch 120: b norm = 1.3491, w norm = 3.9133
# [GPU] Epoch 130: b norm = 1.3491, w norm = 3.9133
# [GPU] Epoch 140: b norm = 1.3491, w norm = 3.9133
# [GPU] Epoch 0: b norm = 0.1947, w norm = 0.6457
# [GPU] Epoch 10: b norm = 0.9537, w norm = 3.0748
# [GPU] Epoch 20: b norm = 1.1618, w norm = 3.7460
# [GPU] Epoch 30: b norm = 1.2332, w norm = 3.9624
# [GPU] Epoch 40: b norm = 1.2594, w norm = 4.0357
# [GPU] Epoch 50: b norm = 1.2693, w norm = 4.0613
# [GPU] Epoch 60: b norm = 1.2731, w norm = 4.0704
# [GPU] Epoch 70: b norm = 1.2746, w norm = 4.0737
# [GPU] Epoch 80: b norm = 1.2752, w norm = 4.0749
# [GPU] Epoch 90: b norm = 1.2754, w norm = 4.0754
# [GPU] Epoch 100: b norm = 1.2755, w norm = 4.0755
# [GPU] Epoch 110: b norm = 1.2755, w norm = 4.0756
# [GPU] Epoch 120: b norm = 1.2755, w norm = 4.0756
# [GPU] Epoch 130: b norm = 1.2755, w norm = 4.0756
# [GPU] Epoch 140: b norm = 1.2755, w norm = 4.0756
# [GPU] Epoch 0: b norm = 0.1943, w norm = 0.6566
# [GPU] Epoch 10: b norm = 0.8670, w norm = 2.8173
# [GPU] Epoch 20: b norm = 1.0757, w norm = 3.4599
# [GPU] Epoch 30: b norm = 1.1580, w norm = 3.6871
# [GPU] Epoch 40: b norm = 1.1924, w norm = 3.7720
# [GPU] Epoch 50: b norm = 1.2072, w norm = 3.8046
# [GPU] Epoch 60: b norm = 1.2136, w norm = 3.8175
# [GPU] Epoch 70: b norm = 1.2165, w norm = 3.8226
# [GPU] Epoch 80: b norm = 1.2177, w norm = 3.8247
# [GPU] Epoch 90: b norm = 1.2183, w norm = 3.8255
# [GPU] Epoch 100: b norm = 1.2185, w norm = 3.8259
# [GPU] Epoch 110: b norm = 1.2186, w norm = 3.8260
# [GPU] Epoch 120: b norm = 1.2187, w norm = 3.8261
# [GPU] Epoch 130: b norm = 1.2187, w norm = 3.8261
# [GPU] Epoch 140: b norm = 1.2187, w norm = 3.8261
# [GPU] Epoch 0: b norm = 0.1969, w norm = 0.6384
# [GPU] Epoch 10: b norm = 0.9579, w norm = 3.0506
# [GPU] Epoch 20: b norm = 1.1690, w norm = 3.7260
# [GPU] Epoch 30: b norm = 1.2413, w norm = 3.9456
# [GPU] Epoch 40: b norm = 1.2677, w norm = 4.0204
# [GPU] Epoch 50: b norm = 1.2777, w norm = 4.0466
# [GPU] Epoch 60: b norm = 1.2815, w norm = 4.0560
# [GPU] Epoch 70: b norm = 1.2830, w norm = 4.0593
# [GPU] Epoch 80: b norm = 1.2835, w norm = 4.0606
# [GPU] Epoch 90: b norm = 1.2838, w norm = 4.0610
# [GPU] Epoch 100: b norm = 1.2838, w norm = 4.0612
# [GPU] Epoch 110: b norm = 1.2839, w norm = 4.0612
# [GPU] Epoch 120: b norm = 1.2839, w norm = 4.0613
# [GPU] Epoch 130: b norm = 1.2839, w norm = 4.0613
# [GPU] Epoch 140: b norm = 1.2839, w norm = 4.0613
# [GPU] Epoch 0: b norm = 0.1970, w norm = 0.6270
# [GPU] Epoch 10: b norm = 0.8761, w norm = 2.8024
# [GPU] Epoch 20: b norm = 1.0870, w norm = 3.4611
# [GPU] Epoch 30: b norm = 1.1684, w norm = 3.6950
# [GPU] Epoch 40: b norm = 1.2017, w norm = 3.7825
# [GPU] Epoch 50: b norm = 1.2157, w norm = 3.8163
# [GPU] Epoch 60: b norm = 1.2217, w norm = 3.8295
# [GPU] Epoch 70: b norm = 1.2243, w norm = 3.8349
# [GPU] Epoch 80: b norm = 1.2255, w norm = 3.8370
# [GPU] Epoch 90: b norm = 1.2260, w norm = 3.8379
# [GPU] Epoch 100: b norm = 1.2262, w norm = 3.8382
# [GPU] Epoch 110: b norm = 1.2263, w norm = 3.8384
# [GPU] Epoch 120: b norm = 1.2263, w norm = 3.8385
# [GPU] Epoch 130: b norm = 1.2263, w norm = 3.8385
# [GPU] Epoch 140: b norm = 1.2264, w norm = 3.8385
# [GPU] Epoch 0: b norm = 0.2126, w norm = 0.6595
# [GPU] Epoch 10: b norm = 0.9942, w norm = 3.1347
# [GPU] Epoch 20: b norm = 1.2049, w norm = 3.8173
# [GPU] Epoch 30: b norm = 1.2770, w norm = 4.0392
# [GPU] Epoch 40: b norm = 1.3035, w norm = 4.1150
# [GPU] Epoch 50: b norm = 1.3136, w norm = 4.1415
# [GPU] Epoch 60: b norm = 1.3174, w norm = 4.1510
# [GPU] Epoch 70: b norm = 1.3189, w norm = 4.1544
# [GPU] Epoch 80: b norm = 1.3195, w norm = 4.1557
# [GPU] Epoch 90: b norm = 1.3198, w norm = 4.1561
# [GPU] Epoch 100: b norm = 1.3199, w norm = 4.1563
# [GPU] Epoch 110: b norm = 1.3199, w norm = 4.1564
# [GPU] Epoch 120: b norm = 1.3199, w norm = 4.1564
# [GPU] Epoch 130: b norm = 1.3199, w norm = 4.1564
# [GPU] Epoch 140: b norm = 1.3199, w norm = 4.1564
# [GPU] Epoch 0: b norm = 0.2261, w norm = 0.6633
# [GPU] Epoch 10: b norm = 0.9053, w norm = 2.8628
# [GPU] Epoch 20: b norm = 1.1142, w norm = 3.5289
# [GPU] Epoch 30: b norm = 1.1965, w norm = 3.7672
# [GPU] Epoch 40: b norm = 1.2309, w norm = 3.8568
# [GPU] Epoch 50: b norm = 1.2457, w norm = 3.8916
# [GPU] Epoch 60: b norm = 1.2521, w norm = 3.9053
# [GPU] Epoch 70: b norm = 1.2549, w norm = 3.9108
# [GPU] Epoch 80: b norm = 1.2562, w norm = 3.9130
# [GPU] Epoch 90: b norm = 1.2567, w norm = 3.9139
# [GPU] Epoch 100: b norm = 1.2570, w norm = 3.9143
# [GPU] Epoch 110: b norm = 1.2571, w norm = 3.9145
# [GPU] Epoch 120: b norm = 1.2571, w norm = 3.9145
# [GPU] Epoch 130: b norm = 1.2571, w norm = 3.9146
# [GPU] Epoch 140: b norm = 1.2571, w norm = 3.9146
# [GPU] Epoch 0: b norm = 0.2106, w norm = 0.6860
# [GPU] Epoch 10: b norm = 0.9885, w norm = 3.1276
# [GPU] Epoch 20: b norm = 1.1899, w norm = 3.7919
# [GPU] Epoch 30: b norm = 1.2577, w norm = 4.0079
# [GPU] Epoch 40: b norm = 1.2824, w norm = 4.0818
# [GPU] Epoch 50: b norm = 1.2918, w norm = 4.1077
# [GPU] Epoch 60: b norm = 1.2954, w norm = 4.1170
# [GPU] Epoch 70: b norm = 1.2967, w norm = 4.1203
# [GPU] Epoch 80: b norm = 1.2973, w norm = 4.1216
# [GPU] Epoch 90: b norm = 1.2975, w norm = 4.1220
# [GPU] Epoch 100: b norm = 1.2976, w norm = 4.1222
# [GPU] Epoch 110: b norm = 1.2976, w norm = 4.1223
# [GPU] Epoch 120: b norm = 1.2976, w norm = 4.1223
# [GPU] Epoch 130: b norm = 1.2976, w norm = 4.1223
# [GPU] Epoch 140: b norm = 1.2976, w norm = 4.1223
# [GPU] Epoch 0: b norm = 0.2028, w norm = 0.6946
# [GPU] Epoch 10: b norm = 0.8754, w norm = 2.8482
# [GPU] Epoch 20: b norm = 1.0770, w norm = 3.4973
# [GPU] Epoch 30: b norm = 1.1558, w norm = 3.7300
# [GPU] Epoch 40: b norm = 1.1886, w norm = 3.8178
# [GPU] Epoch 50: b norm = 1.2026, w norm = 3.8520
# [GPU] Epoch 60: b norm = 1.2086, w norm = 3.8655
# [GPU] Epoch 70: b norm = 1.2113, w norm = 3.8709
# [GPU] Epoch 80: b norm = 1.2124, w norm = 3.8731
# [GPU] Epoch 90: b norm = 1.2129, w norm = 3.8740
# [GPU] Epoch 100: b norm = 1.2131, w norm = 3.8744
# [GPU] Epoch 110: b norm = 1.2132, w norm = 3.8746
# [GPU] Epoch 120: b norm = 1.2133, w norm = 3.8746
# [GPU] Epoch 130: b norm = 1.2133, w norm = 3.8747
# [GPU] Epoch 140: b norm = 1.2133, w norm = 3.8747
# [GPU] Epoch 0: b norm = 0.2132, w norm = 0.6953
# [GPU] Epoch 10: b norm = 1.0601, w norm = 3.2270
# [GPU] Epoch 20: b norm = 1.2864, w norm = 3.8954
# [GPU] Epoch 30: b norm = 1.3627, w norm = 4.1077
# [GPU] Epoch 40: b norm = 1.3906, w norm = 4.1793
# [GPU] Epoch 50: b norm = 1.4011, w norm = 4.2043
# [GPU] Epoch 60: b norm = 1.4052, w norm = 4.2132
# [GPU] Epoch 70: b norm = 1.4068, w norm = 4.2164
# [GPU] Epoch 80: b norm = 1.4074, w norm = 4.2175
# [GPU] Epoch 90: b norm = 1.4077, w norm = 4.2180
# [GPU] Epoch 100: b norm = 1.4078, w norm = 4.2181
# [GPU] Epoch 110: b norm = 1.4078, w norm = 4.2182
# [GPU] Epoch 120: b norm = 1.4078, w norm = 4.2182
# [GPU] Epoch 130: b norm = 1.4078, w norm = 4.2182
# [GPU] Epoch 140: b norm = 1.4078, w norm = 4.2182
# [GPU] Epoch 0: b norm = 0.2180, w norm = 0.6932
# [GPU] Epoch 10: b norm = 0.9526, w norm = 2.9104
# [GPU] Epoch 20: b norm = 1.1741, w norm = 3.5519
# [GPU] Epoch 30: b norm = 1.2619, w norm = 3.7792
# [GPU] Epoch 40: b norm = 1.2992, w norm = 3.8648
# [GPU] Epoch 50: b norm = 1.3155, w norm = 3.8980
# [GPU] Epoch 60: b norm = 1.3227, w norm = 3.9112
# [GPU] Epoch 70: b norm = 1.3259, w norm = 3.9165
# [GPU] Epoch 80: b norm = 1.3273, w norm = 3.9186
# [GPU] Epoch 90: b norm = 1.3279, w norm = 3.9195
# [GPU] Epoch 100: b norm = 1.3282, w norm = 3.9199
# [GPU] Epoch 110: b norm = 1.3284, w norm = 3.9200
# [GPU] Epoch 120: b norm = 1.3284, w norm = 3.9201
# [GPU] Epoch 130: b norm = 1.3284, w norm = 3.9201
# [GPU] Epoch 140: b norm = 1.3285, w norm = 3.9201
# [GPU] Epoch 0: b norm = 0.2140, w norm = 0.7086
# [GPU] Epoch 10: b norm = 1.0224, w norm = 3.1887
# [GPU] Epoch 20: b norm = 1.2422, w norm = 3.8612
# [GPU] Epoch 30: b norm = 1.3175, w norm = 4.0786
# [GPU] Epoch 40: b norm = 1.3452, w norm = 4.1525
# [GPU] Epoch 50: b norm = 1.3557, w norm = 4.1782
# [GPU] Epoch 60: b norm = 1.3597, w norm = 4.1874
# [GPU] Epoch 70: b norm = 1.3613, w norm = 4.1906
# [GPU] Epoch 80: b norm = 1.3619, w norm = 4.1918
# [GPU] Epoch 90: b norm = 1.3621, w norm = 4.1923
# [GPU] Epoch 100: b norm = 1.3622, w norm = 4.1924
# [GPU] Epoch 110: b norm = 1.3623, w norm = 4.1925
# [GPU] Epoch 120: b norm = 1.3623, w norm = 4.1925
# [GPU] Epoch 130: b norm = 1.3623, w norm = 4.1925
# [GPU] Epoch 140: b norm = 1.3623, w norm = 4.1925
# [GPU] Epoch 0: b norm = 0.2091, w norm = 0.7113
# [GPU] Epoch 10: b norm = 0.9205, w norm = 2.8967
# [GPU] Epoch 20: b norm = 1.1406, w norm = 3.5520
# [GPU] Epoch 30: b norm = 1.2271, w norm = 3.7847
# [GPU] Epoch 40: b norm = 1.2632, w norm = 3.8719
# [GPU] Epoch 50: b norm = 1.2787, w norm = 3.9055
# [GPU] Epoch 60: b norm = 1.2854, w norm = 3.9188
# [GPU] Epoch 70: b norm = 1.2884, w norm = 3.9241
# [GPU] Epoch 80: b norm = 1.2897, w norm = 3.9263
# [GPU] Epoch 90: b norm = 1.2903, w norm = 3.9271
# [GPU] Epoch 100: b norm = 1.2905, w norm = 3.9275
# [GPU] Epoch 110: b norm = 1.2907, w norm = 3.9277
# [GPU] Epoch 120: b norm = 1.2907, w norm = 3.9277
# [GPU] Epoch 130: b norm = 1.2907, w norm = 3.9278
# [GPU] Epoch 140: b norm = 1.2907, w norm = 3.9278
# [GPU] Epoch 0: b norm = 0.1843, w norm = 0.6699
# [GPU] Epoch 10: b norm = 0.9772, w norm = 3.1560
# [GPU] Epoch 20: b norm = 1.1989, w norm = 3.8486
# [GPU] Epoch 30: b norm = 1.2752, w norm = 4.0740
# [GPU] Epoch 40: b norm = 1.3034, w norm = 4.1510
# [GPU] Epoch 50: b norm = 1.3140, w norm = 4.1780
# [GPU] Epoch 60: b norm = 1.3182, w norm = 4.1876
# [GPU] Epoch 70: b norm = 1.3198, w norm = 4.1911
# [GPU] Epoch 80: b norm = 1.3204, w norm = 4.1924
# [GPU] Epoch 90: b norm = 1.3206, w norm = 4.1928
# [GPU] Epoch 100: b norm = 1.3207, w norm = 4.1930
# [GPU] Epoch 110: b norm = 1.3208, w norm = 4.1931
# [GPU] Epoch 120: b norm = 1.3208, w norm = 4.1931
# [GPU] Epoch 130: b norm = 1.3208, w norm = 4.1931
# [GPU] Epoch 140: b norm = 1.3208, w norm = 4.1931
# [GPU] Epoch 0: b norm = 0.2104, w norm = 0.6614
# [GPU] Epoch 10: b norm = 0.8987, w norm = 2.8940
# [GPU] Epoch 20: b norm = 1.1165, w norm = 3.5705
# [GPU] Epoch 30: b norm = 1.2028, w norm = 3.8123
# [GPU] Epoch 40: b norm = 1.2390, w norm = 3.9031
# [GPU] Epoch 50: b norm = 1.2547, w norm = 3.9382
# [GPU] Epoch 60: b norm = 1.2615, w norm = 3.9521
# [GPU] Epoch 70: b norm = 1.2646, w norm = 3.9576
# [GPU] Epoch 80: b norm = 1.2659, w norm = 3.9599
# [GPU] Epoch 90: b norm = 1.2665, w norm = 3.9608
# [GPU] Epoch 100: b norm = 1.2668, w norm = 3.9612
# [GPU] Epoch 110: b norm = 1.2669, w norm = 3.9613
# [GPU] Epoch 120: b norm = 1.2670, w norm = 3.9614
# [GPU] Epoch 130: b norm = 1.2670, w norm = 3.9614
# [GPU] Epoch 140: b norm = 1.2670, w norm = 3.9614
# [GPU] Epoch 0: b norm = 0.2118, w norm = 0.6641
# [GPU] Epoch 10: b norm = 0.9687, w norm = 3.1509
# [GPU] Epoch 20: b norm = 1.1654, w norm = 3.8359
# [GPU] Epoch 30: b norm = 1.2305, w norm = 4.0578
# [GPU] Epoch 40: b norm = 1.2539, w norm = 4.1335
# [GPU] Epoch 50: b norm = 1.2626, w norm = 4.1601
# [GPU] Epoch 60: b norm = 1.2660, w norm = 4.1697
# [GPU] Epoch 70: b norm = 1.2672, w norm = 4.1731
# [GPU] Epoch 80: b norm = 1.2677, w norm = 4.1744
# [GPU] Epoch 90: b norm = 1.2679, w norm = 4.1749
# [GPU] Epoch 100: b norm = 1.2680, w norm = 4.1750
# [GPU] Epoch 110: b norm = 1.2680, w norm = 4.1751
# [GPU] Epoch 120: b norm = 1.2680, w norm = 4.1751
# [GPU] Epoch 130: b norm = 1.2681, w norm = 4.1751
# [GPU] Epoch 140: b norm = 1.2681, w norm = 4.1751
# [GPU] Epoch 0: b norm = 0.1983, w norm = 0.6729
# [GPU] Epoch 10: b norm = 0.8620, w norm = 2.8854
# [GPU] Epoch 20: b norm = 1.0558, w norm = 3.5468
# [GPU] Epoch 30: b norm = 1.1299, w norm = 3.7836
# [GPU] Epoch 40: b norm = 1.1604, w norm = 3.8733
# [GPU] Epoch 50: b norm = 1.1734, w norm = 3.9084
# [GPU] Epoch 60: b norm = 1.1789, w norm = 3.9225
# [GPU] Epoch 70: b norm = 1.1813, w norm = 3.9282
# [GPU] Epoch 80: b norm = 1.1824, w norm = 3.9305
# [GPU] Epoch 90: b norm = 1.1828, w norm = 3.9315
# [GPU] Epoch 100: b norm = 1.1831, w norm = 3.9319
# [GPU] Epoch 110: b norm = 1.1831, w norm = 3.9320
# [GPU] Epoch 120: b norm = 1.1832, w norm = 3.9321
# [GPU] Epoch 130: b norm = 1.1832, w norm = 3.9321
# [GPU] Epoch 140: b norm = 1.1832, w norm = 3.9322
# [GPU] Epoch 0: b norm = 0.2227, w norm = 0.6729
# [GPU] Epoch 10: b norm = 1.0179, w norm = 3.1285
# [GPU] Epoch 20: b norm = 1.2279, w norm = 3.7965
# [GPU] Epoch 30: b norm = 1.2987, w norm = 4.0123
# [GPU] Epoch 40: b norm = 1.3244, w norm = 4.0857
# [GPU] Epoch 50: b norm = 1.3341, w norm = 4.1115
# [GPU] Epoch 60: b norm = 1.3378, w norm = 4.1206
# [GPU] Epoch 70: b norm = 1.3393, w norm = 4.1239
# [GPU] Epoch 80: b norm = 1.3399, w norm = 4.1251
# [GPU] Epoch 90: b norm = 1.3401, w norm = 4.1256
# [GPU] Epoch 100: b norm = 1.3402, w norm = 4.1257
# [GPU] Epoch 110: b norm = 1.3402, w norm = 4.1258
# [GPU] Epoch 120: b norm = 1.3402, w norm = 4.1258
# [GPU] Epoch 130: b norm = 1.3402, w norm = 4.1258
# [GPU] Epoch 140: b norm = 1.3402, w norm = 4.1258
# [GPU] Epoch 0: b norm = 0.2109, w norm = 0.6798
# [GPU] Epoch 10: b norm = 0.9113, w norm = 2.8489
# [GPU] Epoch 20: b norm = 1.1201, w norm = 3.4971
# [GPU] Epoch 30: b norm = 1.2008, w norm = 3.7285
# [GPU] Epoch 40: b norm = 1.2341, w norm = 3.8157
# [GPU] Epoch 50: b norm = 1.2482, w norm = 3.8496
# [GPU] Epoch 60: b norm = 1.2543, w norm = 3.8630
# [GPU] Epoch 70: b norm = 1.2570, w norm = 3.8684
# [GPU] Epoch 80: b norm = 1.2582, w norm = 3.8706
# [GPU] Epoch 90: b norm = 1.2587, w norm = 3.8715
# [GPU] Epoch 100: b norm = 1.2589, w norm = 3.8719
# [GPU] Epoch 110: b norm = 1.2590, w norm = 3.8721
# [GPU] Epoch 120: b norm = 1.2591, w norm = 3.8721
# [GPU] Epoch 130: b norm = 1.2591, w norm = 3.8721
# [GPU] Epoch 140: b norm = 1.2591, w norm = 3.8722
# [GPU] Epoch 0: b norm = 0.2054, w norm = 0.6886
# [GPU] Epoch 10: b norm = 0.9848, w norm = 3.1924
# [GPU] Epoch 20: b norm = 1.1910, w norm = 3.8739
# [GPU] Epoch 30: b norm = 1.2607, w norm = 4.0938
# [GPU] Epoch 40: b norm = 1.2862, w norm = 4.1685
# [GPU] Epoch 50: b norm = 1.2958, w norm = 4.1947
# [GPU] Epoch 60: b norm = 1.2995, w norm = 4.2040
# [GPU] Epoch 70: b norm = 1.3009, w norm = 4.2074
# [GPU] Epoch 80: b norm = 1.3015, w norm = 4.2087
# [GPU] Epoch 90: b norm = 1.3017, w norm = 4.2091
# [GPU] Epoch 100: b norm = 1.3018, w norm = 4.2093
# [GPU] Epoch 110: b norm = 1.3018, w norm = 4.2093
# [GPU] Epoch 120: b norm = 1.3018, w norm = 4.2094
# [GPU] Epoch 130: b norm = 1.3018, w norm = 4.2094
# [GPU] Epoch 140: b norm = 1.3018, w norm = 4.2094
# [GPU] Epoch 0: b norm = 0.2136, w norm = 0.6782
# [GPU] Epoch 10: b norm = 0.8901, w norm = 2.9063
# [GPU] Epoch 20: b norm = 1.0924, w norm = 3.5636
# [GPU] Epoch 30: b norm = 1.1715, w norm = 3.7963
# [GPU] Epoch 40: b norm = 1.2044, w norm = 3.8836
# [GPU] Epoch 50: b norm = 1.2184, w norm = 3.9175
# [GPU] Epoch 60: b norm = 1.2245, w norm = 3.9310
# [GPU] Epoch 70: b norm = 1.2271, w norm = 3.9364
# [GPU] Epoch 80: b norm = 1.2283, w norm = 3.9386
# [GPU] Epoch 90: b norm = 1.2288, w norm = 3.9395
# [GPU] Epoch 100: b norm = 1.2290, w norm = 3.9399
# [GPU] Epoch 110: b norm = 1.2291, w norm = 3.9400
# [GPU] Epoch 120: b norm = 1.2292, w norm = 3.9401
# [GPU] Epoch 130: b norm = 1.2292, w norm = 3.9401
# [GPU] Epoch 140: b norm = 1.2292, w norm = 3.9401
# [GPU] Epoch 0: b norm = 0.2069, w norm = 0.6948
# [GPU] Epoch 10: b norm = 0.9985, w norm = 3.1536
# [GPU] Epoch 20: b norm = 1.2149, w norm = 3.8281
# [GPU] Epoch 30: b norm = 1.2900, w norm = 4.0479
# [GPU] Epoch 40: b norm = 1.3179, w norm = 4.1230
# [GPU] Epoch 50: b norm = 1.3286, w norm = 4.1493
# [GPU] Epoch 60: b norm = 1.3327, w norm = 4.1586
# [GPU] Epoch 70: b norm = 1.3343, w norm = 4.1620
# [GPU] Epoch 80: b norm = 1.3349, w norm = 4.1632
# [GPU] Epoch 90: b norm = 1.3352, w norm = 4.1637
# [GPU] Epoch 100: b norm = 1.3353, w norm = 4.1638
# [GPU] Epoch 110: b norm = 1.3353, w norm = 4.1639
# [GPU] Epoch 120: b norm = 1.3354, w norm = 4.1639
# [GPU] Epoch 130: b norm = 1.3354, w norm = 4.1639
# [GPU] Epoch 140: b norm = 1.3354, w norm = 4.1639
# [GPU] Epoch 0: b norm = 0.2132, w norm = 0.6818
# [GPU] Epoch 10: b norm = 0.9050, w norm = 2.8693
# [GPU] Epoch 20: b norm = 1.1258, w norm = 3.5334
# [GPU] Epoch 30: b norm = 1.2148, w norm = 3.7706
# [GPU] Epoch 40: b norm = 1.2527, w norm = 3.8598
# [GPU] Epoch 50: b norm = 1.2692, w norm = 3.8943
# [GPU] Epoch 60: b norm = 1.2765, w norm = 3.9080
# [GPU] Epoch 70: b norm = 1.2797, w norm = 3.9134
# [GPU] Epoch 80: b norm = 1.2812, w norm = 3.9157
# [GPU] Epoch 90: b norm = 1.2818, w norm = 3.9166
# [GPU] Epoch 100: b norm = 1.2821, w norm = 3.9170
# [GPU] Epoch 110: b norm = 1.2822, w norm = 3.9171
# [GPU] Epoch 120: b norm = 1.2823, w norm = 3.9172
# [GPU] Epoch 130: b norm = 1.2823, w norm = 3.9172
# [GPU] Epoch 140: b norm = 1.2823, w norm = 3.9172
# [GPU] Epoch 0: b norm = 0.2181, w norm = 0.7057
# [GPU] Epoch 10: b norm = 1.0457, w norm = 3.2218
# [GPU] Epoch 20: b norm = 1.2696, w norm = 3.9022
# [GPU] Epoch 30: b norm = 1.3458, w norm = 4.1215
# [GPU] Epoch 40: b norm = 1.3738, w norm = 4.1959
# [GPU] Epoch 50: b norm = 1.3843, w norm = 4.2219
# [GPU] Epoch 60: b norm = 1.3884, w norm = 4.2311
# [GPU] Epoch 70: b norm = 1.3900, w norm = 4.2345
# [GPU] Epoch 80: b norm = 1.3906, w norm = 4.2357
# [GPU] Epoch 90: b norm = 1.3909, w norm = 4.2361
# [GPU] Epoch 100: b norm = 1.3910, w norm = 4.2363
# [GPU] Epoch 110: b norm = 1.3910, w norm = 4.2364
# [GPU] Epoch 120: b norm = 1.3910, w norm = 4.2364
# [GPU] Epoch 130: b norm = 1.3910, w norm = 4.2364
# [GPU] Epoch 140: b norm = 1.3910, w norm = 4.2364
# [GPU] Epoch 0: b norm = 0.2251, w norm = 0.6909
# [GPU] Epoch 10: b norm = 0.9454, w norm = 2.9189
# [GPU] Epoch 20: b norm = 1.1656, w norm = 3.5848
# [GPU] Epoch 30: b norm = 1.2518, w norm = 3.8228
# [GPU] Epoch 40: b norm = 1.2880, w norm = 3.9128
# [GPU] Epoch 50: b norm = 1.3036, w norm = 3.9478
# [GPU] Epoch 60: b norm = 1.3104, w norm = 3.9618
# [GPU] Epoch 70: b norm = 1.3134, w norm = 3.9674
# [GPU] Epoch 80: b norm = 1.3148, w norm = 3.9697
# [GPU] Epoch 90: b norm = 1.3154, w norm = 3.9706
# [GPU] Epoch 100: b norm = 1.3156, w norm = 3.9710
# [GPU] Epoch 110: b norm = 1.3157, w norm = 3.9712
# [GPU] Epoch 120: b norm = 1.3158, w norm = 3.9713
# [GPU] Epoch 130: b norm = 1.3158, w norm = 3.9713
# [GPU] Epoch 140: b norm = 1.3158, w norm = 3.9713
# [GPU] Epoch 0: b norm = 0.2117, w norm = 0.6858
# [GPU] Epoch 10: b norm = 1.0321, w norm = 3.1662
# [GPU] Epoch 20: b norm = 1.2507, w norm = 3.8430
# [GPU] Epoch 30: b norm = 1.3250, w norm = 4.0626
# [GPU] Epoch 40: b norm = 1.3522, w norm = 4.1374
# [GPU] Epoch 50: b norm = 1.3625, w norm = 4.1635
# [GPU] Epoch 60: b norm = 1.3664, w norm = 4.1728
# [GPU] Epoch 70: b norm = 1.3680, w norm = 4.1761
# [GPU] Epoch 80: b norm = 1.3686, w norm = 4.1774
# [GPU] Epoch 90: b norm = 1.3688, w norm = 4.1778
# [GPU] Epoch 100: b norm = 1.3689, w norm = 4.1780
# [GPU] Epoch 110: b norm = 1.3689, w norm = 4.1780
# [GPU] Epoch 120: b norm = 1.3689, w norm = 4.1781
# [GPU] Epoch 130: b norm = 1.3690, w norm = 4.1781
# [GPU] Epoch 140: b norm = 1.3690, w norm = 4.1781
# [GPU] Epoch 0: b norm = 0.1970, w norm = 0.6989
# [GPU] Epoch 10: b norm = 0.9200, w norm = 2.8874
# [GPU] Epoch 20: b norm = 1.1399, w norm = 3.5442
# [GPU] Epoch 30: b norm = 1.2255, w norm = 3.7768
# [GPU] Epoch 40: b norm = 1.2611, w norm = 3.8636
# [GPU] Epoch 50: b norm = 1.2763, w norm = 3.8971
# [GPU] Epoch 60: b norm = 1.2829, w norm = 3.9103
# [GPU] Epoch 70: b norm = 1.2858, w norm = 3.9156
# [GPU] Epoch 80: b norm = 1.2871, w norm = 3.9178
# [GPU] Epoch 90: b norm = 1.2877, w norm = 3.9187
# [GPU] Epoch 100: b norm = 1.2879, w norm = 3.9190
# [GPU] Epoch 110: b norm = 1.2880, w norm = 3.9192
# [GPU] Epoch 120: b norm = 1.2881, w norm = 3.9193
# [GPU] Epoch 130: b norm = 1.2881, w norm = 3.9193
# [GPU] Epoch 140: b norm = 1.2881, w norm = 3.9193
# [GPU] Epoch 0: b norm = 0.2201, w norm = 0.7182
# [GPU] Epoch 10: b norm = 1.0359, w norm = 3.2167
# [GPU] Epoch 20: b norm = 1.2514, w norm = 3.8870
# [GPU] Epoch 30: b norm = 1.3245, w norm = 4.1035
# [GPU] Epoch 40: b norm = 1.3513, w norm = 4.1773
# [GPU] Epoch 50: b norm = 1.3614, w norm = 4.2032
# [GPU] Epoch 60: b norm = 1.3653, w norm = 4.2125
# [GPU] Epoch 70: b norm = 1.3668, w norm = 4.2159
# [GPU] Epoch 80: b norm = 1.3674, w norm = 4.2171
# [GPU] Epoch 90: b norm = 1.3677, w norm = 4.2175
# [GPU] Epoch 100: b norm = 1.3677, w norm = 4.2177
# [GPU] Epoch 110: b norm = 1.3678, w norm = 4.2178
# [GPU] Epoch 120: b norm = 1.3678, w norm = 4.2178
# [GPU] Epoch 130: b norm = 1.3678, w norm = 4.2178
# [GPU] Epoch 140: b norm = 1.3678, w norm = 4.2178
# [GPU] Epoch 0: b norm = 0.2124, w norm = 0.7077
# [GPU] Epoch 10: b norm = 0.9274, w norm = 2.9120
# [GPU] Epoch 20: b norm = 1.1411, w norm = 3.5673
# [GPU] Epoch 30: b norm = 1.2238, w norm = 3.8020
# [GPU] Epoch 40: b norm = 1.2581, w norm = 3.8911
# [GPU] Epoch 50: b norm = 1.2728, w norm = 3.9261
# [GPU] Epoch 60: b norm = 1.2791, w norm = 3.9400
# [GPU] Epoch 70: b norm = 1.2819, w norm = 3.9457
# [GPU] Epoch 80: b norm = 1.2832, w norm = 3.9480
# [GPU] Epoch 90: b norm = 1.2837, w norm = 3.9490
# [GPU] Epoch 100: b norm = 1.2839, w norm = 3.9494
# [GPU] Epoch 110: b norm = 1.2841, w norm = 3.9496
# [GPU] Epoch 120: b norm = 1.2841, w norm = 3.9497
# [GPU] Epoch 130: b norm = 1.2841, w norm = 3.9497
# [GPU] Epoch 140: b norm = 1.2841, w norm = 3.9497
# [GPU] Epoch 0: b norm = 0.2229, w norm = 0.6981
# [GPU] Epoch 10: b norm = 1.0430, w norm = 3.1971
# [GPU] Epoch 20: b norm = 1.2646, w norm = 3.8803
# [GPU] Epoch 30: b norm = 1.3402, w norm = 4.1024
# [GPU] Epoch 40: b norm = 1.3679, w norm = 4.1783
# [GPU] Epoch 50: b norm = 1.3785, w norm = 4.2049
# [GPU] Epoch 60: b norm = 1.3825, w norm = 4.2144
# [GPU] Epoch 70: b norm = 1.3841, w norm = 4.2179
# [GPU] Epoch 80: b norm = 1.3847, w norm = 4.2191
# [GPU] Epoch 90: b norm = 1.3850, w norm = 4.2196
# [GPU] Epoch 100: b norm = 1.3851, w norm = 4.2198
# [GPU] Epoch 110: b norm = 1.3851, w norm = 4.2198
# [GPU] Epoch 120: b norm = 1.3851, w norm = 4.2199
# [GPU] Epoch 130: b norm = 1.3851, w norm = 4.2199
# [GPU] Epoch 140: b norm = 1.3851, w norm = 4.2199
# [GPU] Epoch 0: b norm = 0.2021, w norm = 0.7012
# [GPU] Epoch 10: b norm = 0.9328, w norm = 2.9114
# [GPU] Epoch 20: b norm = 1.1588, w norm = 3.5787
# [GPU] Epoch 30: b norm = 1.2478, w norm = 3.8177
# [GPU] Epoch 40: b norm = 1.2853, w norm = 3.9081
# [GPU] Epoch 50: b norm = 1.3015, w norm = 3.9434
# [GPU] Epoch 60: b norm = 1.3086, w norm = 3.9574
# [GPU] Epoch 70: b norm = 1.3117, w norm = 3.9631
# [GPU] Epoch 80: b norm = 1.3131, w norm = 3.9654
# [GPU] Epoch 90: b norm = 1.3138, w norm = 3.9663
# [GPU] Epoch 100: b norm = 1.3140, w norm = 3.9667
# [GPU] Epoch 110: b norm = 1.3142, w norm = 3.9669
# [GPU] Epoch 120: b norm = 1.3142, w norm = 3.9670
# [GPU] Epoch 130: b norm = 1.3143, w norm = 3.9670
# [GPU] Epoch 140: b norm = 1.3143, w norm = 3.9670
# [GPU] Epoch 0: b norm = 0.2579, w norm = 0.7671
# [GPU] Epoch 10: b norm = 1.1206, w norm = 3.3085
# [GPU] Epoch 20: b norm = 1.3452, w norm = 3.9693
# [GPU] Epoch 30: b norm = 1.4223, w norm = 4.1825
# [GPU] Epoch 40: b norm = 1.4509, w norm = 4.2552
# [GPU] Epoch 50: b norm = 1.4618, w norm = 4.2807
# [GPU] Epoch 60: b norm = 1.4661, w norm = 4.2898
# [GPU] Epoch 70: b norm = 1.4677, w norm = 4.2931
# [GPU] Epoch 80: b norm = 1.4684, w norm = 4.2943
# [GPU] Epoch 90: b norm = 1.4686, w norm = 4.2948
# [GPU] Epoch 100: b norm = 1.4687, w norm = 4.2949
# [GPU] Epoch 110: b norm = 1.4688, w norm = 4.2950
# [GPU] Epoch 120: b norm = 1.4688, w norm = 4.2950
# [GPU] Epoch 130: b norm = 1.4688, w norm = 4.2950
# [GPU] Epoch 140: b norm = 1.4688, w norm = 4.2950
# [GPU] Epoch 0: b norm = 0.2285, w norm = 0.7786
# [GPU] Epoch 10: b norm = 0.9868, w norm = 2.9655
# [GPU] Epoch 20: b norm = 1.2168, w norm = 3.6090
# [GPU] Epoch 30: b norm = 1.3080, w norm = 3.8403
# [GPU] Epoch 40: b norm = 1.3463, w norm = 3.9281
# [GPU] Epoch 50: b norm = 1.3629, w norm = 3.9624
# [GPU] Epoch 60: b norm = 1.3702, w norm = 3.9762
# [GPU] Epoch 70: b norm = 1.3734, w norm = 3.9817
# [GPU] Epoch 80: b norm = 1.3748, w norm = 3.9840
# [GPU] Epoch 90: b norm = 1.3755, w norm = 3.9850
# [GPU] Epoch 100: b norm = 1.3757, w norm = 3.9853
# [GPU] Epoch 110: b norm = 1.3759, w norm = 3.9855
# [GPU] Epoch 120: b norm = 1.3759, w norm = 3.9856
# [GPU] Epoch 130: b norm = 1.3760, w norm = 3.9856
# [GPU] Epoch 140: b norm = 1.3760, w norm = 3.9856
# [GPU] Epoch 0: b norm = 0.2101, w norm = 0.7264
# [GPU] Epoch 10: b norm = 1.0313, w norm = 3.2572
# [GPU] Epoch 20: b norm = 1.2446, w norm = 3.9406
# [GPU] Epoch 30: b norm = 1.3161, w norm = 4.1621
# [GPU] Epoch 40: b norm = 1.3421, w norm = 4.2379
# [GPU] Epoch 50: b norm = 1.3520, w norm = 4.2645
# [GPU] Epoch 60: b norm = 1.3558, w norm = 4.2741
# [GPU] Epoch 70: b norm = 1.3572, w norm = 4.2776
# [GPU] Epoch 80: b norm = 1.3578, w norm = 4.2788
# [GPU] Epoch 90: b norm = 1.3580, w norm = 4.2793
# [GPU] Epoch 100: b norm = 1.3581, w norm = 4.2795
# [GPU] Epoch 110: b norm = 1.3581, w norm = 4.2796
# [GPU] Epoch 120: b norm = 1.3582, w norm = 4.2796
# [GPU] Epoch 130: b norm = 1.3582, w norm = 4.2796
# [GPU] Epoch 140: b norm = 1.3582, w norm = 4.2796
# [GPU] Epoch 0: b norm = 0.2133, w norm = 0.7103
# [GPU] Epoch 10: b norm = 0.9217, w norm = 2.9531
# [GPU] Epoch 20: b norm = 1.1291, w norm = 3.6227
# [GPU] Epoch 30: b norm = 1.2102, w norm = 3.8643
# [GPU] Epoch 40: b norm = 1.2442, w norm = 3.9565
# [GPU] Epoch 50: b norm = 1.2589, w norm = 3.9928
# [GPU] Epoch 60: b norm = 1.2654, w norm = 4.0073
# [GPU] Epoch 70: b norm = 1.2682, w norm = 4.0133
# [GPU] Epoch 80: b norm = 1.2694, w norm = 4.0157
# [GPU] Epoch 90: b norm = 1.2700, w norm = 4.0167
# [GPU] Epoch 100: b norm = 1.2702, w norm = 4.0171
# [GPU] Epoch 110: b norm = 1.2703, w norm = 4.0173
# [GPU] Epoch 120: b norm = 1.2704, w norm = 4.0174
# [GPU] Epoch 130: b norm = 1.2704, w norm = 4.0174
# [GPU] Epoch 140: b norm = 1.2704, w norm = 4.0174
# [GPU] Epoch 0: b norm = 0.2269, w norm = 0.7079
# [GPU] Epoch 10: b norm = 1.0483, w norm = 3.2256
# [GPU] Epoch 20: b norm = 1.2699, w norm = 3.9069
# [GPU] Epoch 30: b norm = 1.3459, w norm = 4.1274
# [GPU] Epoch 40: b norm = 1.3740, w norm = 4.2027
# [GPU] Epoch 50: b norm = 1.3847, w norm = 4.2291
# [GPU] Epoch 60: b norm = 1.3889, w norm = 4.2386
# [GPU] Epoch 70: b norm = 1.3905, w norm = 4.2420
# [GPU] Epoch 80: b norm = 1.3912, w norm = 4.2432
# [GPU] Epoch 90: b norm = 1.3914, w norm = 4.2437
# [GPU] Epoch 100: b norm = 1.3915, w norm = 4.2439
# [GPU] Epoch 110: b norm = 1.3916, w norm = 4.2439
# [GPU] Epoch 120: b norm = 1.3916, w norm = 4.2440
# [GPU] Epoch 130: b norm = 1.3916, w norm = 4.2440
# [GPU] Epoch 140: b norm = 1.3916, w norm = 4.2440
# [GPU] Epoch 0: b norm = 0.2132, w norm = 0.6831
# [GPU] Epoch 10: b norm = 0.9456, w norm = 2.9268
# [GPU] Epoch 20: b norm = 1.1702, w norm = 3.5948
# [GPU] Epoch 30: b norm = 1.2596, w norm = 3.8346
# [GPU] Epoch 40: b norm = 1.2974, w norm = 3.9253
# [GPU] Epoch 50: b norm = 1.3138, w norm = 3.9607
# [GPU] Epoch 60: b norm = 1.3210, w norm = 3.9747
# [GPU] Epoch 70: b norm = 1.3242, w norm = 3.9804
# [GPU] Epoch 80: b norm = 1.3256, w norm = 3.9827
# [GPU] Epoch 90: b norm = 1.3263, w norm = 3.9836
# [GPU] Epoch 100: b norm = 1.3265, w norm = 3.9840
# [GPU] Epoch 110: b norm = 1.3267, w norm = 3.9842
# [GPU] Epoch 120: b norm = 1.3267, w norm = 3.9843
# [GPU] Epoch 130: b norm = 1.3268, w norm = 3.9843
# [GPU] Epoch 140: b norm = 1.3268, w norm = 3.9843
# [GPU] Epoch 0: b norm = 0.2065, w norm = 0.6746
# [GPU] Epoch 10: b norm = 1.0245, w norm = 3.1755
# [GPU] Epoch 20: b norm = 1.2443, w norm = 3.8601
# [GPU] Epoch 30: b norm = 1.3188, w norm = 4.0825
# [GPU] Epoch 40: b norm = 1.3461, w norm = 4.1586
# [GPU] Epoch 50: b norm = 1.3564, w norm = 4.1854
# [GPU] Epoch 60: b norm = 1.3604, w norm = 4.1950
# [GPU] Epoch 70: b norm = 1.3620, w norm = 4.1985
# [GPU] Epoch 80: b norm = 1.3626, w norm = 4.1998
# [GPU] Epoch 90: b norm = 1.3628, w norm = 4.2002
# [GPU] Epoch 100: b norm = 1.3629, w norm = 4.2004
# [GPU] Epoch 110: b norm = 1.3630, w norm = 4.2005
# [GPU] Epoch 120: b norm = 1.3630, w norm = 4.2005
# [GPU] Epoch 130: b norm = 1.3630, w norm = 4.2005
# [GPU] Epoch 140: b norm = 1.3630, w norm = 4.2005
# [GPU] Epoch 0: b norm = 0.2262, w norm = 0.6652
# [GPU] Epoch 10: b norm = 0.9317, w norm = 2.8935
# [GPU] Epoch 20: b norm = 1.1459, w norm = 3.5652
# [GPU] Epoch 30: b norm = 1.2301, w norm = 3.8071
# [GPU] Epoch 40: b norm = 1.2655, w norm = 3.8988
# [GPU] Epoch 50: b norm = 1.2808, w norm = 3.9346
# [GPU] Epoch 60: b norm = 1.2875, w norm = 3.9489
# [GPU] Epoch 70: b norm = 1.2905, w norm = 3.9547
# [GPU] Epoch 80: b norm = 1.2918, w norm = 3.9570
# [GPU] Epoch 90: b norm = 1.2924, w norm = 3.9580
# [GPU] Epoch 100: b norm = 1.2927, w norm = 3.9584
# [GPU] Epoch 110: b norm = 1.2928, w norm = 3.9585
# [GPU] Epoch 120: b norm = 1.2928, w norm = 3.9586
# [GPU] Epoch 130: b norm = 1.2929, w norm = 3.9586
# [GPU] Epoch 140: b norm = 1.2929, w norm = 3.9587
# [GPU] Epoch 0: b norm = 0.1972, w norm = 0.6704
# [GPU] Epoch 10: b norm = 0.9822, w norm = 3.2131
# [GPU] Epoch 20: b norm = 1.1990, w norm = 3.9201
# [GPU] Epoch 30: b norm = 1.2739, w norm = 4.1499
# [GPU] Epoch 40: b norm = 1.3015, w norm = 4.2285
# [GPU] Epoch 50: b norm = 1.3121, w norm = 4.2561
# [GPU] Epoch 60: b norm = 1.3162, w norm = 4.2660
# [GPU] Epoch 70: b norm = 1.3178, w norm = 4.2696
# [GPU] Epoch 80: b norm = 1.3184, w norm = 4.2709
# [GPU] Epoch 90: b norm = 1.3186, w norm = 4.2714
# [GPU] Epoch 100: b norm = 1.3187, w norm = 4.2716
# [GPU] Epoch 110: b norm = 1.3188, w norm = 4.2717
# [GPU] Epoch 120: b norm = 1.3188, w norm = 4.2717
# [GPU] Epoch 130: b norm = 1.3188, w norm = 4.2717
# [GPU] Epoch 140: b norm = 1.3188, w norm = 4.2717
# [GPU] Epoch 0: b norm = 0.2007, w norm = 0.6612
# [GPU] Epoch 10: b norm = 0.8950, w norm = 2.9423
# [GPU] Epoch 20: b norm = 1.1153, w norm = 3.6300
# [GPU] Epoch 30: b norm = 1.2037, w norm = 3.8770
# [GPU] Epoch 40: b norm = 1.2413, w norm = 3.9707
# [GPU] Epoch 50: b norm = 1.2577, w norm = 4.0073
# [GPU] Epoch 60: b norm = 1.2649, w norm = 4.0220
# [GPU] Epoch 70: b norm = 1.2681, w norm = 4.0279
# [GPU] Epoch 80: b norm = 1.2695, w norm = 4.0303
# [GPU] Epoch 90: b norm = 1.2701, w norm = 4.0313
# [GPU] Epoch 100: b norm = 1.2704, w norm = 4.0317
# [GPU] Epoch 110: b norm = 1.2705, w norm = 4.0319
# [GPU] Epoch 120: b norm = 1.2706, w norm = 4.0320
# [GPU] Epoch 130: b norm = 1.2706, w norm = 4.0320
# [GPU] Epoch 140: b norm = 1.2706, w norm = 4.0320
# [GPU] Epoch 0: b norm = 0.1973, w norm = 0.7050
# [GPU] Epoch 10: b norm = 0.9965, w norm = 3.2482
# [GPU] Epoch 20: b norm = 1.2136, w norm = 3.9479
# [GPU] Epoch 30: b norm = 1.2876, w norm = 4.1746
# [GPU] Epoch 40: b norm = 1.3148, w norm = 4.2518
# [GPU] Epoch 50: b norm = 1.3252, w norm = 4.2789
# [GPU] Epoch 60: b norm = 1.3291, w norm = 4.2886
# [GPU] Epoch 70: b norm = 1.3307, w norm = 4.2921
# [GPU] Epoch 80: b norm = 1.3313, w norm = 4.2934
# [GPU] Epoch 90: b norm = 1.3315, w norm = 4.2939
# [GPU] Epoch 100: b norm = 1.3316, w norm = 4.2940
# [GPU] Epoch 110: b norm = 1.3317, w norm = 4.2941
# [GPU] Epoch 120: b norm = 1.3317, w norm = 4.2941
# [GPU] Epoch 130: b norm = 1.3317, w norm = 4.2941
# [GPU] Epoch 140: b norm = 1.3317, w norm = 4.2941
# [GPU] Epoch 0: b norm = 0.1975, w norm = 0.6997
# [GPU] Epoch 10: b norm = 0.8996, w norm = 2.9614
# [GPU] Epoch 20: b norm = 1.1143, w norm = 3.6408
# [GPU] Epoch 30: b norm = 1.1993, w norm = 3.8841
# [GPU] Epoch 40: b norm = 1.2352, w norm = 3.9763
# [GPU] Epoch 50: b norm = 1.2507, w norm = 4.0123
# [GPU] Epoch 60: b norm = 1.2575, w norm = 4.0267
# [GPU] Epoch 70: b norm = 1.2606, w norm = 4.0326
# [GPU] Epoch 80: b norm = 1.2619, w norm = 4.0350
# [GPU] Epoch 90: b norm = 1.2625, w norm = 4.0360
# [GPU] Epoch 100: b norm = 1.2628, w norm = 4.0364
# [GPU] Epoch 110: b norm = 1.2629, w norm = 4.0366
# [GPU] Epoch 120: b norm = 1.2630, w norm = 4.0366
# [GPU] Epoch 130: b norm = 1.2630, w norm = 4.0367
# [GPU] Epoch 140: b norm = 1.2630, w norm = 4.0367
# [GPU] Epoch 0: b norm = 0.2065, w norm = 0.6849
# [GPU] Epoch 10: b norm = 1.0142, w norm = 3.2523
# [GPU] Epoch 20: b norm = 1.2339, w norm = 3.9632
# [GPU] Epoch 30: b norm = 1.3086, w norm = 4.1941
# [GPU] Epoch 40: b norm = 1.3360, w norm = 4.2729
# [GPU] Epoch 50: b norm = 1.3463, w norm = 4.3007
# [GPU] Epoch 60: b norm = 1.3503, w norm = 4.3106
# [GPU] Epoch 70: b norm = 1.3519, w norm = 4.3142
# [GPU] Epoch 80: b norm = 1.3525, w norm = 4.3155
# [GPU] Epoch 90: b norm = 1.3527, w norm = 4.3160
# [GPU] Epoch 100: b norm = 1.3528, w norm = 4.3162
# [GPU] Epoch 110: b norm = 1.3528, w norm = 4.3163
# [GPU] Epoch 120: b norm = 1.3528, w norm = 4.3163
# [GPU] Epoch 130: b norm = 1.3528, w norm = 4.3163
# [GPU] Epoch 140: b norm = 1.3529, w norm = 4.3163
# [GPU] Epoch 0: b norm = 0.2122, w norm = 0.7007
# [GPU] Epoch 10: b norm = 0.9185, w norm = 2.9797
# [GPU] Epoch 20: b norm = 1.1370, w norm = 3.6722
# [GPU] Epoch 30: b norm = 1.2229, w norm = 3.9228
# [GPU] Epoch 40: b norm = 1.2590, w norm = 4.0185
# [GPU] Epoch 50: b norm = 1.2744, w norm = 4.0561
# [GPU] Epoch 60: b norm = 1.2812, w norm = 4.0712
# [GPU] Epoch 70: b norm = 1.2842, w norm = 4.0773
# [GPU] Epoch 80: b norm = 1.2855, w norm = 4.0798
# [GPU] Epoch 90: b norm = 1.2861, w norm = 4.0809
# [GPU] Epoch 100: b norm = 1.2863, w norm = 4.0813
# [GPU] Epoch 110: b norm = 1.2864, w norm = 4.0815
# [GPU] Epoch 120: b norm = 1.2865, w norm = 4.0816
# [GPU] Epoch 130: b norm = 1.2865, w norm = 4.0816
# [GPU] Epoch 140: b norm = 1.2865, w norm = 4.0816
# [GPU] Epoch 0: b norm = 0.2075, w norm = 0.7242
# [GPU] Epoch 10: b norm = 1.0087, w norm = 3.2673
# [GPU] Epoch 20: b norm = 1.2236, w norm = 3.9618
# [GPU] Epoch 30: b norm = 1.2975, w norm = 4.1888
# [GPU] Epoch 40: b norm = 1.3248, w norm = 4.2669
# [GPU] Epoch 50: b norm = 1.3352, w norm = 4.2945
# [GPU] Epoch 60: b norm = 1.3392, w norm = 4.3044
# [GPU] Epoch 70: b norm = 1.3408, w norm = 4.3080
# [GPU] Epoch 80: b norm = 1.3414, w norm = 4.3094
# [GPU] Epoch 90: b norm = 1.3417, w norm = 4.3099
# [GPU] Epoch 100: b norm = 1.3418, w norm = 4.3100
# [GPU] Epoch 110: b norm = 1.3418, w norm = 4.3101
# [GPU] Epoch 120: b norm = 1.3418, w norm = 4.3101
# [GPU] Epoch 130: b norm = 1.3418, w norm = 4.3102
# [GPU] Epoch 140: b norm = 1.3418, w norm = 4.3102
# [GPU] Epoch 0: b norm = 0.2014, w norm = 0.7135
# [GPU] Epoch 10: b norm = 0.9027, w norm = 2.9722
# [GPU] Epoch 20: b norm = 1.1205, w norm = 3.6613
# [GPU] Epoch 30: b norm = 1.2069, w norm = 3.9116
# [GPU] Epoch 40: b norm = 1.2434, w norm = 4.0073
# [GPU] Epoch 50: b norm = 1.2591, w norm = 4.0448
# [GPU] Epoch 60: b norm = 1.2660, w norm = 4.0599
# [GPU] Epoch 70: b norm = 1.2690, w norm = 4.0660
# [GPU] Epoch 80: b norm = 1.2704, w norm = 4.0685
# [GPU] Epoch 90: b norm = 1.2710, w norm = 4.0695
# [GPU] Epoch 100: b norm = 1.2712, w norm = 4.0699
# [GPU] Epoch 110: b norm = 1.2714, w norm = 4.0701
# [GPU] Epoch 120: b norm = 1.2714, w norm = 4.0702
# [GPU] Epoch 130: b norm = 1.2714, w norm = 4.0702
# [GPU] Epoch 140: b norm = 1.2714, w norm = 4.0702
# [GPU] Epoch 0: b norm = 0.2183, w norm = 0.6966
# [GPU] Epoch 10: b norm = 1.0308, w norm = 3.2808
# [GPU] Epoch 20: b norm = 1.2560, w norm = 3.9968
# [GPU] Epoch 30: b norm = 1.3338, w norm = 4.2298
# [GPU] Epoch 40: b norm = 1.3626, w norm = 4.3096
# [GPU] Epoch 50: b norm = 1.3736, w norm = 4.3376
# [GPU] Epoch 60: b norm = 1.3778, w norm = 4.3477
# [GPU] Epoch 70: b norm = 1.3795, w norm = 4.3514
# [GPU] Epoch 80: b norm = 1.3801, w norm = 4.3527
# [GPU] Epoch 90: b norm = 1.3804, w norm = 4.3532
# [GPU] Epoch 100: b norm = 1.3805, w norm = 4.3534
# [GPU] Epoch 110: b norm = 1.3805, w norm = 4.3535
# [GPU] Epoch 120: b norm = 1.3805, w norm = 4.3535
# [GPU] Epoch 130: b norm = 1.3805, w norm = 4.3535
# ...
# [GPU] Epoch 60: b norm = 1.3531, w norm = 4.4112
# [GPU] Epoch 70: b norm = 1.3547, w norm = 4.4150
# [GPU] Epoch 80: b norm = 1.3553, w norm = 4.4164
# [GPU] Epoch 90: b norm = 1.3556, w norm = 4.4170
# [GPU] Epoch 100: b norm = 1.3557, w norm = 4.4172
# [GPU] Epoch 110: b norm = 1.3557, w norm = 4.4172
# [GPU] Epoch 120: b norm = 1.3557, w norm = 4.4173
# [GPU] Epoch 130: b norm = 1.3557, w norm = 4.4173
# [GPU] Epoch 140: b norm = 1.3557, w norm = 4.4173
# [GPU] Epoch 0: b norm = 0.2068, w norm = 0.7044
# [GPU] Epoch 10: b norm = 0.9171, w norm = 3.0397
# [GPU] Epoch 20: b norm = 1.1393, w norm = 3.7593
# [GPU] Epoch 30: b norm = 1.2279, w norm = 4.0211
# [GPU] Epoch 40: b norm = 1.2653, w norm = 4.1212
# [GPU] Epoch 50: b norm = 1.2816, w norm = 4.1607
# [GPU] Epoch 60: b norm = 1.2887, w norm = 4.1765
# [GPU] Epoch 70: b norm = 1.2918, w norm = 4.1829
# [GPU] Epoch 80: b norm = 1.2932, w norm = 4.1856
# [GPU] Epoch 90: b norm = 1.2939, w norm = 4.1867
# [GPU] Epoch 100: b norm = 1.2941, w norm = 4.1872
# [GPU] Epoch 110: b norm = 1.2943, w norm = 4.1874
# [GPU] Epoch 120: b norm = 1.2943, w norm = 4.1875
# [GPU] Epoch 130: b norm = 1.2943, w norm = 4.1875
# [GPU] Epoch 140: b norm = 1.2944, w norm = 4.1875
# [GPU] Epoch 0: b norm = 0.2146, w norm = 0.7169
# [GPU] Epoch 10: b norm = 1.0399, w norm = 3.2926
# [GPU] Epoch 20: b norm = 1.2637, w norm = 4.0057
# [GPU] Epoch 30: b norm = 1.3411, w norm = 4.2393
# [GPU] Epoch 40: b norm = 1.3696, w norm = 4.3194
# [GPU] Epoch 50: b norm = 1.3805, w norm = 4.3475
# [GPU] Epoch 60: b norm = 1.3847, w norm = 4.3576
# [GPU] Epoch 70: b norm = 1.3864, w norm = 4.3612
# [GPU] Epoch 80: b norm = 1.3870, w norm = 4.3626
# [GPU] Epoch 90: b norm = 1.3873, w norm = 4.3631
# [GPU] Epoch 100: b norm = 1.3874, w norm = 4.3632
# [GPU] Epoch 110: b norm = 1.3874, w norm = 4.3633
# [GPU] Epoch 120: b norm = 1.3874, w norm = 4.3633
# [GPU] Epoch 130: b norm = 1.3874, w norm = 4.3633
# [GPU] Epoch 140: b norm = 1.3874, w norm = 4.3633
# [GPU] Epoch 0: b norm = 0.2134, w norm = 0.7187
# [GPU] Epoch 10: b norm = 0.9393, w norm = 3.0104
# [GPU] Epoch 20: b norm = 1.1645, w norm = 3.7102
# [GPU] Epoch 30: b norm = 1.2538, w norm = 3.9608
# [GPU] Epoch 40: b norm = 1.2914, w norm = 4.0553
# [GPU] Epoch 50: b norm = 1.3076, w norm = 4.0921
# [GPU] Epoch 60: b norm = 1.3147, w norm = 4.1067
# [GPU] Epoch 70: b norm = 1.3178, w norm = 4.1126
# [GPU] Epoch 80: b norm = 1.3192, w norm = 4.1150
# [GPU] Epoch 90: b norm = 1.3198, w norm = 4.1160
# [GPU] Epoch 100: b norm = 1.3201, w norm = 4.1164
# [GPU] Epoch 110: b norm = 1.3202, w norm = 4.1166
# [GPU] Epoch 120: b norm = 1.3202, w norm = 4.1167
# [GPU] Epoch 130: b norm = 1.3203, w norm = 4.1167
# [GPU] Epoch 140: b norm = 1.3203, w norm = 4.1167
# [GPU] Epoch 0: b norm = 0.2226, w norm = 0.7346
# [GPU] Epoch 10: b norm = 1.0730, w norm = 3.3734
# [GPU] Epoch 20: b norm = 1.3032, w norm = 4.0891
# [GPU] Epoch 30: b norm = 1.3825, w norm = 4.3216
# [GPU] Epoch 40: b norm = 1.4118, w norm = 4.4011
# [GPU] Epoch 50: b norm = 1.4230, w norm = 4.4290
# [GPU] Epoch 60: b norm = 1.4274, w norm = 4.4390
# [GPU] Epoch 70: b norm = 1.4291, w norm = 4.4426
# [GPU] Epoch 80: b norm = 1.4298, w norm = 4.4440
# [GPU] Epoch 90: b norm = 1.4300, w norm = 4.4445
# [GPU] Epoch 100: b norm = 1.4301, w norm = 4.4447
# [GPU] Epoch 110: b norm = 1.4302, w norm = 4.4447
# [GPU] Epoch 120: b norm = 1.4302, w norm = 4.4447
# [GPU] Epoch 130: b norm = 1.4302, w norm = 4.4448
# [GPU] Epoch 140: b norm = 1.4302, w norm = 4.4448
# [GPU] Epoch 0: b norm = 0.2094, w norm = 0.7346
# [GPU] Epoch 10: b norm = 0.9620, w norm = 3.0633
# [GPU] Epoch 20: b norm = 1.1958, w norm = 3.7637
# [GPU] Epoch 30: b norm = 1.2894, w norm = 4.0155
# [GPU] Epoch 40: b norm = 1.3293, w norm = 4.1112
# [GPU] Epoch 50: b norm = 1.3468, w norm = 4.1487
# [GPU] Epoch 60: b norm = 1.3545, w norm = 4.1637
# [GPU] Epoch 70: b norm = 1.3579, w norm = 4.1698
# [GPU] Epoch 80: b norm = 1.3595, w norm = 4.1723
# [GPU] Epoch 90: b norm = 1.3602, w norm = 4.1734
# [GPU] Epoch 100: b norm = 1.3605, w norm = 4.1738
# [GPU] Epoch 110: b norm = 1.3606, w norm = 4.1740
# [GPU] Epoch 120: b norm = 1.3607, w norm = 4.1741
# [GPU] Epoch 130: b norm = 1.3607, w norm = 4.1741
# [GPU] Epoch 140: b norm = 1.3608, w norm = 4.1741
# [GPU] Epoch 0: b norm = 0.2283, w norm = 0.7549
# [GPU] Epoch 10: b norm = 1.0551, w norm = 3.3695
# [GPU] Epoch 20: b norm = 1.2684, w norm = 4.0741
# [GPU] Epoch 30: b norm = 1.3410, w norm = 4.3049
# [GPU] Epoch 40: b norm = 1.3678, w norm = 4.3846
# [GPU] Epoch 50: b norm = 1.3780, w norm = 4.4128
# [GPU] Epoch 60: b norm = 1.3819, w norm = 4.4229
# [GPU] Epoch 70: b norm = 1.3835, w norm = 4.4266
# [GPU] Epoch 80: b norm = 1.3841, w norm = 4.4280
# [GPU] Epoch 90: b norm = 1.3843, w norm = 4.4285
# [GPU] Epoch 100: b norm = 1.3844, w norm = 4.4287
# [GPU] Epoch 110: b norm = 1.3844, w norm = 4.4288
# [GPU] Epoch 120: b norm = 1.3844, w norm = 4.4288
# [GPU] Epoch 130: b norm = 1.3844, w norm = 4.4288
# [GPU] Epoch 140: b norm = 1.3845, w norm = 4.4288
# [GPU] Epoch 0: b norm = 0.2442, w norm = 0.7393
# [GPU] Epoch 10: b norm = 0.9420, w norm = 3.0427
# [GPU] Epoch 20: b norm = 1.1509, w norm = 3.7478
# [GPU] Epoch 30: b norm = 1.2342, w norm = 4.0053
# [GPU] Epoch 40: b norm = 1.2696, w norm = 4.1041
# [GPU] Epoch 50: b norm = 1.2850, w norm = 4.1431
# [GPU] Epoch 60: b norm = 1.2918, w norm = 4.1588
# [GPU] Epoch 70: b norm = 1.2948, w norm = 4.1652
# [GPU] Epoch 80: b norm = 1.2961, w norm = 4.1678
# [GPU] Epoch 90: b norm = 1.2967, w norm = 4.1689
# [GPU] Epoch 100: b norm = 1.2970, w norm = 4.1694
# [GPU] Epoch 110: b norm = 1.2971, w norm = 4.1696
# [GPU] Epoch 120: b norm = 1.2972, w norm = 4.1697
# [GPU] Epoch 130: b norm = 1.2972, w norm = 4.1697
# [GPU] Epoch 140: b norm = 1.2972, w norm = 4.1697
# [GPU] Epoch 0: b norm = 0.2078, w norm = 0.7037
# [GPU] Epoch 10: b norm = 1.0093, w norm = 3.2832
# [GPU] Epoch 20: b norm = 1.2308, w norm = 4.0031
# [GPU] Epoch 30: b norm = 1.3080, w norm = 4.2396
# [GPU] Epoch 40: b norm = 1.3367, w norm = 4.3210
# [GPU] Epoch 50: b norm = 1.3477, w norm = 4.3498
# [GPU] Epoch 60: b norm = 1.3519, w norm = 4.3601
# [GPU] Epoch 70: b norm = 1.3536, w norm = 4.3639
# [GPU] Epoch 80: b norm = 1.3543, w norm = 4.3653
# [GPU] Epoch 90: b norm = 1.3545, w norm = 4.3658
# [GPU] Epoch 100: b norm = 1.3546, w norm = 4.3660
# [GPU] Epoch 110: b norm = 1.3547, w norm = 4.3660
# [GPU] Epoch 120: b norm = 1.3547, w norm = 4.3661
# [GPU] Epoch 130: b norm = 1.3547, w norm = 4.3661
# [GPU] Epoch 140: b norm = 1.3547, w norm = 4.3661
# [GPU] Epoch 0: b norm = 0.2171, w norm = 0.7162
# [GPU] Epoch 10: b norm = 0.9203, w norm = 3.0128
# [GPU] Epoch 20: b norm = 1.1474, w norm = 3.7201
# [GPU] Epoch 30: b norm = 1.2389, w norm = 3.9766
# [GPU] Epoch 40: b norm = 1.2777, w norm = 4.0745
# [GPU] Epoch 50: b norm = 1.2946, w norm = 4.1129
# [GPU] Epoch 60: b norm = 1.3020, w norm = 4.1283
# [GPU] Epoch 70: b norm = 1.3053, w norm = 4.1346
# [GPU] Epoch 80: b norm = 1.3067, w norm = 4.1372
# [GPU] Epoch 90: b norm = 1.3074, w norm = 4.1382
# [GPU] Epoch 100: b norm = 1.3077, w norm = 4.1387
# [GPU] Epoch 110: b norm = 1.3078, w norm = 4.1389
# [GPU] Epoch 120: b norm = 1.3079, w norm = 4.1390
# [GPU] Epoch 130: b norm = 1.3079, w norm = 4.1390
# [GPU] Epoch 140: b norm = 1.3079, w norm = 4.1390
# [GPU] Epoch 0: b norm = 0.2048, w norm = 0.7073
# [GPU] Epoch 10: b norm = 1.0031, w norm = 3.2911
# [GPU] Epoch 20: b norm = 1.2193, w norm = 4.0119
# [GPU] Epoch 30: b norm = 1.2937, w norm = 4.2488
# [GPU] Epoch 40: b norm = 1.3212, w norm = 4.3304
# [GPU] Epoch 50: b norm = 1.3317, w norm = 4.3593
# [GPU] Epoch 60: b norm = 1.3357, w norm = 4.3697
# [GPU] Epoch 70: b norm = 1.3373, w norm = 4.3735
# [GPU] Epoch 80: b norm = 1.3379, w norm = 4.3749
# [GPU] Epoch 90: b norm = 1.3381, w norm = 4.3754
# [GPU] Epoch 100: b norm = 1.3382, w norm = 4.3756
# [GPU] Epoch 110: b norm = 1.3383, w norm = 4.3756
# [GPU] Epoch 120: b norm = 1.3383, w norm = 4.3757
# [GPU] Epoch 130: b norm = 1.3383, w norm = 4.3757
# [GPU] Epoch 140: b norm = 1.3383, w norm = 4.3757
# [GPU] Epoch 0: b norm = 0.2251, w norm = 0.7121
# [GPU] Epoch 10: b norm = 0.9099, w norm = 3.0087
# [GPU] Epoch 20: b norm = 1.1245, w norm = 3.7198
# [GPU] Epoch 30: b norm = 1.2104, w norm = 3.9785
# [GPU] Epoch 40: b norm = 1.2468, w norm = 4.0775
# [GPU] Epoch 50: b norm = 1.2625, w norm = 4.1166
# [GPU] Epoch 60: b norm = 1.2695, w norm = 4.1323
# [GPU] Epoch 70: b norm = 1.2726, w norm = 4.1387
# [GPU] Epoch 80: b norm = 1.2739, w norm = 4.1413
# [GPU] Epoch 90: b norm = 1.2745, w norm = 4.1424
# [GPU] Epoch 100: b norm = 1.2748, w norm = 4.1429
# [GPU] Epoch 110: b norm = 1.2749, w norm = 4.1431
# [GPU] Epoch 120: b norm = 1.2750, w norm = 4.1432
# [GPU] Epoch 130: b norm = 1.2750, w norm = 4.1432
# [GPU] Epoch 140: b norm = 1.2750, w norm = 4.1432
# [GPU] Epoch 0: b norm = 0.2290, w norm = 0.7107
# [GPU] Epoch 10: b norm = 1.0732, w norm = 3.3212
# [GPU] Epoch 20: b norm = 1.3013, w norm = 4.0377
# [GPU] Epoch 30: b norm = 1.3794, w norm = 4.2721
# [GPU] Epoch 40: b norm = 1.4081, w norm = 4.3527
# [GPU] Epoch 50: b norm = 1.4191, w norm = 4.3811
# [GPU] Epoch 60: b norm = 1.4233, w norm = 4.3913
# [GPU] Epoch 70: b norm = 1.4250, w norm = 4.3950
# [GPU] Epoch 80: b norm = 1.4256, w norm = 4.3964
# [GPU] Epoch 90: b norm = 1.4259, w norm = 4.3969
# [GPU] Epoch 100: b norm = 1.4260, w norm = 4.3971
# [GPU] Epoch 110: b norm = 1.4260, w norm = 4.3972
# [GPU] Epoch 120: b norm = 1.4260, w norm = 4.3972
# [GPU] Epoch 130: b norm = 1.4260, w norm = 4.3972
# [GPU] Epoch 140: b norm = 1.4260, w norm = 4.3972
# [GPU] Epoch 0: b norm = 0.2152, w norm = 0.7253
# [GPU] Epoch 10: b norm = 0.9648, w norm = 3.0348
# [GPU] Epoch 20: b norm = 1.1954, w norm = 3.7396
# [GPU] Epoch 30: b norm = 1.2865, w norm = 3.9955
# [GPU] Epoch 40: b norm = 1.3249, w norm = 4.0934
# [GPU] Epoch 50: b norm = 1.3414, w norm = 4.1319
# [GPU] Epoch 60: b norm = 1.3487, w norm = 4.1474
# [GPU] Epoch 70: b norm = 1.3519, w norm = 4.1537
# [GPU] Epoch 80: b norm = 1.3534, w norm = 4.1563
# [GPU] Epoch 90: b norm = 1.3540, w norm = 4.1573
# [GPU] Epoch 100: b norm = 1.3543, w norm = 4.1578
# [GPU] Epoch 110: b norm = 1.3544, w norm = 4.1580
# [GPU] Epoch 120: b norm = 1.3545, w norm = 4.1581
# [GPU] Epoch 130: b norm = 1.3545, w norm = 4.1581
# [GPU] Epoch 140: b norm = 1.3545, w norm = 4.1581
# [GPU] Epoch 0: b norm = 0.2084, w norm = 0.6939
# [GPU] Epoch 10: b norm = 1.0217, w norm = 3.3134
# [GPU] Epoch 20: b norm = 1.2428, w norm = 4.0408
# [GPU] Epoch 30: b norm = 1.3187, w norm = 4.2790
# [GPU] Epoch 40: b norm = 1.3468, w norm = 4.3611
# [GPU] Epoch 50: b norm = 1.3575, w norm = 4.3902
# [GPU] Epoch 60: b norm = 1.3617, w norm = 4.4007
# [GPU] Epoch 70: b norm = 1.3633, w norm = 4.4046
# [GPU] Epoch 80: b norm = 1.3640, w norm = 4.4060
# [GPU] Epoch 90: b norm = 1.3642, w norm = 4.4065
# [GPU] Epoch 100: b norm = 1.3643, w norm = 4.4067
# [GPU] Epoch 110: b norm = 1.3644, w norm = 4.4068
# [GPU] Epoch 120: b norm = 1.3644, w norm = 4.4068
# [GPU] Epoch 130: b norm = 1.3644, w norm = 4.4068
# [GPU] Epoch 140: b norm = 1.3644, w norm = 4.4068
# [GPU] Epoch 0: b norm = 0.2041, w norm = 0.6971
# [GPU] Epoch 10: b norm = 0.9223, w norm = 3.0364
# [GPU] Epoch 20: b norm = 1.1467, w norm = 3.7517
# [GPU] Epoch 30: b norm = 1.2367, w norm = 4.0128
# [GPU] Epoch 40: b norm = 1.2750, w norm = 4.1133
# [GPU] Epoch 50: b norm = 1.2917, w norm = 4.1531
# [GPU] Epoch 60: b norm = 1.2991, w norm = 4.1692
# [GPU] Epoch 70: b norm = 1.3024, w norm = 4.1758
# [GPU] Epoch 80: b norm = 1.3039, w norm = 4.1785
# [GPU] Epoch 90: b norm = 1.3045, w norm = 4.1797
# [GPU] Epoch 100: b norm = 1.3048, w norm = 4.1801
# [GPU] Epoch 110: b norm = 1.3050, w norm = 4.1803
# [GPU] Epoch 120: b norm = 1.3050, w norm = 4.1804
# [GPU] Epoch 130: b norm = 1.3050, w norm = 4.1805
# [GPU] Epoch 140: b norm = 1.3051, w norm = 4.1805
# [GPU] Epoch 0: b norm = 0.2249, w norm = 0.7179
# [GPU] Epoch 10: b norm = 1.0703, w norm = 3.4165
# [GPU] Epoch 20: b norm = 1.3004, w norm = 4.1670
# [GPU] Epoch 30: b norm = 1.3801, w norm = 4.4139
# [GPU] Epoch 40: b norm = 1.4097, w norm = 4.4992
# [GPU] Epoch 50: b norm = 1.4209, w norm = 4.5294
# [GPU] Epoch 60: b norm = 1.4253, w norm = 4.5403
# [GPU] Epoch 70: b norm = 1.4270, w norm = 4.5443
# [GPU] Epoch 80: b norm = 1.4277, w norm = 4.5457
# [GPU] Epoch 90: b norm = 1.4280, w norm = 4.5463
# [GPU] Epoch 100: b norm = 1.4281, w norm = 4.5465
# [GPU] Epoch 110: b norm = 1.4281, w norm = 4.5466
# [GPU] Epoch 120: b norm = 1.4281, w norm = 4.5466
# [GPU] Epoch 130: b norm = 1.4282, w norm = 4.5466
# [GPU] Epoch 140: b norm = 1.4282, w norm = 4.5466
# [GPU] Epoch 0: b norm = 0.2257, w norm = 0.7227
# [GPU] Epoch 10: b norm = 0.9669, w norm = 3.1295
# [GPU] Epoch 20: b norm = 1.2038, w norm = 3.8714
# [GPU] Epoch 30: b norm = 1.2997, w norm = 4.1418
# [GPU] Epoch 40: b norm = 1.3407, w norm = 4.2458
# [GPU] Epoch 50: b norm = 1.3587, w norm = 4.2870
# [GPU] Epoch 60: b norm = 1.3666, w norm = 4.3036
# [GPU] Epoch 70: b norm = 1.3701, w norm = 4.3104
# [GPU] Epoch 80: b norm = 1.3717, w norm = 4.3133
# [GPU] Epoch 90: b norm = 1.3724, w norm = 4.3145
# [GPU] Epoch 100: b norm = 1.3727, w norm = 4.3150
# [GPU] Epoch 110: b norm = 1.3729, w norm = 4.3152
# [GPU] Epoch 120: b norm = 1.3729, w norm = 4.3153
# [GPU] Epoch 130: b norm = 1.3730, w norm = 4.3153
# [GPU] Epoch 140: b norm = 1.3730, w norm = 4.3153
# [GPU] Epoch 0: b norm = 0.2347, w norm = 0.7654
# [GPU] Epoch 10: b norm = 1.1007, w norm = 3.4343
# [GPU] Epoch 20: b norm = 1.3333, w norm = 4.1614
# [GPU] Epoch 30: b norm = 1.4140, w norm = 4.4013
# [GPU] Epoch 40: b norm = 1.4440, w norm = 4.4844
# [GPU] Epoch 50: b norm = 1.4555, w norm = 4.5140
# [GPU] Epoch 60: b norm = 1.4600, w norm = 4.5246
# [GPU] Epoch 70: b norm = 1.4618, w norm = 4.5285
# [GPU] Epoch 80: b norm = 1.4625, w norm = 4.5299
# [GPU] Epoch 90: b norm = 1.4627, w norm = 4.5305
# [GPU] Epoch 100: b norm = 1.4628, w norm = 4.5307
# [GPU] Epoch 110: b norm = 1.4629, w norm = 4.5307
# [GPU] Epoch 120: b norm = 1.4629, w norm = 4.5308
# [GPU] Epoch 130: b norm = 1.4629, w norm = 4.5308
# [GPU] Epoch 140: b norm = 1.4629, w norm = 4.5308
# [GPU] Epoch 0: b norm = 0.2426, w norm = 0.7548
# [GPU] Epoch 10: b norm = 0.9900, w norm = 3.1162
# [GPU] Epoch 20: b norm = 1.2244, w norm = 3.8456
# [GPU] Epoch 30: b norm = 1.3193, w norm = 4.1133
# [GPU] Epoch 40: b norm = 1.3600, w norm = 4.2162
# [GPU] Epoch 50: b norm = 1.3778, w norm = 4.2568
# [GPU] Epoch 60: b norm = 1.3857, w norm = 4.2731
# [GPU] Epoch 70: b norm = 1.3893, w norm = 4.2797
# [GPU] Epoch 80: b norm = 1.3909, w norm = 4.2825
# [GPU] Epoch 90: b norm = 1.3916, w norm = 4.2836
# [GPU] Epoch 100: b norm = 1.3919, w norm = 4.2841
# [GPU] Epoch 110: b norm = 1.3920, w norm = 4.2843
# [GPU] Epoch 120: b norm = 1.3921, w norm = 4.2844
# [GPU] Epoch 130: b norm = 1.3921, w norm = 4.2844
# [GPU] Epoch 140: b norm = 1.3922, w norm = 4.2844
# [GPU] Epoch 0: b norm = 0.2254, w norm = 0.6986
# [GPU] Epoch 10: b norm = 1.0558, w norm = 3.3652
# [GPU] Epoch 20: b norm = 1.2823, w norm = 4.0958
# [GPU] Epoch 30: b norm = 1.3612, w norm = 4.3355
# [GPU] Epoch 40: b norm = 1.3907, w norm = 4.4181
# [GPU] Epoch 50: b norm = 1.4020, w norm = 4.4474
# [GPU] Epoch 60: b norm = 1.4064, w norm = 4.4580
# [GPU] Epoch 70: b norm = 1.4081, w norm = 4.4618
# [GPU] Epoch 80: b norm = 1.4088, w norm = 4.4632
# [GPU] Epoch 90: b norm = 1.4091, w norm = 4.4637
# [GPU] Epoch 100: b norm = 1.4092, w norm = 4.4639
# [GPU] Epoch 110: b norm = 1.4092, w norm = 4.4640
# [GPU] Epoch 120: b norm = 1.4093, w norm = 4.4640
# [GPU] Epoch 130: b norm = 1.4093, w norm = 4.4640
# [GPU] Epoch 140: b norm = 1.4093, w norm = 4.4640
# [GPU] Epoch 0: b norm = 0.2329, w norm = 0.7181
# [GPU] Epoch 10: b norm = 0.9566, w norm = 3.0704
# [GPU] Epoch 20: b norm = 1.1871, w norm = 3.7904
# [GPU] Epoch 30: b norm = 1.2809, w norm = 4.0534
# [GPU] Epoch 40: b norm = 1.3211, w norm = 4.1544
# [GPU] Epoch 50: b norm = 1.3388, w norm = 4.1943
# [GPU] Epoch 60: b norm = 1.3466, w norm = 4.2103
# [GPU] Epoch 70: b norm = 1.3501, w norm = 4.2169
# [GPU] Epoch 80: b norm = 1.3517, w norm = 4.2196
# [GPU] Epoch 90: b norm = 1.3524, w norm = 4.2207
# [GPU] Epoch 100: b norm = 1.3527, w norm = 4.2211
# [GPU] Epoch 110: b norm = 1.3529, w norm = 4.2213
# [GPU] Epoch 120: b norm = 1.3530, w norm = 4.2214
# [GPU] Epoch 130: b norm = 1.3530, w norm = 4.2215
# [GPU] Epoch 140: b norm = 1.3530, w norm = 4.2215

# %%
b_list = []
w_list = []

b_list_1 = []
w_list_1 = []

mse_list = []
mse_list_1 = []
for epoch in range(1,50):
    real_epoch = epoch * 1000
    x_= load_multi_samples(name = real_epoch, batch_size=5000, total_samples=100000)
    b_in, w_in = train_erasure_machine_torch(x_, N, epsilon=0.84, lr=0.1, epochs=150)
    b_in_1, w_in_1 = train_erasure_machine_torch(x_, N, epsilon=0.7, lr=0.1, epochs=150)

    b_list.append(b_in)
    w_list.append(w_in)
    b_list_1.append(b_in_1)
    w_list_1.append(w_in_1)

    mse_in = mse(w, w_in, b, b_in)
    mse_in_1 = mse(w, w_in_1, b, b_in_1)
    mse_list.append(mse_in)
    mse_list_1.append(mse_in_1)

np.save(f"b_list_100K.npy", np.array(b_list))
np.save(f"w_list_100K.npy", np.array(w_list))
np.save(f"b_list_1_100K.npy", np.array(b_list_1))
np.save(f"w_list_1_100K.npy", np.array(w_list_1))
np.save(f"mse_list_100K.npy", np.array(mse_list))
np.save(f"mse_list_1_100K.npy", np.array(mse_list_1))
# Out:
# [GPU] Epoch 0: b norm = 0.2840, w norm = 0.9363
# [GPU] Epoch 10: b norm = 1.2768, w norm = 3.3584
# [GPU] Epoch 20: b norm = 1.5299, w norm = 3.8755
# [GPU] Epoch 30: b norm = 1.6176, w norm = 4.0334
# [GPU] Epoch 40: b norm = 1.6504, w norm = 4.0850
# [GPU] Epoch 50: b norm = 1.6632, w norm = 4.1023
# [GPU] Epoch 60: b norm = 1.6682, w norm = 4.1083
# [GPU] Epoch 70: b norm = 1.6702, w norm = 4.1104
# [GPU] Epoch 80: b norm = 1.6710, w norm = 4.1111
# [GPU] Epoch 90: b norm = 1.6713, w norm = 4.1113
# [GPU] Epoch 100: b norm = 1.6714, w norm = 4.1114
# [GPU] Epoch 110: b norm = 1.6715, w norm = 4.1115
# [GPU] Epoch 120: b norm = 1.6715, w norm = 4.1115
# [GPU] Epoch 130: b norm = 1.6715, w norm = 4.1115
# [GPU] Epoch 140: b norm = 1.6715, w norm = 4.1115
# [GPU] Epoch 0: b norm = 0.2917, w norm = 0.9343
# [GPU] Epoch 10: b norm = 1.1214, w norm = 2.8410
# [GPU] Epoch 20: b norm = 1.3685, w norm = 3.3366
# [GPU] Epoch 30: b norm = 1.4677, w norm = 3.5048
# [GPU] Epoch 40: b norm = 1.5104, w norm = 3.5649
# [GPU] Epoch 50: b norm = 1.5294, w norm = 3.5870
# [GPU] Epoch 60: b norm = 1.5379, w norm = 3.5952
# [GPU] Epoch 70: b norm = 1.5418, w norm = 3.5984
# [GPU] Epoch 80: b norm = 1.5435, w norm = 3.5995
# [GPU] Epoch 90: b norm = 1.5443, w norm = 3.6000
# [GPU] Epoch 100: b norm = 1.5447, w norm = 3.6002
# [GPU] Epoch 110: b norm = 1.5448, w norm = 3.6002
# [GPU] Epoch 120: b norm = 1.5449, w norm = 3.6003
# [GPU] Epoch 130: b norm = 1.5450, w norm = 3.6003
# [GPU] Epoch 140: b norm = 1.5450, w norm = 3.6003
# [GPU] Epoch 0: b norm = 0.2285, w norm = 0.7267
# [GPU] Epoch 10: b norm = 1.0846, w norm = 3.1926
# [GPU] Epoch 20: b norm = 1.3133, w norm = 3.8463
# [GPU] Epoch 30: b norm = 1.3908, w norm = 4.0569
# [GPU] Epoch 40: b norm = 1.4191, w norm = 4.1284
# [GPU] Epoch 50: b norm = 1.4298, w norm = 4.1534
# [GPU] Epoch 60: b norm = 1.4339, w norm = 4.1623
# [GPU] Epoch 70: b norm = 1.4355, w norm = 4.1655
# [GPU] Epoch 80: b norm = 1.4362, w norm = 4.1667
# [GPU] Epoch 90: b norm = 1.4364, w norm = 4.1672
# [GPU] Epoch 100: b norm = 1.4365, w norm = 4.1673
# [GPU] Epoch 110: b norm = 1.4366, w norm = 4.1674
# [GPU] Epoch 120: b norm = 1.4366, w norm = 4.1674
# [GPU] Epoch 130: b norm = 1.4366, w norm = 4.1674
# [GPU] Epoch 140: b norm = 1.4366, w norm = 4.1674
# [GPU] Epoch 0: b norm = 0.2312, w norm = 0.7134
# [GPU] Epoch 10: b norm = 0.9754, w norm = 2.8724
# [GPU] Epoch 20: b norm = 1.1971, w norm = 3.5115
# [GPU] Epoch 30: b norm = 1.2823, w norm = 3.7382
# [GPU] Epoch 40: b norm = 1.3176, w norm = 3.8231
# [GPU] Epoch 50: b norm = 1.3326, w norm = 3.8559
# [GPU] Epoch 60: b norm = 1.3392, w norm = 3.8688
# [GPU] Epoch 70: b norm = 1.3420, w norm = 3.8739
# [GPU] Epoch 80: b norm = 1.3433, w norm = 3.8760
# [GPU] Epoch 90: b norm = 1.3438, w norm = 3.8769
# [GPU] Epoch 100: b norm = 1.3441, w norm = 3.8772
# [GPU] Epoch 110: b norm = 1.3442, w norm = 3.8774
# [GPU] Epoch 120: b norm = 1.3442, w norm = 3.8774
# [GPU] Epoch 130: b norm = 1.3443, w norm = 3.8775
# [GPU] Epoch 140: b norm = 1.3443, w norm = 3.8775
# [GPU] Epoch 0: b norm = 0.2120, w norm = 0.6813
# [GPU] Epoch 10: b norm = 1.0720, w norm = 3.1388
# [GPU] Epoch 20: b norm = 1.2960, w norm = 3.7767
# [GPU] Epoch 30: b norm = 1.3704, w norm = 3.9778
# [GPU] Epoch 40: b norm = 1.3972, w norm = 4.0450
# [GPU] Epoch 50: b norm = 1.4072, w norm = 4.0683
# [GPU] Epoch 60: b norm = 1.4111, w norm = 4.0765
# [GPU] Epoch 70: b norm = 1.4125, w norm = 4.0794
# [GPU] Epoch 80: b norm = 1.4131, w norm = 4.0805
# [GPU] Epoch 90: b norm = 1.4133, w norm = 4.0808
# [GPU] Epoch 100: b norm = 1.4134, w norm = 4.0810
# [GPU] Epoch 110: b norm = 1.4135, w norm = 4.0810
# [GPU] Epoch 120: b norm = 1.4135, w norm = 4.0811
# [GPU] Epoch 130: b norm = 1.4135, w norm = 4.0811
# [GPU] Epoch 140: b norm = 1.4135, w norm = 4.0811
# [GPU] Epoch 0: b norm = 0.2253, w norm = 0.6943
# [GPU] Epoch 10: b norm = 0.9635, w norm = 2.8219
# [GPU] Epoch 20: b norm = 1.1742, w norm = 3.4239
# [GPU] Epoch 30: b norm = 1.2533, w norm = 3.6321
# [GPU] Epoch 40: b norm = 1.2855, w norm = 3.7084
# [GPU] Epoch 50: b norm = 1.2991, w norm = 3.7373
# [GPU] Epoch 60: b norm = 1.3049, w norm = 3.7485
# [GPU] Epoch 70: b norm = 1.3075, w norm = 3.7529
# [GPU] Epoch 80: b norm = 1.3086, w norm = 3.7546
# [GPU] Epoch 90: b norm = 1.3091, w norm = 3.7553
# [GPU] Epoch 100: b norm = 1.3093, w norm = 3.7556
# [GPU] Epoch 110: b norm = 1.3094, w norm = 3.7557
# [GPU] Epoch 120: b norm = 1.3094, w norm = 3.7558
# [GPU] Epoch 130: b norm = 1.3095, w norm = 3.7558
# [GPU] Epoch 140: b norm = 1.3095, w norm = 3.7558
# [GPU] Epoch 0: b norm = 0.2219, w norm = 0.6820
# [GPU] Epoch 10: b norm = 1.0293, w norm = 3.1188
# [GPU] Epoch 20: b norm = 1.2350, w norm = 3.7574
# [GPU] Epoch 30: b norm = 1.3026, w norm = 3.9599
# [GPU] Epoch 40: b norm = 1.3268, w norm = 4.0280
# [GPU] Epoch 50: b norm = 1.3358, w norm = 4.0515
# [GPU] Epoch 60: b norm = 1.3392, w norm = 4.0599
# [GPU] Epoch 70: b norm = 1.3405, w norm = 4.0629
# [GPU] Epoch 80: b norm = 1.3410, w norm = 4.0639
# [GPU] Epoch 90: b norm = 1.3412, w norm = 4.0643
# [GPU] Epoch 100: b norm = 1.3413, w norm = 4.0645
# [GPU] Epoch 110: b norm = 1.3413, w norm = 4.0645
# [GPU] Epoch 120: b norm = 1.3414, w norm = 4.0646
# [GPU] Epoch 130: b norm = 1.3414, w norm = 4.0646
# [GPU] Epoch 140: b norm = 1.3414, w norm = 4.0646
# [GPU] Epoch 0: b norm = 0.2271, w norm = 0.6980
# [GPU] Epoch 10: b norm = 0.9154, w norm = 2.8131
# [GPU] Epoch 20: b norm = 1.1100, w norm = 3.4189
# [GPU] Epoch 30: b norm = 1.1826, w norm = 3.6298
# [GPU] Epoch 40: b norm = 1.2119, w norm = 3.7077
# [GPU] Epoch 50: b norm = 1.2241, w norm = 3.7373
# [GPU] Epoch 60: b norm = 1.2293, w norm = 3.7489
# [GPU] Epoch 70: b norm = 1.2315, w norm = 3.7535
# [GPU] Epoch 80: b norm = 1.2325, w norm = 3.7553
# [GPU] Epoch 90: b norm = 1.2329, w norm = 3.7561
# [GPU] Epoch 100: b norm = 1.2331, w norm = 3.7564
# [GPU] Epoch 110: b norm = 1.2332, w norm = 3.7565
# [GPU] Epoch 120: b norm = 1.2332, w norm = 3.7565
# [GPU] Epoch 130: b norm = 1.2332, w norm = 3.7566
# [GPU] Epoch 140: b norm = 1.2332, w norm = 3.7566
# [GPU] Epoch 0: b norm = 0.2181, w norm = 0.6606
# [GPU] Epoch 10: b norm = 1.0051, w norm = 3.1275
# [GPU] Epoch 20: b norm = 1.2085, w norm = 3.7889
# [GPU] Epoch 30: b norm = 1.2754, w norm = 3.9990
# [GPU] Epoch 40: b norm = 1.2993, w norm = 4.0697
# [GPU] Epoch 50: b norm = 1.3081, w norm = 4.0942
# [GPU] Epoch 60: b norm = 1.3114, w norm = 4.1028
# [GPU] Epoch 70: b norm = 1.3127, w norm = 4.1059
# [GPU] Epoch 80: b norm = 1.3132, w norm = 4.1071
# [GPU] Epoch 90: b norm = 1.3134, w norm = 4.1075
# [GPU] Epoch 100: b norm = 1.3135, w norm = 4.1076
# [GPU] Epoch 110: b norm = 1.3135, w norm = 4.1077
# [GPU] Epoch 120: b norm = 1.3135, w norm = 4.1077
# [GPU] Epoch 130: b norm = 1.3135, w norm = 4.1077
# [GPU] Epoch 140: b norm = 1.3135, w norm = 4.1077
# [GPU] Epoch 0: b norm = 0.2100, w norm = 0.6893
# [GPU] Epoch 10: b norm = 0.8945, w norm = 2.8438
# [GPU] Epoch 20: b norm = 1.0922, w norm = 3.4639
# [GPU] Epoch 30: b norm = 1.1668, w norm = 3.6790
# [GPU] Epoch 40: b norm = 1.1971, w norm = 3.7581
# [GPU] Epoch 50: b norm = 1.2098, w norm = 3.7883
# [GPU] Epoch 60: b norm = 1.2152, w norm = 3.8000
# [GPU] Epoch 70: b norm = 1.2175, w norm = 3.8047
# [GPU] Epoch 80: b norm = 1.2185, w norm = 3.8065
# [GPU] Epoch 90: b norm = 1.2190, w norm = 3.8073
# [GPU] Epoch 100: b norm = 1.2192, w norm = 3.8076
# [GPU] Epoch 110: b norm = 1.2193, w norm = 3.8077
# [GPU] Epoch 120: b norm = 1.2193, w norm = 3.8078
# [GPU] Epoch 130: b norm = 1.2193, w norm = 3.8078
# [GPU] Epoch 140: b norm = 1.2193, w norm = 3.8078
# [GPU] Epoch 0: b norm = 0.2270, w norm = 0.7235
# [GPU] Epoch 10: b norm = 1.0567, w norm = 3.1918
# [GPU] Epoch 20: b norm = 1.2742, w norm = 3.8401
# [GPU] Epoch 30: b norm = 1.3478, w norm = 4.0473
# [GPU] Epoch 40: b norm = 1.3747, w norm = 4.1173
# [GPU] Epoch 50: b norm = 1.3849, w norm = 4.1416
# [GPU] Epoch 60: b norm = 1.3889, w norm = 4.1503
# [GPU] Epoch 70: b norm = 1.3904, w norm = 4.1533
# [GPU] Epoch 80: b norm = 1.3910, w norm = 4.1545
# [GPU] Epoch 90: b norm = 1.3912, w norm = 4.1549
# [GPU] Epoch 100: b norm = 1.3913, w norm = 4.1550
# [GPU] Epoch 110: b norm = 1.3914, w norm = 4.1551
# [GPU] Epoch 120: b norm = 1.3914, w norm = 4.1551
# [GPU] Epoch 130: b norm = 1.3914, w norm = 4.1551
# [GPU] Epoch 140: b norm = 1.3914, w norm = 4.1551
# [GPU] Epoch 0: b norm = 0.2201, w norm = 0.7199
# [GPU] Epoch 10: b norm = 0.9396, w norm = 2.8708
# [GPU] Epoch 20: b norm = 1.1580, w norm = 3.4957
# [GPU] Epoch 30: b norm = 1.2436, w norm = 3.7154
# [GPU] Epoch 40: b norm = 1.2796, w norm = 3.7969
# [GPU] Epoch 50: b norm = 1.2951, w norm = 3.8281
# [GPU] Epoch 60: b norm = 1.3019, w norm = 3.8403
# [GPU] Epoch 70: b norm = 1.3049, w norm = 3.8452
# [GPU] Epoch 80: b norm = 1.3063, w norm = 3.8471
# [GPU] Epoch 90: b norm = 1.3069, w norm = 3.8479
# [GPU] Epoch 100: b norm = 1.3072, w norm = 3.8482
# [GPU] Epoch 110: b norm = 1.3073, w norm = 3.8483
# [GPU] Epoch 120: b norm = 1.3073, w norm = 3.8484
# [GPU] Epoch 130: b norm = 1.3074, w norm = 3.8484
# [GPU] Epoch 140: b norm = 1.3074, w norm = 3.8484
# [GPU] Epoch 0: b norm = 0.2277, w norm = 0.6878
# [GPU] Epoch 10: b norm = 1.0531, w norm = 3.1346
# [GPU] Epoch 20: b norm = 1.2714, w norm = 3.7828
# [GPU] Epoch 30: b norm = 1.3440, w norm = 3.9881
# [GPU] Epoch 40: b norm = 1.3701, w norm = 4.0568
# [GPU] Epoch 50: b norm = 1.3798, w norm = 4.0805
# [GPU] Epoch 60: b norm = 1.3835, w norm = 4.0888
# [GPU] Epoch 70: b norm = 1.3850, w norm = 4.0918
# [GPU] Epoch 80: b norm = 1.3855, w norm = 4.0929
# [GPU] Epoch 90: b norm = 1.3857, w norm = 4.0933
# [GPU] Epoch 100: b norm = 1.3858, w norm = 4.0934
# [GPU] Epoch 110: b norm = 1.3859, w norm = 4.0935
# [GPU] Epoch 120: b norm = 1.3859, w norm = 4.0935
# [GPU] Epoch 130: b norm = 1.3859, w norm = 4.0935
# [GPU] Epoch 140: b norm = 1.3859, w norm = 4.0935
# [GPU] Epoch 0: b norm = 0.2149, w norm = 0.6877
# [GPU] Epoch 10: b norm = 0.9424, w norm = 2.8282
# [GPU] Epoch 20: b norm = 1.1526, w norm = 3.4401
# [GPU] Epoch 30: b norm = 1.2315, w norm = 3.6507
# [GPU] Epoch 40: b norm = 1.2636, w norm = 3.7274
# [GPU] Epoch 50: b norm = 1.2772, w norm = 3.7564
# [GPU] Epoch 60: b norm = 1.2830, w norm = 3.7675
# [GPU] Epoch 70: b norm = 1.2855, w norm = 3.7719
# [GPU] Epoch 80: b norm = 1.2866, w norm = 3.7737
# [GPU] Epoch 90: b norm = 1.2871, w norm = 3.7744
# [GPU] Epoch 100: b norm = 1.2873, w norm = 3.7747
# [GPU] Epoch 110: b norm = 1.2874, w norm = 3.7748
# [GPU] Epoch 120: b norm = 1.2874, w norm = 3.7748
# [GPU] Epoch 130: b norm = 1.2874, w norm = 3.7749
# [GPU] Epoch 140: b norm = 1.2874, w norm = 3.7749
# [GPU] Epoch 0: b norm = 0.2120, w norm = 0.6559
# [GPU] Epoch 10: b norm = 1.0061, w norm = 3.1328
# [GPU] Epoch 20: b norm = 1.2148, w norm = 3.7966
# [GPU] Epoch 30: b norm = 1.2841, w norm = 4.0076
# [GPU] Epoch 40: b norm = 1.3090, w norm = 4.0786
# [GPU] Epoch 50: b norm = 1.3183, w norm = 4.1032
# [GPU] Epoch 60: b norm = 1.3219, w norm = 4.1119
# [GPU] Epoch 70: b norm = 1.3232, w norm = 4.1150
# [GPU] Epoch 80: b norm = 1.3238, w norm = 4.1161
# [GPU] Epoch 90: b norm = 1.3240, w norm = 4.1165
# [GPU] Epoch 100: b norm = 1.3241, w norm = 4.1167
# [GPU] Epoch 110: b norm = 1.3241, w norm = 4.1167
# [GPU] Epoch 120: b norm = 1.3241, w norm = 4.1168
# [GPU] Epoch 130: b norm = 1.3241, w norm = 4.1168
# [GPU] Epoch 140: b norm = 1.3241, w norm = 4.1168
# [GPU] Epoch 0: b norm = 0.1987, w norm = 0.6615
# [GPU] Epoch 10: b norm = 0.9009, w norm = 2.8464
# [GPU] Epoch 20: b norm = 1.1029, w norm = 3.4764
# [GPU] Epoch 30: b norm = 1.1787, w norm = 3.6960
# [GPU] Epoch 40: b norm = 1.2093, w norm = 3.7770
# [GPU] Epoch 50: b norm = 1.2221, w norm = 3.8078
# [GPU] Epoch 60: b norm = 1.2275, w norm = 3.8198
# [GPU] Epoch 70: b norm = 1.2298, w norm = 3.8246
# [GPU] Epoch 80: b norm = 1.2308, w norm = 3.8265
# [GPU] Epoch 90: b norm = 1.2312, w norm = 3.8272
# [GPU] Epoch 100: b norm = 1.2314, w norm = 3.8276
# [GPU] Epoch 110: b norm = 1.2315, w norm = 3.8277
# [GPU] Epoch 120: b norm = 1.2315, w norm = 3.8277
# [GPU] Epoch 130: b norm = 1.2315, w norm = 3.8278
# [GPU] Epoch 140: b norm = 1.2315, w norm = 3.8278
# [GPU] Epoch 0: b norm = 0.2376, w norm = 0.7189
# [GPU] Epoch 10: b norm = 1.0880, w norm = 3.2310
# [GPU] Epoch 20: b norm = 1.3148, w norm = 3.8923
# [GPU] Epoch 30: b norm = 1.3922, w norm = 4.1035
# [GPU] Epoch 40: b norm = 1.4207, w norm = 4.1747
# [GPU] Epoch 50: b norm = 1.4315, w norm = 4.1994
# [GPU] Epoch 60: b norm = 1.4357, w norm = 4.2081
# [GPU] Epoch 70: b norm = 1.4374, w norm = 4.2113
# [GPU] Epoch 80: b norm = 1.4380, w norm = 4.2124
# [GPU] Epoch 90: b norm = 1.4383, w norm = 4.2128
# [GPU] Epoch 100: b norm = 1.4384, w norm = 4.2130
# [GPU] Epoch 110: b norm = 1.4384, w norm = 4.2130
# [GPU] Epoch 120: b norm = 1.4384, w norm = 4.2130
# [GPU] Epoch 130: b norm = 1.4384, w norm = 4.2130
# [GPU] Epoch 140: b norm = 1.4384, w norm = 4.2130
# [GPU] Epoch 0: b norm = 0.2467, w norm = 0.7281
# [GPU] Epoch 10: b norm = 0.9790, w norm = 2.9123
# [GPU] Epoch 20: b norm = 1.2041, w norm = 3.5455
# [GPU] Epoch 30: b norm = 1.2930, w norm = 3.7664
# [GPU] Epoch 40: b norm = 1.3304, w norm = 3.8478
# [GPU] Epoch 50: b norm = 1.3466, w norm = 3.8787
# [GPU] Epoch 60: b norm = 1.3537, w norm = 3.8907
# [GPU] Epoch 70: b norm = 1.3569, w norm = 3.8954
# [GPU] Epoch 80: b norm = 1.3583, w norm = 3.8973
# [GPU] Epoch 90: b norm = 1.3589, w norm = 3.8981
# [GPU] Epoch 100: b norm = 1.3592, w norm = 3.8984
# [GPU] Epoch 110: b norm = 1.3593, w norm = 3.8985
# [GPU] Epoch 120: b norm = 1.3593, w norm = 3.8986
# [GPU] Epoch 130: b norm = 1.3594, w norm = 3.8986
# [GPU] Epoch 140: b norm = 1.3594, w norm = 3.8986
# [GPU] Epoch 0: b norm = 0.2006, w norm = 0.6538
# [GPU] Epoch 10: b norm = 0.9547, w norm = 3.0747
# [GPU] Epoch 20: b norm = 1.1603, w norm = 3.7407
# [GPU] Epoch 30: b norm = 1.2304, w norm = 3.9548
# [GPU] Epoch 40: b norm = 1.2561, w norm = 4.0273
# [GPU] Epoch 50: b norm = 1.2659, w norm = 4.0525
# [GPU] Epoch 60: b norm = 1.2696, w norm = 4.0614
# [GPU] Epoch 70: b norm = 1.2710, w norm = 4.0646
# [GPU] Epoch 80: b norm = 1.2716, w norm = 4.0658
# [GPU] Epoch 90: b norm = 1.2718, w norm = 4.0662
# [GPU] Epoch 100: b norm = 1.2719, w norm = 4.0664
# [GPU] Epoch 110: b norm = 1.2719, w norm = 4.0664
# [GPU] Epoch 120: b norm = 1.2720, w norm = 4.0665
# [GPU] Epoch 130: b norm = 1.2720, w norm = 4.0665
# [GPU] Epoch 140: b norm = 1.2720, w norm = 4.0665
# [GPU] Epoch 0: b norm = 0.1940, w norm = 0.6486
# [GPU] Epoch 10: b norm = 0.8664, w norm = 2.8106
# [GPU] Epoch 20: b norm = 1.0723, w norm = 3.4484
# [GPU] Epoch 30: b norm = 1.1526, w norm = 3.6709
# [GPU] Epoch 40: b norm = 1.1858, w norm = 3.7528
# [GPU] Epoch 50: b norm = 1.1999, w norm = 3.7840
# [GPU] Epoch 60: b norm = 1.2060, w norm = 3.7961
# [GPU] Epoch 70: b norm = 1.2086, w norm = 3.8008
# [GPU] Epoch 80: b norm = 1.2098, w norm = 3.8028
# [GPU] Epoch 90: b norm = 1.2103, w norm = 3.8035
# [GPU] Epoch 100: b norm = 1.2105, w norm = 3.8038
# [GPU] Epoch 110: b norm = 1.2106, w norm = 3.8040
# [GPU] Epoch 120: b norm = 1.2107, w norm = 3.8040
# [GPU] Epoch 130: b norm = 1.2107, w norm = 3.8041
# [GPU] Epoch 140: b norm = 1.2107, w norm = 3.8041
# [GPU] Epoch 0: b norm = 0.1886, w norm = 0.6370
# [GPU] Epoch 10: b norm = 0.9523, w norm = 3.0461
# [GPU] Epoch 20: b norm = 1.1653, w norm = 3.7230
# [GPU] Epoch 30: b norm = 1.2383, w norm = 3.9423
# [GPU] Epoch 40: b norm = 1.2650, w norm = 4.0167
# [GPU] Epoch 50: b norm = 1.2751, w norm = 4.0427
# [GPU] Epoch 60: b norm = 1.2790, w norm = 4.0519
# [GPU] Epoch 70: b norm = 1.2805, w norm = 4.0552
# [GPU] Epoch 80: b norm = 1.2811, w norm = 4.0564
# [GPU] Epoch 90: b norm = 1.2813, w norm = 4.0568
# [GPU] Epoch 100: b norm = 1.2814, w norm = 4.0570
# [GPU] Epoch 110: b norm = 1.2815, w norm = 4.0571
# [GPU] Epoch 120: b norm = 1.2815, w norm = 4.0571
# [GPU] Epoch 130: b norm = 1.2815, w norm = 4.0571
# [GPU] Epoch 140: b norm = 1.2815, w norm = 4.0571
# [GPU] Epoch 0: b norm = 0.2097, w norm = 0.6417
# [GPU] Epoch 10: b norm = 0.8805, w norm = 2.8026
# [GPU] Epoch 20: b norm = 1.0872, w norm = 3.4539
# [GPU] Epoch 30: b norm = 1.1669, w norm = 3.6826
# [GPU] Epoch 40: b norm = 1.1995, w norm = 3.7671
# [GPU] Epoch 50: b norm = 1.2132, w norm = 3.7992
# [GPU] Epoch 60: b norm = 1.2191, w norm = 3.8117
# [GPU] Epoch 70: b norm = 1.2217, w norm = 3.8166
# [GPU] Epoch 80: b norm = 1.2228, w norm = 3.8186
# [GPU] Epoch 90: b norm = 1.2233, w norm = 3.8194
# [GPU] Epoch 100: b norm = 1.2235, w norm = 3.8197
# [GPU] Epoch 110: b norm = 1.2236, w norm = 3.8198
# [GPU] Epoch 120: b norm = 1.2236, w norm = 3.8199
# [GPU] Epoch 130: b norm = 1.2236, w norm = 3.8199
# [GPU] Epoch 140: b norm = 1.2237, w norm = 3.8199
# [GPU] Epoch 0: b norm = 0.2030, w norm = 0.6757
# [GPU] Epoch 10: b norm = 0.9902, w norm = 3.1402
# [GPU] Epoch 20: b norm = 1.2024, w norm = 3.8171
# [GPU] Epoch 30: b norm = 1.2750, w norm = 4.0364
# [GPU] Epoch 40: b norm = 1.3017, w norm = 4.1110
# [GPU] Epoch 50: b norm = 1.3118, w norm = 4.1371
# [GPU] Epoch 60: b norm = 1.3157, w norm = 4.1464
# [GPU] Epoch 70: b norm = 1.3172, w norm = 4.1497
# [GPU] Epoch 80: b norm = 1.3178, w norm = 4.1510
# [GPU] Epoch 90: b norm = 1.3180, w norm = 4.1514
# [GPU] Epoch 100: b norm = 1.3181, w norm = 4.1516
# [GPU] Epoch 110: b norm = 1.3182, w norm = 4.1516
# [GPU] Epoch 120: b norm = 1.3182, w norm = 4.1517
# [GPU] Epoch 130: b norm = 1.3182, w norm = 4.1517
# [GPU] Epoch 140: b norm = 1.3182, w norm = 4.1517
# [GPU] Epoch 0: b norm = 0.2256, w norm = 0.6794
# [GPU] Epoch 10: b norm = 0.9005, w norm = 2.8663
# [GPU] Epoch 20: b norm = 1.1107, w norm = 3.5222
# [GPU] Epoch 30: b norm = 1.1937, w norm = 3.7538
# [GPU] Epoch 40: b norm = 1.2283, w norm = 3.8397
# [GPU] Epoch 50: b norm = 1.2431, w norm = 3.8725
# [GPU] Epoch 60: b norm = 1.2496, w norm = 3.8853
# [GPU] Epoch 70: b norm = 1.2524, w norm = 3.8904
# [GPU] Epoch 80: b norm = 1.2536, w norm = 3.8924
# [GPU] Epoch 90: b norm = 1.2542, w norm = 3.8932
# [GPU] Epoch 100: b norm = 1.2544, w norm = 3.8935
# [GPU] Epoch 110: b norm = 1.2545, w norm = 3.8937
# [GPU] Epoch 120: b norm = 1.2546, w norm = 3.8937
# [GPU] Epoch 130: b norm = 1.2546, w norm = 3.8938
# [GPU] Epoch 140: b norm = 1.2546, w norm = 3.8938
# [GPU] Epoch 0: b norm = 0.2143, w norm = 0.6849
# [GPU] Epoch 10: b norm = 0.9865, w norm = 3.1244
# [GPU] Epoch 20: b norm = 1.1858, w norm = 3.7838
# [GPU] Epoch 30: b norm = 1.2527, w norm = 3.9972
# [GPU] Epoch 40: b norm = 1.2770, w norm = 4.0698
# [GPU] Epoch 50: b norm = 1.2861, w norm = 4.0953
# [GPU] Epoch 60: b norm = 1.2896, w norm = 4.1043
# [GPU] Epoch 70: b norm = 1.2910, w norm = 4.1076
# [GPU] Epoch 80: b norm = 1.2915, w norm = 4.1088
# [GPU] Epoch 90: b norm = 1.2917, w norm = 4.1092
# [GPU] Epoch 100: b norm = 1.2918, w norm = 4.1094
# [GPU] Epoch 110: b norm = 1.2918, w norm = 4.1095
# [GPU] Epoch 120: b norm = 1.2918, w norm = 4.1095
# [GPU] Epoch 130: b norm = 1.2919, w norm = 4.1095
# [GPU] Epoch 140: b norm = 1.2919, w norm = 4.1095
# [GPU] Epoch 0: b norm = 0.2079, w norm = 0.6866
# [GPU] Epoch 10: b norm = 0.8785, w norm = 2.8371
# [GPU] Epoch 20: b norm = 1.0742, w norm = 3.4807
# [GPU] Epoch 30: b norm = 1.1495, w norm = 3.7089
# [GPU] Epoch 40: b norm = 1.1805, w norm = 3.7940
# [GPU] Epoch 50: b norm = 1.1935, w norm = 3.8266
# [GPU] Epoch 60: b norm = 1.1991, w norm = 3.8394
# [GPU] Epoch 70: b norm = 1.2015, w norm = 3.8445
# [GPU] Epoch 80: b norm = 1.2026, w norm = 3.8465
# [GPU] Epoch 90: b norm = 1.2031, w norm = 3.8474
# [GPU] Epoch 100: b norm = 1.2033, w norm = 3.8477
# [GPU] Epoch 110: b norm = 1.2033, w norm = 3.8479
# [GPU] Epoch 120: b norm = 1.2034, w norm = 3.8479
# [GPU] Epoch 130: b norm = 1.2034, w norm = 3.8479
# [GPU] Epoch 140: b norm = 1.2034, w norm = 3.8480
# [GPU] Epoch 0: b norm = 0.2121, w norm = 0.6913
# [GPU] Epoch 10: b norm = 1.0618, w norm = 3.2214
# [GPU] Epoch 20: b norm = 1.2899, w norm = 3.8896
# [GPU] Epoch 30: b norm = 1.3668, w norm = 4.1022
# [GPU] Epoch 40: b norm = 1.3948, w norm = 4.1738
# [GPU] Epoch 50: b norm = 1.4054, w norm = 4.1988
# [GPU] Epoch 60: b norm = 1.4095, w norm = 4.2077
# [GPU] Epoch 70: b norm = 1.4111, w norm = 4.2109
# [GPU] Epoch 80: b norm = 1.4117, w norm = 4.2120
# [GPU] Epoch 90: b norm = 1.4120, w norm = 4.2125
# [GPU] Epoch 100: b norm = 1.4121, w norm = 4.2126
# [GPU] Epoch 110: b norm = 1.4121, w norm = 4.2127
# [GPU] Epoch 120: b norm = 1.4121, w norm = 4.2127
# [GPU] Epoch 130: b norm = 1.4121, w norm = 4.2127
# [GPU] Epoch 140: b norm = 1.4121, w norm = 4.2127
# [GPU] Epoch 0: b norm = 0.2251, w norm = 0.7010
# [GPU] Epoch 10: b norm = 0.9624, w norm = 2.9143
# [GPU] Epoch 20: b norm = 1.1819, w norm = 3.5516
# [GPU] Epoch 30: b norm = 1.2673, w norm = 3.7757
# [GPU] Epoch 40: b norm = 1.3032, w norm = 3.8591
# [GPU] Epoch 50: b norm = 1.3188, w norm = 3.8911
# [GPU] Epoch 60: b norm = 1.3256, w norm = 3.9036
# [GPU] Epoch 70: b norm = 1.3286, w norm = 3.9086
# [GPU] Epoch 80: b norm = 1.3300, w norm = 3.9106
# [GPU] Epoch 90: b norm = 1.3306, w norm = 3.9114
# [GPU] Epoch 100: b norm = 1.3308, w norm = 3.9117
# [GPU] Epoch 110: b norm = 1.3310, w norm = 3.9119
# [GPU] Epoch 120: b norm = 1.3310, w norm = 3.9119
# [GPU] Epoch 130: b norm = 1.3310, w norm = 3.9119
# [GPU] Epoch 140: b norm = 1.3311, w norm = 3.9119
# [GPU] Epoch 0: b norm = 0.2153, w norm = 0.7168
# [GPU] Epoch 10: b norm = 1.0245, w norm = 3.1903
# [GPU] Epoch 20: b norm = 1.2434, w norm = 3.8609
# [GPU] Epoch 30: b norm = 1.3183, w norm = 4.0773
# [GPU] Epoch 40: b norm = 1.3457, w norm = 4.1506
# [GPU] Epoch 50: b norm = 1.3560, w norm = 4.1761
# [GPU] Epoch 60: b norm = 1.3600, w norm = 4.1852
# [GPU] Epoch 70: b norm = 1.3616, w norm = 4.1884
# [GPU] Epoch 80: b norm = 1.3622, w norm = 4.1896
# [GPU] Epoch 90: b norm = 1.3624, w norm = 4.1900
# [GPU] Epoch 100: b norm = 1.3625, w norm = 4.1902
# [GPU] Epoch 110: b norm = 1.3625, w norm = 4.1902
# [GPU] Epoch 120: b norm = 1.3626, w norm = 4.1903
# [GPU] Epoch 130: b norm = 1.3626, w norm = 4.1903
# [GPU] Epoch 140: b norm = 1.3626, w norm = 4.1903
# [GPU] Epoch 0: b norm = 0.2171, w norm = 0.6955
# [GPU] Epoch 10: b norm = 0.9268, w norm = 2.8904
# [GPU] Epoch 20: b norm = 1.1430, w norm = 3.5436
# [GPU] Epoch 30: b norm = 1.2269, w norm = 3.7728
# [GPU] Epoch 40: b norm = 1.2615, w norm = 3.8574
# [GPU] Epoch 50: b norm = 1.2763, w norm = 3.8896
# [GPU] Epoch 60: b norm = 1.2826, w norm = 3.9021
# [GPU] Epoch 70: b norm = 1.2854, w norm = 3.9070
# [GPU] Epoch 80: b norm = 1.2866, w norm = 3.9090
# [GPU] Epoch 90: b norm = 1.2872, w norm = 3.9098
# [GPU] Epoch 100: b norm = 1.2874, w norm = 3.9101
# [GPU] Epoch 110: b norm = 1.2875, w norm = 3.9103
# [GPU] Epoch 120: b norm = 1.2876, w norm = 3.9103
# [GPU] Epoch 130: b norm = 1.2876, w norm = 3.9103
# [GPU] Epoch 140: b norm = 1.2876, w norm = 3.9104
# [GPU] Epoch 0: b norm = 0.1898, w norm = 0.6501
# [GPU] Epoch 10: b norm = 0.9793, w norm = 3.1505
# [GPU] Epoch 20: b norm = 1.1980, w norm = 3.8401
# [GPU] Epoch 30: b norm = 1.2729, w norm = 4.0625
# [GPU] Epoch 40: b norm = 1.3004, w norm = 4.1378
# [GPU] Epoch 50: b norm = 1.3109, w norm = 4.1641
# [GPU] Epoch 60: b norm = 1.3149, w norm = 4.1734
# [GPU] Epoch 70: b norm = 1.3164, w norm = 4.1767
# [GPU] Epoch 80: b norm = 1.3170, w norm = 4.1779
# [GPU] Epoch 90: b norm = 1.3173, w norm = 4.1784
# [GPU] Epoch 100: b norm = 1.3174, w norm = 4.1785
# [GPU] Epoch 110: b norm = 1.3174, w norm = 4.1786
# [GPU] Epoch 120: b norm = 1.3174, w norm = 4.1786
# [GPU] Epoch 130: b norm = 1.3174, w norm = 4.1786
# [GPU] Epoch 140: b norm = 1.3174, w norm = 4.1786
# [GPU] Epoch 0: b norm = 0.2073, w norm = 0.6463
# [GPU] Epoch 10: b norm = 0.8979, w norm = 2.8830
# [GPU] Epoch 20: b norm = 1.1116, w norm = 3.5485
# [GPU] Epoch 30: b norm = 1.1951, w norm = 3.7814
# [GPU] Epoch 40: b norm = 1.2298, w norm = 3.8671
# [GPU] Epoch 50: b norm = 1.2447, w norm = 3.8997
# [GPU] Epoch 60: b norm = 1.2511, w norm = 3.9123
# [GPU] Epoch 70: b norm = 1.2539, w norm = 3.9173
# [GPU] Epoch 80: b norm = 1.2552, w norm = 3.9193
# [GPU] Epoch 90: b norm = 1.2557, w norm = 3.9201
# [GPU] Epoch 100: b norm = 1.2560, w norm = 3.9204
# [GPU] Epoch 110: b norm = 1.2561, w norm = 3.9206
# [GPU] Epoch 120: b norm = 1.2561, w norm = 3.9206
# [GPU] Epoch 130: b norm = 1.2562, w norm = 3.9207
# [GPU] Epoch 140: b norm = 1.2562, w norm = 3.9207
# [GPU] Epoch 0: b norm = 0.2111, w norm = 0.6680
# [GPU] Epoch 10: b norm = 0.9695, w norm = 3.1535
# [GPU] Epoch 20: b norm = 1.1673, w norm = 3.8352
# [GPU] Epoch 30: b norm = 1.2328, w norm = 4.0551
# [GPU] Epoch 40: b norm = 1.2563, w norm = 4.1299
# [GPU] Epoch 50: b norm = 1.2651, w norm = 4.1560
# [GPU] Epoch 60: b norm = 1.2684, w norm = 4.1653
# [GPU] Epoch 70: b norm = 1.2697, w norm = 4.1687
# [GPU] Epoch 80: b norm = 1.2702, w norm = 4.1699
# [GPU] Epoch 90: b norm = 1.2704, w norm = 4.1704
# [GPU] Epoch 100: b norm = 1.2705, w norm = 4.1705
# [GPU] Epoch 110: b norm = 1.2705, w norm = 4.1706
# [GPU] Epoch 120: b norm = 1.2705, w norm = 4.1706
# [GPU] Epoch 130: b norm = 1.2705, w norm = 4.1706
# [GPU] Epoch 140: b norm = 1.2705, w norm = 4.1706
# [GPU] Epoch 0: b norm = 0.1952, w norm = 0.6709
# [GPU] Epoch 10: b norm = 0.8626, w norm = 2.8821
# [GPU] Epoch 20: b norm = 1.0574, w norm = 3.5387
# [GPU] Epoch 30: b norm = 1.1317, w norm = 3.7706
# [GPU] Epoch 40: b norm = 1.1621, w norm = 3.8572
# [GPU] Epoch 50: b norm = 1.1749, w norm = 3.8906
# [GPU] Epoch 60: b norm = 1.1804, w norm = 3.9037
# [GPU] Epoch 70: b norm = 1.1827, w norm = 3.9090
# [GPU] Epoch 80: b norm = 1.1837, w norm = 3.9111
# [GPU] Epoch 90: b norm = 1.1842, w norm = 3.9120
# [GPU] Epoch 100: b norm = 1.1844, w norm = 3.9123
# [GPU] Epoch 110: b norm = 1.1845, w norm = 3.9125
# [GPU] Epoch 120: b norm = 1.1845, w norm = 3.9125
# [GPU] Epoch 130: b norm = 1.1845, w norm = 3.9126
# [GPU] Epoch 140: b norm = 1.1845, w norm = 3.9126
# [GPU] Epoch 0: b norm = 0.2225, w norm = 0.6618
# [GPU] Epoch 10: b norm = 1.0194, w norm = 3.1224
# [GPU] Epoch 20: b norm = 1.2309, w norm = 3.7883
# [GPU] Epoch 30: b norm = 1.3022, w norm = 4.0022
# [GPU] Epoch 40: b norm = 1.3281, w norm = 4.0746
# [GPU] Epoch 50: b norm = 1.3379, w norm = 4.0998
# [GPU] Epoch 60: b norm = 1.3417, w norm = 4.1087
# [GPU] Epoch 70: b norm = 1.3431, w norm = 4.1120
# [GPU] Epoch 80: b norm = 1.3437, w norm = 4.1131
# [GPU] Epoch 90: b norm = 1.3439, w norm = 4.1135
# [GPU] Epoch 100: b norm = 1.3440, w norm = 4.1137
# [GPU] Epoch 110: b norm = 1.3440, w norm = 4.1138
# [GPU] Epoch 120: b norm = 1.3441, w norm = 4.1138
# [GPU] Epoch 130: b norm = 1.3441, w norm = 4.1138
# [GPU] Epoch 140: b norm = 1.3441, w norm = 4.1138
# [GPU] Epoch 0: b norm = 0.2087, w norm = 0.6762
# [GPU] Epoch 10: b norm = 0.9105, w norm = 2.8428
# [GPU] Epoch 20: b norm = 1.1218, w norm = 3.4843
# [GPU] Epoch 30: b norm = 1.2036, w norm = 3.7103
# [GPU] Epoch 40: b norm = 1.2373, w norm = 3.7941
# [GPU] Epoch 50: b norm = 1.2517, w norm = 3.8262
# [GPU] Epoch 60: b norm = 1.2579, w norm = 3.8387
# [GPU] Epoch 70: b norm = 1.2607, w norm = 3.8436
# [GPU] Epoch 80: b norm = 1.2618, w norm = 3.8456
# [GPU] Epoch 90: b norm = 1.2624, w norm = 3.8464
# [GPU] Epoch 100: b norm = 1.2626, w norm = 3.8468
# [GPU] Epoch 110: b norm = 1.2627, w norm = 3.8469
# [GPU] Epoch 120: b norm = 1.2628, w norm = 3.8470
# [GPU] Epoch 130: b norm = 1.2628, w norm = 3.8470
# [GPU] Epoch 140: b norm = 1.2628, w norm = 3.8470
# [GPU] Epoch 0: b norm = 0.1880, w norm = 0.6834
# [GPU] Epoch 10: b norm = 0.9791, w norm = 3.1958
# [GPU] Epoch 20: b norm = 1.1868, w norm = 3.8758
# [GPU] Epoch 30: b norm = 1.2568, w norm = 4.0948
# [GPU] Epoch 40: b norm = 1.2823, w norm = 4.1692
# [GPU] Epoch 50: b norm = 1.2919, w norm = 4.1952
# [GPU] Epoch 60: b norm = 1.2956, w norm = 4.2045
# [GPU] Epoch 70: b norm = 1.2970, w norm = 4.2078
# [GPU] Epoch 80: b norm = 1.2976, w norm = 4.2091
# [GPU] Epoch 90: b norm = 1.2978, w norm = 4.2095
# [GPU] Epoch 100: b norm = 1.2979, w norm = 4.2097
# [GPU] Epoch 110: b norm = 1.2979, w norm = 4.2097
# [GPU] Epoch 120: b norm = 1.2979, w norm = 4.2098
# [GPU] Epoch 130: b norm = 1.2979, w norm = 4.2098
# [GPU] Epoch 140: b norm = 1.2979, w norm = 4.2098
# [GPU] Epoch 0: b norm = 0.2050, w norm = 0.6790
# [GPU] Epoch 10: b norm = 0.8800, w norm = 2.9070
# [GPU] Epoch 20: b norm = 1.0839, w norm = 3.5649
# [GPU] Epoch 30: b norm = 1.1634, w norm = 3.7968
# [GPU] Epoch 40: b norm = 1.1964, w norm = 3.8830
# [GPU] Epoch 50: b norm = 1.2103, w norm = 3.9161
# [GPU] Epoch 60: b norm = 1.2164, w norm = 3.9290
# [GPU] Epoch 70: b norm = 1.2190, w norm = 3.9342
# [GPU] Epoch 80: b norm = 1.2201, w norm = 3.9363
# [GPU] Epoch 90: b norm = 1.2206, w norm = 3.9371
# [GPU] Epoch 100: b norm = 1.2209, w norm = 3.9375
# [GPU] Epoch 110: b norm = 1.2210, w norm = 3.9376
# [GPU] Epoch 120: b norm = 1.2210, w norm = 3.9377
# [GPU] Epoch 130: b norm = 1.2210, w norm = 3.9377
# [GPU] Epoch 140: b norm = 1.2210, w norm = 3.9377
# [GPU] Epoch 0: b norm = 0.2360, w norm = 0.6951
# [GPU] Epoch 10: b norm = 1.0101, w norm = 3.1521
# [GPU] Epoch 20: b norm = 1.2204, w norm = 3.8268
# [GPU] Epoch 30: b norm = 1.2931, w norm = 4.0459
# [GPU] Epoch 40: b norm = 1.3200, w norm = 4.1205
# [GPU] Epoch 50: b norm = 1.3303, w norm = 4.1465
# [GPU] Epoch 60: b norm = 1.3342, w norm = 4.1557
# [GPU] Epoch 70: b norm = 1.3358, w norm = 4.1590
# [GPU] Epoch 80: b norm = 1.3364, w norm = 4.1602
# [GPU] Epoch 90: b norm = 1.3366, w norm = 4.1607
# [GPU] Epoch 100: b norm = 1.3367, w norm = 4.1608
# [GPU] Epoch 110: b norm = 1.3368, w norm = 4.1609
# [GPU] Epoch 120: b norm = 1.3368, w norm = 4.1609
# [GPU] Epoch 130: b norm = 1.3368, w norm = 4.1609
# [GPU] Epoch 140: b norm = 1.3368, w norm = 4.1609
# [GPU] Epoch 0: b norm = 0.2060, w norm = 0.7039
# [GPU] Epoch 10: b norm = 0.9066, w norm = 2.8753
# [GPU] Epoch 20: b norm = 1.1250, w norm = 3.5277
# [GPU] Epoch 30: b norm = 1.2118, w norm = 3.7573
# [GPU] Epoch 40: b norm = 1.2485, w norm = 3.8422
# [GPU] Epoch 50: b norm = 1.2644, w norm = 3.8746
# [GPU] Epoch 60: b norm = 1.2713, w norm = 3.8872
# [GPU] Epoch 70: b norm = 1.2744, w norm = 3.8921
# [GPU] Epoch 80: b norm = 1.2758, w norm = 3.8941
# [GPU] Epoch 90: b norm = 1.2764, w norm = 3.8949
# [GPU] Epoch 100: b norm = 1.2767, w norm = 3.8952
# [GPU] Epoch 110: b norm = 1.2768, w norm = 3.8954
# [GPU] Epoch 120: b norm = 1.2769, w norm = 3.8954
# [GPU] Epoch 130: b norm = 1.2769, w norm = 3.8955
# [GPU] Epoch 140: b norm = 1.2769, w norm = 3.8955
# [GPU] Epoch 0: b norm = 0.2064, w norm = 0.6944
# [GPU] Epoch 10: b norm = 1.0441, w norm = 3.2248
# [GPU] Epoch 20: b norm = 1.2698, w norm = 3.9093
# [GPU] Epoch 30: b norm = 1.3466, w norm = 4.1293
# [GPU] Epoch 40: b norm = 1.3746, w norm = 4.2037
# [GPU] Epoch 50: b norm = 1.3853, w norm = 4.2296
# [GPU] Epoch 60: b norm = 1.3894, w norm = 4.2388
# [GPU] Epoch 70: b norm = 1.3910, w norm = 4.2421
# [GPU] Epoch 80: b norm = 1.3916, w norm = 4.2433
# [GPU] Epoch 90: b norm = 1.3918, w norm = 4.2438
# [GPU] Epoch 100: b norm = 1.3919, w norm = 4.2439
# [GPU] Epoch 110: b norm = 1.3920, w norm = 4.2440
# [GPU] Epoch 120: b norm = 1.3920, w norm = 4.2440
# [GPU] Epoch 130: b norm = 1.3920, w norm = 4.2440
# [GPU] Epoch 140: b norm = 1.3920, w norm = 4.2440
# [GPU] Epoch 0: b norm = 0.2243, w norm = 0.6933
# [GPU] Epoch 10: b norm = 0.9461, w norm = 2.9312
# [GPU] Epoch 20: b norm = 1.1672, w norm = 3.5899
# [GPU] Epoch 30: b norm = 1.2539, w norm = 3.8220
# [GPU] Epoch 40: b norm = 1.2903, w norm = 3.9085
# [GPU] Epoch 50: b norm = 1.3059, w norm = 3.9417
# [GPU] Epoch 60: b norm = 1.3127, w norm = 3.9548
# [GPU] Epoch 70: b norm = 1.3157, w norm = 3.9600
# [GPU] Epoch 80: b norm = 1.3171, w norm = 3.9621
# [GPU] Epoch 90: b norm = 1.3177, w norm = 3.9629
# [GPU] Epoch 100: b norm = 1.3179, w norm = 3.9633
# [GPU] Epoch 110: b norm = 1.3180, w norm = 3.9634
# [GPU] Epoch 120: b norm = 1.3181, w norm = 3.9635
# [GPU] Epoch 130: b norm = 1.3181, w norm = 3.9635
# [GPU] Epoch 140: b norm = 1.3181, w norm = 3.9635
# [GPU] Epoch 0: b norm = 0.2266, w norm = 0.7009
# [GPU] Epoch 10: b norm = 1.0375, w norm = 3.1744
# [GPU] Epoch 20: b norm = 1.2550, w norm = 3.8469
# [GPU] Epoch 30: b norm = 1.3287, w norm = 4.0640
# [GPU] Epoch 40: b norm = 1.3557, w norm = 4.1376
# [GPU] Epoch 50: b norm = 1.3659, w norm = 4.1632
# [GPU] Epoch 60: b norm = 1.3698, w norm = 4.1723
# [GPU] Epoch 70: b norm = 1.3713, w norm = 4.1756
# [GPU] Epoch 80: b norm = 1.3719, w norm = 4.1768
# [GPU] Epoch 90: b norm = 1.3721, w norm = 4.1772
# [GPU] Epoch 100: b norm = 1.3722, w norm = 4.1774
# [GPU] Epoch 110: b norm = 1.3722, w norm = 4.1774
# [GPU] Epoch 120: b norm = 1.3722, w norm = 4.1775
# [GPU] Epoch 130: b norm = 1.3723, w norm = 4.1775
# [GPU] Epoch 140: b norm = 1.3723, w norm = 4.1775
# [GPU] Epoch 0: b norm = 0.2176, w norm = 0.6913
# [GPU] Epoch 10: b norm = 0.9313, w norm = 2.8855
# [GPU] Epoch 20: b norm = 1.1452, w norm = 3.5388
# [GPU] Epoch 30: b norm = 1.2273, w norm = 3.7684
# [GPU] Epoch 40: b norm = 1.2610, w norm = 3.8534
# [GPU] Epoch 50: b norm = 1.2753, w norm = 3.8858
# [GPU] Epoch 60: b norm = 1.2815, w norm = 3.8984
# [GPU] Epoch 70: b norm = 1.2841, w norm = 3.9034
# [GPU] Epoch 80: b norm = 1.2853, w norm = 3.9054
# [GPU] Epoch 90: b norm = 1.2858, w norm = 3.9062
# [GPU] Epoch 100: b norm = 1.2860, w norm = 3.9066
# [GPU] Epoch 110: b norm = 1.2861, w norm = 3.9067
# [GPU] Epoch 120: b norm = 1.2862, w norm = 3.9068
# [GPU] Epoch 130: b norm = 1.2862, w norm = 3.9068
# [GPU] Epoch 140: b norm = 1.2862, w norm = 3.9068
# [GPU] Epoch 0: b norm = 0.2159, w norm = 0.7168
# [GPU] Epoch 10: b norm = 1.0344, w norm = 3.2145
# [GPU] Epoch 20: b norm = 1.2511, w norm = 3.8838
# [GPU] Epoch 30: b norm = 1.3247, w norm = 4.0994
# [GPU] Epoch 40: b norm = 1.3515, w norm = 4.1727
# [GPU] Epoch 50: b norm = 1.3617, w norm = 4.1984
# [GPU] Epoch 60: b norm = 1.3656, w norm = 4.2075
# [GPU] Epoch 70: b norm = 1.3671, w norm = 4.2109
# [GPU] Epoch 80: b norm = 1.3677, w norm = 4.2121
# [GPU] Epoch 90: b norm = 1.3679, w norm = 4.2125
# [GPU] Epoch 100: b norm = 1.3680, w norm = 4.2127
# [GPU] Epoch 110: b norm = 1.3681, w norm = 4.2127
# [GPU] Epoch 120: b norm = 1.3681, w norm = 4.2128
# [GPU] Epoch 130: b norm = 1.3681, w norm = 4.2128
# [GPU] Epoch 140: b norm = 1.3681, w norm = 4.2128
# [GPU] Epoch 0: b norm = 0.2122, w norm = 0.7176
# [GPU] Epoch 10: b norm = 0.9258, w norm = 2.9152
# [GPU] Epoch 20: b norm = 1.1395, w norm = 3.5600
# [GPU] Epoch 30: b norm = 1.2224, w norm = 3.7876
# [GPU] Epoch 40: b norm = 1.2567, w norm = 3.8726
# [GPU] Epoch 50: b norm = 1.2713, w norm = 3.9054
# [GPU] Epoch 60: b norm = 1.2776, w norm = 3.9183
# [GPU] Epoch 70: b norm = 1.2803, w norm = 3.9235
# [GPU] Epoch 80: b norm = 1.2815, w norm = 3.9256
# [GPU] Epoch 90: b norm = 1.2821, w norm = 3.9264
# [GPU] Epoch 100: b norm = 1.2823, w norm = 3.9268
# [GPU] Epoch 110: b norm = 1.2824, w norm = 3.9269
# [GPU] Epoch 120: b norm = 1.2825, w norm = 3.9270
# [GPU] Epoch 130: b norm = 1.2825, w norm = 3.9270
# [GPU] Epoch 140: b norm = 1.2825, w norm = 3.9270
# [GPU] Epoch 0: b norm = 0.2201, w norm = 0.6871
# [GPU] Epoch 10: b norm = 1.0401, w norm = 3.1930
# [GPU] Epoch 20: b norm = 1.2615, w norm = 3.8750
# [GPU] Epoch 30: b norm = 1.3370, w norm = 4.0956
# [GPU] Epoch 40: b norm = 1.3646, w norm = 4.1705
# [GPU] Epoch 50: b norm = 1.3751, w norm = 4.1967
# [GPU] Epoch 60: b norm = 1.3791, w norm = 4.2060
# [GPU] Epoch 70: b norm = 1.3807, w norm = 4.2094
# [GPU] Epoch 80: b norm = 1.3813, w norm = 4.2106
# [GPU] Epoch 90: b norm = 1.3816, w norm = 4.2111
# [GPU] Epoch 100: b norm = 1.3816, w norm = 4.2112
# [GPU] Epoch 110: b norm = 1.3817, w norm = 4.2113
# [GPU] Epoch 120: b norm = 1.3817, w norm = 4.2113
# [GPU] Epoch 130: b norm = 1.3817, w norm = 4.2113
# [GPU] Epoch 140: b norm = 1.3817, w norm = 4.2113
# [GPU] Epoch 0: b norm = 0.2043, w norm = 0.6847
# [GPU] Epoch 10: b norm = 0.9308, w norm = 2.9008
# [GPU] Epoch 20: b norm = 1.1549, w norm = 3.5634
# [GPU] Epoch 30: b norm = 1.2426, w norm = 3.7971
# [GPU] Epoch 40: b norm = 1.2792, w norm = 3.8838
# [GPU] Epoch 50: b norm = 1.2949, w norm = 3.9170
# [GPU] Epoch 60: b norm = 1.3018, w norm = 3.9299
# [GPU] Epoch 70: b norm = 1.3048, w norm = 3.9351
# [GPU] Epoch 80: b norm = 1.3061, w norm = 3.9372
# [GPU] Epoch 90: b norm = 1.3067, w norm = 3.9380
# [GPU] Epoch 100: b norm = 1.3070, w norm = 3.9384
# [GPU] Epoch 110: b norm = 1.3071, w norm = 3.9385
# [GPU] Epoch 120: b norm = 1.3072, w norm = 3.9386
# [GPU] Epoch 130: b norm = 1.3072, w norm = 3.9386
# [GPU] Epoch 140: b norm = 1.3072, w norm = 3.9386
# [GPU] Epoch 0: b norm = 0.2532, w norm = 0.7740
# [GPU] Epoch 10: b norm = 1.1219, w norm = 3.3130
# [GPU] Epoch 20: b norm = 1.3483, w norm = 3.9692
# [GPU] Epoch 30: b norm = 1.4260, w norm = 4.1804
# [GPU] Epoch 40: b norm = 1.4548, w norm = 4.2523
# [GPU] Epoch 50: b norm = 1.4658, w norm = 4.2774
# [GPU] Epoch 60: b norm = 1.4701, w norm = 4.2864
# [GPU] Epoch 70: b norm = 1.4717, w norm = 4.2896
# [GPU] Epoch 80: b norm = 1.4724, w norm = 4.2908
# [GPU] Epoch 90: b norm = 1.4726, w norm = 4.2912
# [GPU] Epoch 100: b norm = 1.4727, w norm = 4.2914
# [GPU] Epoch 110: b norm = 1.4728, w norm = 4.2914
# [GPU] Epoch 120: b norm = 1.4728, w norm = 4.2915
# [GPU] Epoch 130: b norm = 1.4728, w norm = 4.2915
# [GPU] Epoch 140: b norm = 1.4728, w norm = 4.2915
# [GPU] Epoch 0: b norm = 0.2389, w norm = 0.7779
# [GPU] Epoch 10: b norm = 0.9925, w norm = 2.9609
# [GPU] Epoch 20: b norm = 1.2199, w norm = 3.6029
# [GPU] Epoch 30: b norm = 1.3095, w norm = 3.8319
# [GPU] Epoch 40: b norm = 1.3470, w norm = 3.9178
# [GPU] Epoch 50: b norm = 1.3631, w norm = 3.9510
# [GPU] Epoch 60: b norm = 1.3701, w norm = 3.9640
# [GPU] Epoch 70: b norm = 1.3731, w norm = 3.9693
# [GPU] Epoch 80: b norm = 1.3745, w norm = 3.9714
# [GPU] Epoch 90: b norm = 1.3751, w norm = 3.9722
# [GPU] Epoch 100: b norm = 1.3753, w norm = 3.9726
# [GPU] Epoch 110: b norm = 1.3755, w norm = 3.9727
# [GPU] Epoch 120: b norm = 1.3755, w norm = 3.9728
# [GPU] Epoch 130: b norm = 1.3755, w norm = 3.9728
# [GPU] Epoch 140: b norm = 1.3755, w norm = 3.9728
# [GPU] Epoch 0: b norm = 0.2145, w norm = 0.7172
# [GPU] Epoch 10: b norm = 1.0297, w norm = 3.2558
# [GPU] Epoch 20: b norm = 1.2407, w norm = 3.9350
# [GPU] Epoch 30: b norm = 1.3113, w norm = 4.1546
# [GPU] Epoch 40: b norm = 1.3369, w norm = 4.2296
# [GPU] Epoch 50: b norm = 1.3465, w norm = 4.2559
# [GPU] Epoch 60: b norm = 1.3503, w norm = 4.2654
# [GPU] Epoch 70: b norm = 1.3517, w norm = 4.2688
# [GPU] Epoch 80: b norm = 1.3522, w norm = 4.2700
# [GPU] Epoch 90: b norm = 1.3525, w norm = 4.2705
# [GPU] Epoch 100: b norm = 1.3525, w norm = 4.2707
# [GPU] Epoch 110: b norm = 1.3526, w norm = 4.2707
# [GPU] Epoch 120: b norm = 1.3526, w norm = 4.2707
# [GPU] Epoch 130: b norm = 1.3526, w norm = 4.2707
# [GPU] Epoch 140: b norm = 1.3526, w norm = 4.2708
# [GPU] Epoch 0: b norm = 0.2159, w norm = 0.7109
# [GPU] Epoch 10: b norm = 0.9167, w norm = 2.9438
# [GPU] Epoch 20: b norm = 1.1206, w norm = 3.6090
# [GPU] Epoch 30: b norm = 1.1995, w norm = 3.8466
# [GPU] Epoch 40: b norm = 1.2322, w norm = 3.9361
# [GPU] Epoch 50: b norm = 1.2462, w norm = 3.9708
# [GPU] Epoch 60: b norm = 1.2522, w norm = 3.9845
# [GPU] Epoch 70: b norm = 1.2549, w norm = 3.9900
# [GPU] Epoch 80: b norm = 1.2560, w norm = 3.9923
# [GPU] Epoch 90: b norm = 1.2566, w norm = 3.9932
# [GPU] Epoch 100: b norm = 1.2568, w norm = 3.9936
# [GPU] Epoch 110: b norm = 1.2569, w norm = 3.9937
# [GPU] Epoch 120: b norm = 1.2569, w norm = 3.9938
# [GPU] Epoch 130: b norm = 1.2569, w norm = 3.9938
# [GPU] Epoch 140: b norm = 1.2570, w norm = 3.9939
# [GPU] Epoch 0: b norm = 0.1972, w norm = 0.6913
# [GPU] Epoch 10: b norm = 1.0392, w norm = 3.2275
# [GPU] Epoch 20: b norm = 1.2661, w norm = 3.9068
# [GPU] Epoch 30: b norm = 1.3439, w norm = 4.1248
# [GPU] Epoch 40: b norm = 1.3726, w norm = 4.1987
# [GPU] Epoch 50: b norm = 1.3835, w norm = 4.2245
# [GPU] Epoch 60: b norm = 1.3878, w norm = 4.2336
# [GPU] Epoch 70: b norm = 1.3894, w norm = 4.2369
# [GPU] Epoch 80: b norm = 1.3901, w norm = 4.2381
# [GPU] Epoch 90: b norm = 1.3903, w norm = 4.2386
# [GPU] Epoch 100: b norm = 1.3904, w norm = 4.2387
# [GPU] Epoch 110: b norm = 1.3905, w norm = 4.2388
# [GPU] Epoch 120: b norm = 1.3905, w norm = 4.2388
# [GPU] Epoch 130: b norm = 1.3905, w norm = 4.2388
# [GPU] Epoch 140: b norm = 1.3905, w norm = 4.2388
# [GPU] Epoch 0: b norm = 0.2051, w norm = 0.6879
# [GPU] Epoch 10: b norm = 0.9400, w norm = 2.9240
# [GPU] Epoch 20: b norm = 1.1658, w norm = 3.5797
# [GPU] Epoch 30: b norm = 1.2553, w norm = 3.8110
# [GPU] Epoch 40: b norm = 1.2929, w norm = 3.8971
# [GPU] Epoch 50: b norm = 1.3092, w norm = 3.9301
# [GPU] Epoch 60: b norm = 1.3164, w norm = 3.9430
# [GPU] Epoch 70: b norm = 1.3196, w norm = 3.9482
# [GPU] Epoch 80: b norm = 1.3210, w norm = 3.9503
# [GPU] Epoch 90: b norm = 1.3216, w norm = 3.9511
# [GPU] Epoch 100: b norm = 1.3219, w norm = 3.9515
# [GPU] Epoch 110: b norm = 1.3220, w norm = 3.9516
# [GPU] Epoch 120: b norm = 1.3221, w norm = 3.9517
# [GPU] Epoch 130: b norm = 1.3221, w norm = 3.9517
# [GPU] Epoch 140: b norm = 1.3221, w norm = 3.9517
# [GPU] Epoch 0: b norm = 0.2022, w norm = 0.6801
# [GPU] Epoch 10: b norm = 1.0271, w norm = 3.1801
# [GPU] Epoch 20: b norm = 1.2498, w norm = 3.8594
# [GPU] Epoch 30: b norm = 1.3254, w norm = 4.0789
# [GPU] Epoch 40: b norm = 1.3530, w norm = 4.1535
# [GPU] Epoch 50: b norm = 1.3635, w norm = 4.1795
# [GPU] Epoch 60: b norm = 1.3675, w norm = 4.1888
# [GPU] Epoch 70: b norm = 1.3691, w norm = 4.1922
# [GPU] Epoch 80: b norm = 1.3697, w norm = 4.1934
# [GPU] Epoch 90: b norm = 1.3700, w norm = 4.1938
# [GPU] Epoch 100: b norm = 1.3700, w norm = 4.1940
# [GPU] Epoch 110: b norm = 1.3701, w norm = 4.1941
# [GPU] Epoch 120: b norm = 1.3701, w norm = 4.1941
# [GPU] Epoch 130: b norm = 1.3701, w norm = 4.1941
# [GPU] Epoch 140: b norm = 1.3701, w norm = 4.1941
# [GPU] Epoch 0: b norm = 0.2116, w norm = 0.6835
# [GPU] Epoch 10: b norm = 0.9311, w norm = 2.8973
# [GPU] Epoch 20: b norm = 1.1495, w norm = 3.5541
# [GPU] Epoch 30: b norm = 1.2350, w norm = 3.7866
# [GPU] Epoch 40: b norm = 1.2708, w norm = 3.8732
# [GPU] Epoch 50: b norm = 1.2863, w norm = 3.9065
# [GPU] Epoch 60: b norm = 1.2931, w norm = 3.9196
# [GPU] Epoch 70: b norm = 1.2960, w norm = 3.9248
# [GPU] Epoch 80: b norm = 1.2974, w norm = 3.9269
# [GPU] Epoch 90: b norm = 1.2980, w norm = 3.9278
# [GPU] Epoch 100: b norm = 1.2982, w norm = 3.9281
# [GPU] Epoch 110: b norm = 1.2984, w norm = 3.9283
# [GPU] Epoch 120: b norm = 1.2984, w norm = 3.9283
# [GPU] Epoch 130: b norm = 1.2984, w norm = 3.9283
# [GPU] Epoch 140: b norm = 1.2984, w norm = 3.9284
# [GPU] Epoch 0: b norm = 0.2157, w norm = 0.6620
# [GPU] Epoch 10: b norm = 0.9907, w norm = 3.2187
# [GPU] Epoch 20: b norm = 1.2024, w norm = 3.9273
# [GPU] Epoch 30: b norm = 1.2751, w norm = 4.1570
# [GPU] Epoch 40: b norm = 1.3018, w norm = 4.2353
# [GPU] Epoch 50: b norm = 1.3120, w norm = 4.2627
# [GPU] Epoch 60: b norm = 1.3159, w norm = 4.2725
# [GPU] Epoch 70: b norm = 1.3174, w norm = 4.2760
# [GPU] Epoch 80: b norm = 1.3180, w norm = 4.2773
# [GPU] Epoch 90: b norm = 1.3183, w norm = 4.2778
# [GPU] Epoch 100: b norm = 1.3184, w norm = 4.2779
# [GPU] Epoch 110: b norm = 1.3184, w norm = 4.2780
# [GPU] Epoch 120: b norm = 1.3184, w norm = 4.2780
# [GPU] Epoch 130: b norm = 1.3184, w norm = 4.2780
# [GPU] Epoch 140: b norm = 1.3184, w norm = 4.2780
# [GPU] Epoch 0: b norm = 0.1985, w norm = 0.6583
# [GPU] Epoch 10: b norm = 0.8966, w norm = 2.9471
# [GPU] Epoch 20: b norm = 1.1162, w norm = 3.6351
# [GPU] Epoch 30: b norm = 1.2033, w norm = 3.8791
# [GPU] Epoch 40: b norm = 1.2401, w norm = 3.9703
# [GPU] Epoch 50: b norm = 1.2559, w norm = 4.0053
# [GPU] Epoch 60: b norm = 1.2629, w norm = 4.0191
# [GPU] Epoch 70: b norm = 1.2659, w norm = 4.0246
# [GPU] Epoch 80: b norm = 1.2673, w norm = 4.0268
# [GPU] Epoch 90: b norm = 1.2679, w norm = 4.0277
# [GPU] Epoch 100: b norm = 1.2682, w norm = 4.0281
# [GPU] Epoch 110: b norm = 1.2683, w norm = 4.0282
# [GPU] Epoch 120: b norm = 1.2683, w norm = 4.0283
# [GPU] Epoch 130: b norm = 1.2684, w norm = 4.0283
# [GPU] Epoch 140: b norm = 1.2684, w norm = 4.0283
# [GPU] Epoch 0: b norm = 0.2062, w norm = 0.6889
# [GPU] Epoch 10: b norm = 1.0013, w norm = 3.2350
# [GPU] Epoch 20: b norm = 1.2142, w norm = 3.9384
# [GPU] Epoch 30: b norm = 1.2864, w norm = 4.1667
# [GPU] Epoch 40: b norm = 1.3127, w norm = 4.2446
# [GPU] Epoch 50: b norm = 1.3227, w norm = 4.2718
# [GPU] Epoch 60: b norm = 1.3265, w norm = 4.2816
# [GPU] Epoch 70: b norm = 1.3280, w norm = 4.2851
# [GPU] Epoch 80: b norm = 1.3286, w norm = 4.2864
# [GPU] Epoch 90: b norm = 1.3288, w norm = 4.2868
# [GPU] Epoch 100: b norm = 1.3289, w norm = 4.2870
# [GPU] Epoch 110: b norm = 1.3289, w norm = 4.2871
# [GPU] Epoch 120: b norm = 1.3290, w norm = 4.2871
# [GPU] Epoch 130: b norm = 1.3290, w norm = 4.2871
# [GPU] Epoch 140: b norm = 1.3290, w norm = 4.2871
# [GPU] Epoch 0: b norm = 0.2213, w norm = 0.7027
# [GPU] Epoch 10: b norm = 0.9079, w norm = 2.9624
# [GPU] Epoch 20: b norm = 1.1156, w norm = 3.6382
# [GPU] Epoch 30: b norm = 1.1966, w norm = 3.8771
# [GPU] Epoch 40: b norm = 1.2303, w norm = 3.9662
# [GPU] Epoch 50: b norm = 1.2447, w norm = 4.0006
# [GPU] Epoch 60: b norm = 1.2509, w norm = 4.0141
# [GPU] Epoch 70: b norm = 1.2537, w norm = 4.0195
# [GPU] Epoch 80: b norm = 1.2549, w norm = 4.0217
# [GPU] Epoch 90: b norm = 1.2554, w norm = 4.0226
# [GPU] Epoch 100: b norm = 1.2557, w norm = 4.0230
# [GPU] Epoch 110: b norm = 1.2558, w norm = 4.0231
# [GPU] Epoch 120: b norm = 1.2558, w norm = 4.0232
# [GPU] Epoch 130: b norm = 1.2559, w norm = 4.0232
# [GPU] Epoch 140: b norm = 1.2559, w norm = 4.0232
# [GPU] Epoch 0: b norm = 0.2198, w norm = 0.6985
# [GPU] Epoch 10: b norm = 1.0151, w norm = 3.2505
# [GPU] Epoch 20: b norm = 1.2319, w norm = 3.9549
# [GPU] Epoch 30: b norm = 1.3056, w norm = 4.1834
# [GPU] Epoch 40: b norm = 1.3326, w norm = 4.2613
# [GPU] Epoch 50: b norm = 1.3427, w norm = 4.2886
# [GPU] Epoch 60: b norm = 1.3466, w norm = 4.2984
# [GPU] Epoch 70: b norm = 1.3481, w norm = 4.3019
# [GPU] Epoch 80: b norm = 1.3487, w norm = 4.3032
# [GPU] Epoch 90: b norm = 1.3490, w norm = 4.3037
# [GPU] Epoch 100: b norm = 1.3491, w norm = 4.3039
# [GPU] Epoch 110: b norm = 1.3491, w norm = 4.3039
# [GPU] Epoch 120: b norm = 1.3491, w norm = 4.3039
# [GPU] Epoch 130: b norm = 1.3491, w norm = 4.3040
# [GPU] Epoch 140: b norm = 1.3491, w norm = 4.3040
# [GPU] Epoch 0: b norm = 0.2103, w norm = 0.6934
# [GPU] Epoch 10: b norm = 0.9121, w norm = 2.9707
# [GPU] Epoch 20: b norm = 1.1304, w norm = 3.6550
# [GPU] Epoch 30: b norm = 1.2155, w norm = 3.8986
# [GPU] Epoch 40: b norm = 1.2507, w norm = 3.9899
# [GPU] Epoch 50: b norm = 1.2656, w norm = 4.0252
# [GPU] Epoch 60: b norm = 1.2721, w norm = 4.0391
# [GPU] Epoch 70: b norm = 1.2749, w norm = 4.0447
# [GPU] Epoch 80: b norm = 1.2762, w norm = 4.0470
# [GPU] Epoch 90: b norm = 1.2767, w norm = 4.0479
# [GPU] Epoch 100: b norm = 1.2770, w norm = 4.0483
# [GPU] Epoch 110: b norm = 1.2771, w norm = 4.0484
# [GPU] Epoch 120: b norm = 1.2771, w norm = 4.0485
# [GPU] Epoch 130: b norm = 1.2772, w norm = 4.0485
# [GPU] Epoch 140: b norm = 1.2772, w norm = 4.0486
# [GPU] Epoch 0: b norm = 0.2123, w norm = 0.7217
# [GPU] Epoch 10: b norm = 1.0139, w norm = 3.2545
# [GPU] Epoch 20: b norm = 1.2274, w norm = 3.9432
# [GPU] Epoch 30: b norm = 1.3000, w norm = 4.1669
# [GPU] Epoch 40: b norm = 1.3266, w norm = 4.2434
# [GPU] Epoch 50: b norm = 1.3367, w norm = 4.2702
# [GPU] Epoch 60: b norm = 1.3405, w norm = 4.2798
# [GPU] Epoch 70: b norm = 1.3420, w norm = 4.2833
# [GPU] Epoch 80: b norm = 1.3426, w norm = 4.2845
# [GPU] Epoch 90: b norm = 1.3429, w norm = 4.2850
# [GPU] Epoch 100: b norm = 1.3430, w norm = 4.2852
# [GPU] Epoch 110: b norm = 1.3430, w norm = 4.2853
# [GPU] Epoch 120: b norm = 1.3430, w norm = 4.2853
# [GPU] Epoch 130: b norm = 1.3430, w norm = 4.2853
# [GPU] Epoch 140: b norm = 1.3430, w norm = 4.2853
# [GPU] Epoch 0: b norm = 0.2157, w norm = 0.7178
# [GPU] Epoch 10: b norm = 0.9120, w norm = 2.9561
# [GPU] Epoch 20: b norm = 1.1226, w norm = 3.6308
# [GPU] Epoch 30: b norm = 1.2050, w norm = 3.8714
# [GPU] Epoch 40: b norm = 1.2393, w norm = 3.9617
# [GPU] Epoch 50: b norm = 1.2540, w norm = 3.9966
# [GPU] Epoch 60: b norm = 1.2603, w norm = 4.0104
# [GPU] Epoch 70: b norm = 1.2631, w norm = 4.0159
# [GPU] Epoch 80: b norm = 1.2644, w norm = 4.0181
# [GPU] Epoch 90: b norm = 1.2649, w norm = 4.0191
# [GPU] Epoch 100: b norm = 1.2651, w norm = 4.0194
# [GPU] Epoch 110: b norm = 1.2653, w norm = 4.0196
# [GPU] Epoch 120: b norm = 1.2653, w norm = 4.0197
# [GPU] Epoch 130: b norm = 1.2653, w norm = 4.0197
# [GPU] Epoch 140: b norm = 1.2653, w norm = 4.0197
# [GPU] Epoch 0: b norm = 0.2019, w norm = 0.7075
# [GPU] Epoch 10: b norm = 1.0296, w norm = 3.2955
# [GPU] Epoch 20: b norm = 1.2579, w norm = 4.0079
# [GPU] Epoch 30: b norm = 1.3365, w norm = 4.2388
# [GPU] Epoch 40: b norm = 1.3654, w norm = 4.3175
# [GPU] Epoch 50: b norm = 1.3764, w norm = 4.3450
# [GPU] Epoch 60: b norm = 1.3806, w norm = 4.3549
# [GPU] Epoch 70: b norm = 1.3823, w norm = 4.3584
# [GPU] Epoch 80: b norm = 1.3830, w norm = 4.3598
# [GPU] Epoch 90: b norm = 1.3832, w norm = 4.3602
# [GPU] Epoch 100: b norm = 1.3833, w norm = 4.3604
# [GPU] Epoch 110: b norm = 1.3834, w norm = 4.3605
# [GPU] Epoch 120: b norm = 1.3834, w norm = 4.3605
# [GPU] Epoch 130: b norm = 1.3834, w norm = 4.3605
# ...
# [GPU] Epoch 60: b norm = 1.3601, w norm = 4.3989
# [GPU] Epoch 70: b norm = 1.3617, w norm = 4.4027
# [GPU] Epoch 80: b norm = 1.3623, w norm = 4.4040
# [GPU] Epoch 90: b norm = 1.3625, w norm = 4.4045
# [GPU] Epoch 100: b norm = 1.3626, w norm = 4.4047
# [GPU] Epoch 110: b norm = 1.3627, w norm = 4.4048
# [GPU] Epoch 120: b norm = 1.3627, w norm = 4.4048
# [GPU] Epoch 130: b norm = 1.3627, w norm = 4.4048
# [GPU] Epoch 140: b norm = 1.3627, w norm = 4.4048
# [GPU] Epoch 0: b norm = 0.2331, w norm = 0.7106
# [GPU] Epoch 10: b norm = 0.9287, w norm = 3.0342
# [GPU] Epoch 20: b norm = 1.1477, w norm = 3.7400
# [GPU] Epoch 30: b norm = 1.2347, w norm = 3.9923
# [GPU] Epoch 40: b norm = 1.2713, w norm = 4.0872
# [GPU] Epoch 50: b norm = 1.2870, w norm = 4.1239
# [GPU] Epoch 60: b norm = 1.2939, w norm = 4.1385
# [GPU] Epoch 70: b norm = 1.2969, w norm = 4.1443
# [GPU] Epoch 80: b norm = 1.2983, w norm = 4.1467
# [GPU] Epoch 90: b norm = 1.2989, w norm = 4.1477
# [GPU] Epoch 100: b norm = 1.2992, w norm = 4.1481
# [GPU] Epoch 110: b norm = 1.2993, w norm = 4.1483
# [GPU] Epoch 120: b norm = 1.2993, w norm = 4.1484
# [GPU] Epoch 130: b norm = 1.2994, w norm = 4.1484
# [GPU] Epoch 140: b norm = 1.2994, w norm = 4.1484
# [GPU] Epoch 0: b norm = 0.2106, w norm = 0.7293
# [GPU] Epoch 10: b norm = 1.0407, w norm = 3.2859
# [GPU] Epoch 20: b norm = 1.2672, w norm = 3.9945
# [GPU] Epoch 30: b norm = 1.3455, w norm = 4.2262
# [GPU] Epoch 40: b norm = 1.3745, w norm = 4.3054
# [GPU] Epoch 50: b norm = 1.3855, w norm = 4.3332
# [GPU] Epoch 60: b norm = 1.3897, w norm = 4.3431
# [GPU] Epoch 70: b norm = 1.3914, w norm = 4.3466
# [GPU] Epoch 80: b norm = 1.3920, w norm = 4.3479
# [GPU] Epoch 90: b norm = 1.3923, w norm = 4.3484
# [GPU] Epoch 100: b norm = 1.3924, w norm = 4.3486
# [GPU] Epoch 110: b norm = 1.3924, w norm = 4.3487
# [GPU] Epoch 120: b norm = 1.3924, w norm = 4.3487
# [GPU] Epoch 130: b norm = 1.3924, w norm = 4.3487
# [GPU] Epoch 140: b norm = 1.3924, w norm = 4.3487
# [GPU] Epoch 0: b norm = 0.2416, w norm = 0.7181
# [GPU] Epoch 10: b norm = 0.9490, w norm = 3.0017
# [GPU] Epoch 20: b norm = 1.1712, w norm = 3.6941
# [GPU] Epoch 30: b norm = 1.2593, w norm = 3.9388
# [GPU] Epoch 40: b norm = 1.2962, w norm = 4.0296
# [GPU] Epoch 50: b norm = 1.3121, w norm = 4.0644
# [GPU] Epoch 60: b norm = 1.3191, w norm = 4.0780
# [GPU] Epoch 70: b norm = 1.3221, w norm = 4.0834
# [GPU] Epoch 80: b norm = 1.3234, w norm = 4.0856
# [GPU] Epoch 90: b norm = 1.3240, w norm = 4.0865
# [GPU] Epoch 100: b norm = 1.3243, w norm = 4.0868
# [GPU] Epoch 110: b norm = 1.3244, w norm = 4.0870
# [GPU] Epoch 120: b norm = 1.3245, w norm = 4.0871
# [GPU] Epoch 130: b norm = 1.3245, w norm = 4.0871
# [GPU] Epoch 140: b norm = 1.3245, w norm = 4.0871
# [GPU] Epoch 0: b norm = 0.2286, w norm = 0.7426
# [GPU] Epoch 10: b norm = 1.0717, w norm = 3.3758
# [GPU] Epoch 20: b norm = 1.2988, w norm = 4.0894
# [GPU] Epoch 30: b norm = 1.3769, w norm = 4.3204
# [GPU] Epoch 40: b norm = 1.4058, w norm = 4.3991
# [GPU] Epoch 50: b norm = 1.4169, w norm = 4.4266
# [GPU] Epoch 60: b norm = 1.4212, w norm = 4.4365
# [GPU] Epoch 70: b norm = 1.4228, w norm = 4.4400
# [GPU] Epoch 80: b norm = 1.4235, w norm = 4.4413
# [GPU] Epoch 90: b norm = 1.4238, w norm = 4.4418
# [GPU] Epoch 100: b norm = 1.4239, w norm = 4.4420
# [GPU] Epoch 110: b norm = 1.4239, w norm = 4.4420
# [GPU] Epoch 120: b norm = 1.4239, w norm = 4.4421
# [GPU] Epoch 130: b norm = 1.4239, w norm = 4.4421
# [GPU] Epoch 140: b norm = 1.4239, w norm = 4.4421
# [GPU] Epoch 0: b norm = 0.2161, w norm = 0.7404
# [GPU] Epoch 10: b norm = 0.9599, w norm = 3.0653
# [GPU] Epoch 20: b norm = 1.1910, w norm = 3.7594
# [GPU] Epoch 30: b norm = 1.2832, w norm = 4.0060
# [GPU] Epoch 40: b norm = 1.3225, w norm = 4.0983
# [GPU] Epoch 50: b norm = 1.3396, w norm = 4.1338
# [GPU] Epoch 60: b norm = 1.3471, w norm = 4.1479
# [GPU] Epoch 70: b norm = 1.3505, w norm = 4.1535
# [GPU] Epoch 80: b norm = 1.3520, w norm = 4.1558
# [GPU] Epoch 90: b norm = 1.3527, w norm = 4.1567
# [GPU] Epoch 100: b norm = 1.3530, w norm = 4.1571
# [GPU] Epoch 110: b norm = 1.3531, w norm = 4.1573
# [GPU] Epoch 120: b norm = 1.3532, w norm = 4.1573
# [GPU] Epoch 130: b norm = 1.3532, w norm = 4.1574
# [GPU] Epoch 140: b norm = 1.3532, w norm = 4.1574
# [GPU] Epoch 0: b norm = 0.2387, w norm = 0.7507
# [GPU] Epoch 10: b norm = 1.0582, w norm = 3.3689
# [GPU] Epoch 20: b norm = 1.2699, w norm = 4.0724
# [GPU] Epoch 30: b norm = 1.3417, w norm = 4.3019
# [GPU] Epoch 40: b norm = 1.3681, w norm = 4.3807
# [GPU] Epoch 50: b norm = 1.3782, w norm = 4.4085
# [GPU] Epoch 60: b norm = 1.3820, w norm = 4.4185
# [GPU] Epoch 70: b norm = 1.3835, w norm = 4.4221
# [GPU] Epoch 80: b norm = 1.3841, w norm = 4.4234
# [GPU] Epoch 90: b norm = 1.3843, w norm = 4.4239
# [GPU] Epoch 100: b norm = 1.3844, w norm = 4.4241
# [GPU] Epoch 110: b norm = 1.3845, w norm = 4.4242
# [GPU] Epoch 120: b norm = 1.3845, w norm = 4.4242
# [GPU] Epoch 130: b norm = 1.3845, w norm = 4.4242
# [GPU] Epoch 140: b norm = 1.3845, w norm = 4.4242
# [GPU] Epoch 0: b norm = 0.2233, w norm = 0.7539
# [GPU] Epoch 10: b norm = 0.9336, w norm = 3.0488
# [GPU] Epoch 20: b norm = 1.1472, w norm = 3.7411
# [GPU] Epoch 30: b norm = 1.2316, w norm = 3.9906
# [GPU] Epoch 40: b norm = 1.2670, w norm = 4.0851
# [GPU] Epoch 50: b norm = 1.2822, w norm = 4.1220
# [GPU] Epoch 60: b norm = 1.2889, w norm = 4.1367
# [GPU] Epoch 70: b norm = 1.2918, w norm = 4.1426
# [GPU] Epoch 80: b norm = 1.2931, w norm = 4.1450
# [GPU] Epoch 90: b norm = 1.2937, w norm = 4.1460
# [GPU] Epoch 100: b norm = 1.2939, w norm = 4.1464
# [GPU] Epoch 110: b norm = 1.2940, w norm = 4.1466
# [GPU] Epoch 120: b norm = 1.2941, w norm = 4.1467
# [GPU] Epoch 130: b norm = 1.2941, w norm = 4.1467
# [GPU] Epoch 140: b norm = 1.2941, w norm = 4.1467
# [GPU] Epoch 0: b norm = 0.2093, w norm = 0.7043
# [GPU] Epoch 10: b norm = 1.0105, w norm = 3.2888
# [GPU] Epoch 20: b norm = 1.2328, w norm = 4.0086
# [GPU] Epoch 30: b norm = 1.3105, w norm = 4.2444
# [GPU] Epoch 40: b norm = 1.3394, w norm = 4.3254
# [GPU] Epoch 50: b norm = 1.3504, w norm = 4.3539
# [GPU] Epoch 60: b norm = 1.3547, w norm = 4.3641
# [GPU] Epoch 70: b norm = 1.3564, w norm = 4.3678
# [GPU] Epoch 80: b norm = 1.3570, w norm = 4.3691
# [GPU] Epoch 90: b norm = 1.3573, w norm = 4.3696
# [GPU] Epoch 100: b norm = 1.3574, w norm = 4.3698
# [GPU] Epoch 110: b norm = 1.3574, w norm = 4.3699
# [GPU] Epoch 120: b norm = 1.3574, w norm = 4.3699
# [GPU] Epoch 130: b norm = 1.3574, w norm = 4.3699
# [GPU] Epoch 140: b norm = 1.3574, w norm = 4.3699
# [GPU] Epoch 0: b norm = 0.1988, w norm = 0.7115
# [GPU] Epoch 10: b norm = 0.9114, w norm = 3.0081
# [GPU] Epoch 20: b norm = 1.1446, w norm = 3.7150
# [GPU] Epoch 30: b norm = 1.2384, w norm = 3.9683
# [GPU] Epoch 40: b norm = 1.2781, w norm = 4.0636
# [GPU] Epoch 50: b norm = 1.2953, w norm = 4.1006
# [GPU] Epoch 60: b norm = 1.3028, w norm = 4.1152
# [GPU] Epoch 70: b norm = 1.3062, w norm = 4.1211
# [GPU] Epoch 80: b norm = 1.3077, w norm = 4.1235
# [GPU] Epoch 90: b norm = 1.3083, w norm = 4.1245
# [GPU] Epoch 100: b norm = 1.3086, w norm = 4.1249
# [GPU] Epoch 110: b norm = 1.3088, w norm = 4.1251
# [GPU] Epoch 120: b norm = 1.3088, w norm = 4.1251
# [GPU] Epoch 130: b norm = 1.3089, w norm = 4.1252
# [GPU] Epoch 140: b norm = 1.3089, w norm = 4.1252
# [GPU] Epoch 0: b norm = 0.2275, w norm = 0.7201
# [GPU] Epoch 10: b norm = 1.0078, w norm = 3.2894
# [GPU] Epoch 20: b norm = 1.2201, w norm = 4.0056
# [GPU] Epoch 30: b norm = 1.2934, w norm = 4.2408
# [GPU] Epoch 40: b norm = 1.3204, w norm = 4.3216
# [GPU] Epoch 50: b norm = 1.3307, w norm = 4.3501
# [GPU] Epoch 60: b norm = 1.3347, w norm = 4.3603
# [GPU] Epoch 70: b norm = 1.3362, w norm = 4.3640
# [GPU] Epoch 80: b norm = 1.3368, w norm = 4.3654
# [GPU] Epoch 90: b norm = 1.3371, w norm = 4.3659
# [GPU] Epoch 100: b norm = 1.3372, w norm = 4.3661
# [GPU] Epoch 110: b norm = 1.3372, w norm = 4.3662
# [GPU] Epoch 120: b norm = 1.3372, w norm = 4.3662
# [GPU] Epoch 130: b norm = 1.3372, w norm = 4.3662
# [GPU] Epoch 140: b norm = 1.3372, w norm = 4.3662
# [GPU] Epoch 0: b norm = 0.2034, w norm = 0.7181
# [GPU] Epoch 10: b norm = 0.9057, w norm = 3.0071
# [GPU] Epoch 20: b norm = 1.1223, w norm = 3.7097
# [GPU] Epoch 30: b norm = 1.2078, w norm = 3.9616
# [GPU] Epoch 40: b norm = 1.2436, w norm = 4.0564
# [GPU] Epoch 50: b norm = 1.2591, w norm = 4.0932
# [GPU] Epoch 60: b norm = 1.2658, w norm = 4.1078
# [GPU] Epoch 70: b norm = 1.2687, w norm = 4.1136
# [GPU] Epoch 80: b norm = 1.2700, w norm = 4.1160
# [GPU] Epoch 90: b norm = 1.2706, w norm = 4.1170
# [GPU] Epoch 100: b norm = 1.2709, w norm = 4.1174
# [GPU] Epoch 110: b norm = 1.2710, w norm = 4.1176
# [GPU] Epoch 120: b norm = 1.2711, w norm = 4.1176
# [GPU] Epoch 130: b norm = 1.2711, w norm = 4.1177
# [GPU] Epoch 140: b norm = 1.2711, w norm = 4.1177
# [GPU] Epoch 0: b norm = 0.2283, w norm = 0.7072
# [GPU] Epoch 10: b norm = 1.0692, w norm = 3.3140
# [GPU] Epoch 20: b norm = 1.2970, w norm = 4.0334
# [GPU] Epoch 30: b norm = 1.3747, w norm = 4.2684
# [GPU] Epoch 40: b norm = 1.4033, w norm = 4.3490
# [GPU] Epoch 50: b norm = 1.4142, w norm = 4.3774
# [GPU] Epoch 60: b norm = 1.4184, w norm = 4.3876
# [GPU] Epoch 70: b norm = 1.4200, w norm = 4.3913
# [GPU] Epoch 80: b norm = 1.4207, w norm = 4.3926
# [GPU] Epoch 90: b norm = 1.4209, w norm = 4.3931
# [GPU] Epoch 100: b norm = 1.4210, w norm = 4.3933
# [GPU] Epoch 110: b norm = 1.4211, w norm = 4.3934
# [GPU] Epoch 120: b norm = 1.4211, w norm = 4.3934
# [GPU] Epoch 130: b norm = 1.4211, w norm = 4.3934
# [GPU] Epoch 140: b norm = 1.4211, w norm = 4.3934
# [GPU] Epoch 0: b norm = 0.2201, w norm = 0.7062
# [GPU] Epoch 10: b norm = 0.9637, w norm = 3.0261
# [GPU] Epoch 20: b norm = 1.1932, w norm = 3.7299
# [GPU] Epoch 30: b norm = 1.2838, w norm = 3.9822
# [GPU] Epoch 40: b norm = 1.3221, w norm = 4.0774
# [GPU] Epoch 50: b norm = 1.3386, w norm = 4.1144
# [GPU] Epoch 60: b norm = 1.3459, w norm = 4.1291
# [GPU] Epoch 70: b norm = 1.3491, w norm = 4.1350
# [GPU] Epoch 80: b norm = 1.3506, w norm = 4.1374
# [GPU] Epoch 90: b norm = 1.3512, w norm = 4.1384
# [GPU] Epoch 100: b norm = 1.3515, w norm = 4.1389
# [GPU] Epoch 110: b norm = 1.3516, w norm = 4.1390
# [GPU] Epoch 120: b norm = 1.3517, w norm = 4.1391
# [GPU] Epoch 130: b norm = 1.3517, w norm = 4.1391
# [GPU] Epoch 140: b norm = 1.3517, w norm = 4.1391
# [GPU] Epoch 0: b norm = 0.1901, w norm = 0.6841
# [GPU] Epoch 10: b norm = 1.0194, w norm = 3.3077
# [GPU] Epoch 20: b norm = 1.2460, w norm = 4.0375
# [GPU] Epoch 30: b norm = 1.3238, w norm = 4.2762
# [GPU] Epoch 40: b norm = 1.3526, w norm = 4.3583
# [GPU] Epoch 50: b norm = 1.3635, w norm = 4.3873
# [GPU] Epoch 60: b norm = 1.3678, w norm = 4.3977
# [GPU] Epoch 70: b norm = 1.3694, w norm = 4.4014
# [GPU] Epoch 80: b norm = 1.3701, w norm = 4.4028
# [GPU] Epoch 90: b norm = 1.3703, w norm = 4.4034
# [GPU] Epoch 100: b norm = 1.3704, w norm = 4.4035
# [GPU] Epoch 110: b norm = 1.3705, w norm = 4.4036
# [GPU] Epoch 120: b norm = 1.3705, w norm = 4.4036
# [GPU] Epoch 130: b norm = 1.3705, w norm = 4.4037
# [GPU] Epoch 140: b norm = 1.3705, w norm = 4.4037
# [GPU] Epoch 0: b norm = 0.2030, w norm = 0.6948
# [GPU] Epoch 10: b norm = 0.9277, w norm = 3.0341
# [GPU] Epoch 20: b norm = 1.1523, w norm = 3.7455
# [GPU] Epoch 30: b norm = 1.2416, w norm = 4.0014
# [GPU] Epoch 40: b norm = 1.2793, w norm = 4.0983
# [GPU] Epoch 50: b norm = 1.2957, w norm = 4.1360
# [GPU] Epoch 60: b norm = 1.3028, w norm = 4.1510
# [GPU] Epoch 70: b norm = 1.3060, w norm = 4.1570
# [GPU] Epoch 80: b norm = 1.3074, w norm = 4.1595
# [GPU] Epoch 90: b norm = 1.3080, w norm = 4.1605
# [GPU] Epoch 100: b norm = 1.3083, w norm = 4.1609
# [GPU] Epoch 110: b norm = 1.3085, w norm = 4.1611
# [GPU] Epoch 120: b norm = 1.3085, w norm = 4.1612
# [GPU] Epoch 130: b norm = 1.3085, w norm = 4.1612
# [GPU] Epoch 140: b norm = 1.3086, w norm = 4.1612
# [GPU] Epoch 0: b norm = 0.2304, w norm = 0.7282
# [GPU] Epoch 10: b norm = 1.0685, w norm = 3.4095
# [GPU] Epoch 20: b norm = 1.2987, w norm = 4.1484
# [GPU] Epoch 30: b norm = 1.3784, w norm = 4.3900
# [GPU] Epoch 40: b norm = 1.4080, w norm = 4.4730
# [GPU] Epoch 50: b norm = 1.4194, w norm = 4.5023
# [GPU] Epoch 60: b norm = 1.4238, w norm = 4.5128
# [GPU] Epoch 70: b norm = 1.4255, w norm = 4.5166
# [GPU] Epoch 80: b norm = 1.4262, w norm = 4.5180
# [GPU] Epoch 90: b norm = 1.4265, w norm = 4.5186
# [GPU] Epoch 100: b norm = 1.4266, w norm = 4.5187
# [GPU] Epoch 110: b norm = 1.4266, w norm = 4.5188
# [GPU] Epoch 120: b norm = 1.4266, w norm = 4.5188
# [GPU] Epoch 130: b norm = 1.4266, w norm = 4.5189
# [GPU] Epoch 140: b norm = 1.4266, w norm = 4.5189
# [GPU] Epoch 0: b norm = 0.2180, w norm = 0.7302
# [GPU] Epoch 10: b norm = 0.9621, w norm = 3.1112
# [GPU] Epoch 20: b norm = 1.1976, w norm = 3.8358
# [GPU] Epoch 30: b norm = 1.2924, w norm = 4.0969
# [GPU] Epoch 40: b norm = 1.3327, w norm = 4.1959
# [GPU] Epoch 50: b norm = 1.3503, w norm = 4.2346
# [GPU] Epoch 60: b norm = 1.3580, w norm = 4.2500
# [GPU] Epoch 70: b norm = 1.3615, w norm = 4.2563
# [GPU] Epoch 80: b norm = 1.3630, w norm = 4.2588
# [GPU] Epoch 90: b norm = 1.3637, w norm = 4.2599
# [GPU] Epoch 100: b norm = 1.3641, w norm = 4.2603
# [GPU] Epoch 110: b norm = 1.3642, w norm = 4.2605
# [GPU] Epoch 120: b norm = 1.3643, w norm = 4.2606
# [GPU] Epoch 130: b norm = 1.3643, w norm = 4.2606
# [GPU] Epoch 140: b norm = 1.3643, w norm = 4.2607
# [GPU] Epoch 0: b norm = 0.2285, w norm = 0.7634
# [GPU] Epoch 10: b norm = 1.0957, w norm = 3.4288
# [GPU] Epoch 20: b norm = 1.3274, w norm = 4.1554
# [GPU] Epoch 30: b norm = 1.4075, w norm = 4.3950
# [GPU] Epoch 40: b norm = 1.4372, w norm = 4.4779
# [GPU] Epoch 50: b norm = 1.4486, w norm = 4.5073
# [GPU] Epoch 60: b norm = 1.4530, w norm = 4.5179
# [GPU] Epoch 70: b norm = 1.4547, w norm = 4.5217
# [GPU] Epoch 80: b norm = 1.4554, w norm = 4.5232
# [GPU] Epoch 90: b norm = 1.4557, w norm = 4.5237
# [GPU] Epoch 100: b norm = 1.4558, w norm = 4.5239
# [GPU] Epoch 110: b norm = 1.4558, w norm = 4.5240
# [GPU] Epoch 120: b norm = 1.4558, w norm = 4.5240
# [GPU] Epoch 130: b norm = 1.4558, w norm = 4.5240
# [GPU] Epoch 140: b norm = 1.4558, w norm = 4.5240
# [GPU] Epoch 0: b norm = 0.2200, w norm = 0.7695
# [GPU] Epoch 10: b norm = 0.9802, w norm = 3.1129
# [GPU] Epoch 20: b norm = 1.2143, w norm = 3.8336
# [GPU] Epoch 30: b norm = 1.3075, w norm = 4.0960
# [GPU] Epoch 40: b norm = 1.3469, w norm = 4.1959
# [GPU] Epoch 50: b norm = 1.3640, w norm = 4.2349
# [GPU] Epoch 60: b norm = 1.3716, w norm = 4.2505
# [GPU] Epoch 70: b norm = 1.3749, w norm = 4.2568
# [GPU] Epoch 80: b norm = 1.3764, w norm = 4.2593
# [GPU] Epoch 90: b norm = 1.3770, w norm = 4.2604
# [GPU] Epoch 100: b norm = 1.3773, w norm = 4.2608
# [GPU] Epoch 110: b norm = 1.3775, w norm = 4.2610
# [GPU] Epoch 120: b norm = 1.3775, w norm = 4.2611
# [GPU] Epoch 130: b norm = 1.3776, w norm = 4.2611
# [GPU] Epoch 140: b norm = 1.3776, w norm = 4.2612
# [GPU] Epoch 0: b norm = 0.2123, w norm = 0.7306
# [GPU] Epoch 10: b norm = 1.0536, w norm = 3.3769
# [GPU] Epoch 20: b norm = 1.2823, w norm = 4.1004
# [GPU] Epoch 30: b norm = 1.3618, w norm = 4.3372
# [GPU] Epoch 40: b norm = 1.3915, w norm = 4.4187
# [GPU] Epoch 50: b norm = 1.4028, w norm = 4.4475
# [GPU] Epoch 60: b norm = 1.4073, w norm = 4.4579
# [GPU] Epoch 70: b norm = 1.4090, w norm = 4.4616
# [GPU] Epoch 80: b norm = 1.4097, w norm = 4.4630
# [GPU] Epoch 90: b norm = 1.4099, w norm = 4.4635
# [GPU] Epoch 100: b norm = 1.4101, w norm = 4.4637
# [GPU] Epoch 110: b norm = 1.4101, w norm = 4.4638
# [GPU] Epoch 120: b norm = 1.4101, w norm = 4.4638
# [GPU] Epoch 130: b norm = 1.4101, w norm = 4.4638
# [GPU] Epoch 140: b norm = 1.4101, w norm = 4.4638
# [GPU] Epoch 0: b norm = 0.2090, w norm = 0.7286
# [GPU] Epoch 10: b norm = 0.9477, w norm = 3.0718
# [GPU] Epoch 20: b norm = 1.1821, w norm = 3.7861
# [GPU] Epoch 30: b norm = 1.2766, w norm = 4.0442
# [GPU] Epoch 40: b norm = 1.3168, w norm = 4.1422
# [GPU] Epoch 50: b norm = 1.3343, w norm = 4.1804
# [GPU] Epoch 60: b norm = 1.3420, w norm = 4.1956
# [GPU] Epoch 70: b norm = 1.3454, w norm = 4.2017
# [GPU] Epoch 80: b norm = 1.3469, w norm = 4.2042
# [GPU] Epoch 90: b norm = 1.3476, w norm = 4.2052
# [GPU] Epoch 100: b norm = 1.3479, w norm = 4.2057
# [GPU] Epoch 110: b norm = 1.3481, w norm = 4.2058
# [GPU] Epoch 120: b norm = 1.3481, w norm = 4.2059
# [GPU] Epoch 130: b norm = 1.3482, w norm = 4.2060
# [GPU] Epoch 140: b norm = 1.3482, w norm = 4.2060

# %%
x = np.concatenate([b, w[np.triu_indices_from(w, k=1)]])
y_s = np.concatenate([b_s, w_s[np.triu_indices_from(w, k=1)]])
y = np.concatenate([b_list[10], w_list[10][np.triu_indices_from(w, k=1)]])

plt.figure(figsize=(6, 6))
plt.plot([-1, 1], [-1, 1], 'r--', label='y = x')
plt.xlim(-0.7, 0.7)
plt.ylim(-0.7, 0.7)
plt.scatter(x, y, label='aug', alpha=0.5, color='blue')
plt.scatter(x, y_s, label='obs', alpha=0.5, color='green')
plt.legend()
plt.show()

# %%
x = np.concatenate([b, w[np.triu_indices_from(w, k=1)]])
y_s = np.concatenate([b_s_1, w_s_1[np.triu_indices_from(w, k=1)]])
y = np.concatenate([b_list_1[0], w_list_1[0][np.triu_indices_from(w, k=1)]])

plt.figure(figsize=(6, 6))
plt.plot([-1, 1], [-1, 1], 'r--', label='y = x')
plt.xlim(-0.7, 0.7)
plt.ylim(-0.7, 0.7)
plt.scatter(x, y, label='aug', alpha=0.5, color='blue')
plt.scatter(x, y_s, label='obs', alpha=0.5, color='green')
plt.legend()
plt.show()

# %%
tensor = np.tile(np.arange(40), (40, 1))
print(tensor.shape)
plt.imshow(w_list[10], origin='lower', cmap='viridis', extent=[0, 39, 0, 39])
plt.colorbar(label='w value')
plt.xlabel('i (column index)')
plt.ylabel('j (row index)')
plt.title('2D Heatmap of w')
plt.show()
# Out:
# (40, 40)

# %%
tensor = np.tile(np.arange(40), (40, 1))
print(tensor.shape)
plt.imshow(w_list[0], origin='lower', cmap='viridis', extent=[0, 39, 0, 39])
plt.colorbar(label='w value')
plt.xlabel('x (column index)')
plt.ylabel('y (row index)')
plt.title('2D Heatmap of w')
plt.show()
# Out:
# (40, 40)
